# %%
import time
import json
import re
import os 
import tensorflow as tf
import pandas as pd
import numpy as np
from itertools import compress
import matplotlib.pyplot as plt

# %%
def json_to_csv(directory, fileNames, createSample=False):
    """
    json_to_csv: loops through specified JSON files and converts them to csv files.
                 option to also create a sample csv, which uses np.random.seed 9001 to create a sample dataset with 10% of the observations
    
                 pandas has a read_json function, but returns a 'Trailing data error' when working with these specific files
                 
                 
    Inputs: -directory of JSON files
            -list of JSON filenames
            -createSample flag
            
    """
    
    start = time.time()

    jsonData = []

    for fileName in fileNames:
        with open(directory + fileName,  encoding="utf8") as file:
            print('{0} opened'.format(fileName))
            for line in file:
                #I use an rstrip here because some of the files have trailing blank spaces
                jsonData.append(json.loads(line.rstrip()))
        
        df = pd.DataFrame.from_dict(jsonData)
        
        csvFileName = fileName[:len(fileName)-5] + '.csv'
        
        df.to_csv(directory + csvFileName)
        print('{0} created'.format(csvFileName))
        
        
        if createSample:
            np.random.seed(9001)
            msk = np.random.rand(len(df)) <= 0.1
            sample = df[msk]
            
            csvSampleFileName = fileName[:len(fileName)-5] + '_sample.csv'
            
            sample.to_csv(directory + csvSampleFileName)
            print('{0} created'.format(csvSampleFileName))
        
    print('This function took {} minutes to run'.format((time.time()-start)/60))

# %%
df_business = pd.read_json('data/business.json', lines=True)

# df_business.dropna(inplace=True, subset = ['categories'], axis=0)

# df_business.loc[df_business['categories'].str.contains('Restaurants')]

# df_business['categories'].value_counts()

# %%
df_business.head()
# Out:
#                           address  \
# 0     2818 E Camino Acequia Drive
# 1            30 Eglinton Avenue W
# 2       10110 Johnston Rd, Ste 15
# 3   15655 W Roosevelt St, Ste 237
# 4  4209 Stuart Andrew Blvd, Ste F
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 3                                               None  xvX2CttrVhyG2z1dFg_0xw
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
#
#                                           categories         city  \
# 0                                  Golf, Active Life      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 2                  Sushi Bars, Restaurants, Japanese    Charlotte
# 3                      Insurance, Financial Services     Goodyear
# 4  Plumbing, Shopping, Local Services, Home Servi...    Charlotte
#
#                                                hours  is_open   latitude  \
# 0                                               None        0  33.522143
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...        1  43.605499
# 2  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...        1  35.092564
# 3  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  33.455613
# 4  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...        1  35.190012
#
#     longitude                             name postal_code  review_count  \
# 0 -112.018481       Arizona Biltmore Golf Club       85016             5
# 1  -79.652289       Emerald Chinese Restaurant     L5R 3E7           128
# 2  -80.859132      Musashi Japanese Restaurant       28210           170
# 3 -112.395596  Farmers Insurance - Paul Lorenz       85338             3
# 4  -80.887223              Queen City Plumbing       28217             4
#
#    stars state
# 0    3.0    AZ
# 1    2.5    ON
# 2    4.0    NC
# 3    5.0    AZ
# 4    4.0    NC

# %%
#df_user = pd.read_csv('data/user.csv', nrows = 100)

# df_review =  pd.read_csv('data/review.csv', usecols = ['business_id', 'user_id', 'stars'])
# user_cnts = df_review['user_id'].value_counts()
# top_users = user_cnts.loc[user_cnts>2].index
# df_review = df_review.loc[df_review['user_id'].isin(top_users)]
# df_review.to_csv('data/filtered_reviews.csv')

# %%
# reading filterdreview 

df_review = pd.read_csv('data/filtered_reviews.csv', index_col=0)
# Out:
# /Users/thomaslee/anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
# inumerating business_in and user_id with bid and uid 
def build_fmap_invmap(ser):
    uni_ele = ser.unique()
    fmap = {v:i for i, v in enumerate(uni_ele)}
    invmap = {i:v for i, v in enumerate(uni_ele)}
    return fmap, invmap

# %%
# setting debuging enviroment on (dbg =1) to turn it off (dbg = 0)
dbg = 1
if dbg:
    df_review = df_review.head(100000)

# %%
bus_fmap, bus_invmap = build_fmap_invmap(df_review['business_id'])
u_fmap, u_invmap = build_fmap_invmap(df_review['user_id'])

# %%
df_review['bid'] = df_review['business_id'].map(bus_fmap)

# %%
df_review['uid'] = df_review['user_id'].map(u_fmap)

# %%
df_review.head()
# Out:
#               business_id  stars                 user_id  bid  uid
# 0  ujmEBvifdJM6h6RLv4wQIg    1.0  hG7b0MtEbXx5QzbzE6C_VA    0    0
# 2  WTqjgwHlXbSFevF32_DJVw    5.0  n6-Gk65cPZL6Uz8qRm3NYw    1    1
# 3  ikCg8xy5JIg_NGPx-MSIDA    5.0  dacAIZ6fTM6mqwW5uxkskg    2    2
# 6  3fw2X5bZYeW9xCz_zGhOHg    3.0  jlu4CztcSxrKx56ba1a5AQ    3    3
# 7  zvO-PJCpNk4fgAVUnExYAA    1.0  d6xvYpyzcfbF_AZ8vMB7QA    4    4

# %%
n_users, n_bus = df_review['uid'].nunique(), df_review['bid'].nunique()

# %%
n_dim = 5

# %%
# Initializing tensor flow at a randon number | n_users * n_dim (layers) initializing at some random number between
# -1 to 1 both for business and users. For internal layer. 
# PS > Create a function with code below: 

user_vector_raw = tf.Variable(tf.random_uniform([n_users, n_dim], minval = -1., maxval = 1.))
bus_vector_raw = tf.Variable(tf.random_uniform([n_bus, n_dim], minval = -1., maxval = 1.))

# running the tanh function to find 
user_vector = tf.tanh(user_vector_raw)
bus_vector = tf.tanh(bus_vector_raw)

# Stipulating the imput layer. 
users = tf.placeholder(tf.int32, shape=(None))
businesses = tf.placeholder(tf.int32, shape=(None))
ratings = tf.placeholder(tf.float32, shape=(None))

UserSampled = tf.nn.embedding_lookup(user_vector, users)
BusinessSampled = tf.nn.embedding_lookup(bus_vector, businesses)
UserSampled.set_shape([None, n_dim])
BusinessSampled.set_shape([None, n_dim])

# input tensors for products, users, ratings
# Out:
# WARNING:tensorflow:From /Users/thomaslee/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Defining the output
# transfer into a fucntion
estimatedaffinitiesraw = tf.reduce_sum(UserSampled * BusinessSampled, 1)
estimatedaffinities = tf.sigmoid(estimatedaffinitiesraw)*5

# %%
# estimatedaffinities - ratings ask Lee to clarify ratings, where that ratings comes from? ask to explain the loss function 
# transfer into a function 
loss = tf.reduce_sum(tf.square(estimatedaffinities - ratings))
opt = tf.train.RMSPropOptimizer(learning_rate=.1).minimize(loss)
# Out:
# WARNING:tensorflow:From /Users/thomaslee/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
# Setting the session and intialize it 

sess = tf.Session()

# %%
# picking up 64 randon rows in order to run under memory capacity
rows = np.random.choice(df_review.shape[0], 64)

# %%
sess.run(tf.global_variables_initializer())

# %%
# Creating a loop to train under 64 random rows 
for i in range(10000):
    rows = np.random.choice(df_review.shape[0], 64)
    dfrows = df_review.iloc[rows]
    fd = {users:dfrows['uid'].values,
         businesses:dfrows['bid'].values,
         ratings:dfrows['stars'].values}
    _, l2loss = sess.run([opt, loss], fd)
    if i % 1000 == 0:
        print(l2loss)
# Out:
# 228.34375
# 196.62096
# 129.46735
# 127.56539
# 62.1024
# 92.022675
# 63.691776
# 67.92952
# 44.007023
# 30.19474

# %%
user_values, bus_values = sess.run([user_vector, bus_vector])

# %%
bus_vec_df = pd.DataFrame(data = bus_values, index = 
                          [bus_invmap[i] for i in range(n_bus)])

# %%
bus_vec_df
# Out:
#                                0         1         2         3         4
# ujmEBvifdJM6h6RLv4wQIg  0.999999  0.939678  0.999999  0.999996  0.421627
# WTqjgwHlXbSFevF32_DJVw -0.846114 -0.983510  0.999340 -0.999994 -0.998755
# ikCg8xy5JIg_NGPx-MSIDA  0.991453  0.998031  0.820526 -0.996142 -0.725511
# 3fw2X5bZYeW9xCz_zGhOHg -0.060154 -0.462281 -0.474131 -0.891558  0.803159
# zvO-PJCpNk4fgAVUnExYAA  0.623059  0.518949 -0.653268  0.720762  0.564523
# b2jN2mm9Wf3RcrZCgfo1cg  0.974992 -0.713141 -0.999624 -0.996452 -0.999995
# oxwGyA17NL6c5t1Etg5WgQ  0.999998  0.800680  0.283163  0.624772 -0.207765
# 8mIrX_LrOnAqWsB5JrOojQ -1.000000 -1.000000  1.000000 -0.163437 -1.000000
# FxLfqxdYPA6Z85PFKaqLrg -0.051394  0.675002  0.243848  0.584288 -0.356887
# AakkkTuGZA2KBodKi2_u8A  0.961140  0.331234  0.961127 -0.429804  0.735228
# YvrylyuWgbP90RgMqZQVnQ  0.890114 -0.999396 -0.997183  0.998125  0.999638
# NyLYY8q1-H3hfsTwuwLPCg -0.999996 -0.999999 -0.999968  1.000000  0.593669
# cHdJXLlKNWixBXpDwEGb_A  0.999980 -1.000000  0.782609  0.300945  0.999999
# 6lj2BJ4tJeu7db5asGHQ4w -0.997242  0.481218 -0.292575 -0.996774 -0.993340
# y-Iw6dZflNix4BdwIyTNGA -0.758632  0.999999 -0.997426  0.999995  0.956489
# qx6WhZ42eDKmBchZDax4dQ -1.000000  0.999999 -0.570631 -1.000000  1.000000
# Mem13A3C202RzT53npn4NA  0.999994  0.999712 -0.999990  0.999996 -0.999994
# I4Nr-MVc26qWr08-S3Q1ow  0.999902  0.586578  0.999902  0.997191 -0.999998
# Sfc8Haz2Yri8Mo1L0E0TsA -0.285478  0.432406 -0.999948 -0.604157  0.801617
# FQ1wBQb3aNeRMThSQEV0Qg -0.999792 -0.999810  0.999992 -0.999865 -0.999982
# hd5xm20tfSa70-6UqD9-bg  0.999972 -0.999991 -0.999998  0.999995  0.999787
# 9nTF596jDvBBia2EXXiOOg -0.578006 -0.746048  0.694451 -0.783559 -0.621112
# dm6sO_Y8JdKTE1ZM955yug -1.000000  1.000000  0.259241  0.999999  0.999999
# XTzKRvWciP_BZ9imk8mmPQ  0.999642  0.968388  0.999975 -0.999999 -0.999989
# CDpoJiqgM04wqQTZ6QkTqQ  0.977577  0.999942 -0.999998  0.999992  0.999976
# 3JxKzWquEbPC3yPIfoCiLw -0.999209 -0.998936 -0.999997 -0.999866 -0.995253
# YSUcHqlKMPHHJ_cTrqtNrA -0.056523 -0.397395 -0.090760  0.293328 -0.156621
# N0apJkxIem2E8irTBRKnHw -1.000000  0.871262  0.668152  0.290955  1.000000
# sMzNLdhJZGzYirIWt-fMAg -0.999955 -0.998373  0.956837 -0.598506  0.999927
# IMLrj2klosTFvPRLv56cng  1.000000  0.999995 -0.976369  0.398130  0.550336
# ...                          ...       ...       ...       ...       ...
# _WsGlZnbXBdPcs0qM2Qm7w  0.670364  0.112146 -0.607103  0.657302  0.142602
# MGo5TXadUjDaPi5LYHArhA  0.787191 -0.219182  0.750189 -0.309501  0.750384
# um0brvgJQ_k0bfYQ4S6FpA -0.367808 -0.536673 -0.313175 -0.275295 -0.862707
# hJda5g5v_2rT3D-3mSf7cQ  0.091368 -0.142520  0.336610 -0.243421 -0.535638
# 0-7jRk54XXZgND3F3bo8sw -0.559608  0.640301  0.417675  0.158867 -0.061364
# aIVCYE8frb2ELMQkvqykrw -0.034604 -0.978038 -0.046785 -0.979288 -0.970321
# lbYQ5INAEa1yCjS3XUFN_A -0.748089  0.853806  0.978553  0.977893 -0.156016
# m3Tatgcyw8dUzts0wqpKMg  0.994894 -0.982110  0.984246 -0.157997 -0.964514
# n2kOsDur7tCLygSa87glJQ  0.486295  0.551493  0.387403 -0.409286  0.350987
# aiSFOdB2rMeA5cdwwmAGtA -0.732485 -0.782207 -0.924845  0.456186  0.285495
# lCcjph5wdCzGfTUO6LPocg -0.964510 -0.972034  0.290606 -0.007987 -0.284508
# Vt1iSx253f6yL0_TaSx6gQ -0.406382  0.812001  0.496623  0.734692  0.771816
# VJTBDu7fc20u277sZckJzg  0.983669  0.943188  0.919614 -0.957936 -0.966367
# pBEM4bDE7MJ6G4SKmnjfbg -0.973124  0.979946  0.953495  0.906503 -0.857004
# 3kvyAFaf_x9xRBjlKBaA-Q  0.378418  0.962869  0.301333  0.190069  0.214736
# JIlybDRCddKZAJ2-Y8SKCg -0.080647 -0.812976  0.446587  0.694084  0.732520
# 7uhvxvEu5x3t_OJk-zp2sQ  0.798947 -0.901194  0.623777  0.008344 -0.871044
# bhosqo-Q1xp67iLqrd1Rbw  0.760642  0.825553  0.622797  0.260760  0.525502
# 0n3l_hKswZ3BJrRhSxOa1g  0.422347  0.326536  0.437604 -0.242494 -0.106307
# ZEuTAZjWKctjQLbQLCEP5Q -0.899600 -0.684004  0.938917  0.662635  0.935600
# HeH4qL9xS_XYnAQh6Yu8JQ  0.439368  0.213724 -0.255968 -0.125806  0.390623
# U5zf1i_WzinhXLZH7X-N-Q  0.579462  0.463461 -0.373033 -0.351086 -0.543552
# cEcTtJIc0h3rRuJWoTgcMg -0.160012 -0.216376  0.690095 -0.287531 -0.105457
# _5S7EhbqW5_YoxuPTrfnuQ  0.424477 -0.186036  0.739833  0.064394  0.069278
# aaJ-RaUdHyB4R3U4qNbRBA  0.906112  0.904863  0.750640 -0.686097  0.974038
# cPPYaBM07eTlkknpvVpW1Q  0.881341 -0.638927 -0.273555  0.197146 -0.241081
# duVuU_LzYwjdd9LNbCgnyw -0.441969  0.852708 -0.381388 -0.494247 -0.801130
# M8kNekCc1vK-w84MSK79kw  0.820060 -0.576980 -0.538251  0.741019 -0.574189
# 0NK0knbek2VGaMp01UkENw -0.988171  0.980887 -0.745132 -0.931220  0.182859
# 0p405x2TRJCPYfHHt1sgTA  0.898661 -0.506382  0.338778 -0.634931 -0.657295
#
# [13589 rows x 5 columns]

# %%
# Joining df_business + bus_vec_df
df_all = df_business.join(bus_vec_df, on='business_id', how='right')

# %%
# Dropping NaN columns 
df_all = df_all.dropna()

# %%
# Pulling user ID 4 and comparing to inverse map on uid (not sure why, maybe to check accuracy?)
uid = 4
u_invmap[uid]
# Out:
# 'd6xvYpyzcfbF_AZ8vMB7QA'

# %%
bname = 'cHdJXLlKNWixBXpDwEGb_A'
bid = bus_fmap[bname]

# %%
df_all.loc[df_all['categories'].str.contains('Restaurant') & 
           df_all['categories'].str.contains('Japanese')]
# Out:
#                                                 address  \
# 2                             10110 Johnston Rd, Ste 15
# 73                                        436 Market St
# 80                                   529-17th Avenue SW
# 185                           2945 Lake Shore Boulevard
# 343                                 10624 S Eastern Ave
# 346                                       1909 E Ray Rd
# 444                          3339 Boulevard des Sources
# 507                           6989 N Hayden Rd, Ste A12
# 524                               338-8338 18 Street SE
# 577                                    1418 Rue Cartier
# 706                  1716 W Horizon Ridge Pkwy, Ste 110
# 766                                  599 Bloor Street W
# 1037                            16 W Horizon Ridge Pkwy
# 1057                      2035 Kennedy Road, 14th Floor
# 1130                            1900 Cayuga St, Ste 101
# 1236                               149 Rue Jean-Talon O
# 1308                                  1137 17 Avenue SW
# 1309                                  30 Bristol Road E
# 1564                          7318 E Shea Blvd, Ste 101
# 1637                          1061 W Pleasant Valley Rd
# 1890                                       8750 Jane St
# 1905                               2861 Dundas Street W
# 1916                                572 Danforth Avenue
# 1980                              1813 Rue Jean-Talon E
# 1994                               7212 Macleod Trail S
# 2043                     750 East Pyle Ave, Ste 108-109
# 2078                                    3531 Forbes Ave
# 2229                                 833 Bloor Street W
# 2261                                      6025 Kruse Dr
# 2347                 4355 W Spring Mountain Rd, Ste 107
# ...                                                 ...
# 15354                              1224 Dundas Street W
# 15396                           360 Highway 7 E, Unit 3
# 15715                 3820 Brentwood Road NW, Suite 130
# 15832                                      8418 Park Rd
# 16257                                      751 N Hwy 16
# 16277                                 81 Harbord Street
# 16345                                   4136 Library Rd
# 16408                          2861 N Green Valley Pkwy
# 16416                     3540 Rutherford Road, Unit 64
# 16569                                     1276 W 6th St
# 16826                                 1919 S Gilbert Rd
# 17024                                 2036 Yonge Street
# 17260                            5751 Boulevard Gouin O
# 17286  Crystals Mall City Center, 3720 Las Vegas Blvd S
# 17308                                    5904 Bryant St
# 17461                       4206 E Chandler Blvd, Ste 7
# 17750                        161 Frederick St, Unit 100
# 17887                         1006 E Warner Rd, Ste 113
# 17917                               6485 Mississauga Rd
# 17924                              6705 Avenue Papineau
# 17948                                   89 E Towne Mall
# 17959                                80 Thickson Road S
# 18195                              2795 Danforth Avenue
# 18415                                      124 S 6th St
# 18490                                    234 Euclid Ave
# 18595                        15111 N Hayden Rd, Ste 120
# 18748                                1232 Greene Avenue
# 18863                       1616 Rue Sainte-Catherine O
# 18991                                305 16th Avenue NW
# 19016                             5795 W Bell Rd, Ste 1
#
#                                               attributes  \
# 2      {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...
# 73     {'OutdoorSeating': 'False', 'HasTV': 'True', '...
# 80     {'WiFi': ''free'', 'GoodForDancing': 'False', ...
# 185    {'RestaurantsDelivery': 'True', 'HasTV': 'True...
# 343    {'RestaurantsTakeOut': 'True', 'NoiseLevel': '...
# 346    {'RestaurantsDelivery': 'False', 'RestaurantsT...
# 444    {'RestaurantsDelivery': 'False', 'RestaurantsA...
# 507    {'RestaurantsAttire': ''casual'', 'OutdoorSeat...
# 524    {'GoodForMeal': '{'dessert': False, 'latenight...
# 577    {'RestaurantsPriceRange2': '3', 'OutdoorSeatin...
# 706    {'WiFi': 'u'no'', 'RestaurantsAttire': ''casua...
# 766    {'RestaurantsGoodForGroups': 'False', 'Restaur...
# 1037   {'NoiseLevel': 'u'average'', 'BikeParking': 'T...
# 1057   {'RestaurantsGoodForGroups': 'True', 'WiFi': '...
# 1130   {'RestaurantsAttire': ''casual'', 'GoodForKids...
# 1236   {'BusinessParking': '{'garage': False, 'street...
# 1308   {'OutdoorSeating': 'True', 'WheelchairAccessib...
# 1309   {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 1564   {'NoiseLevel': 'u'average'', 'RestaurantsGoodF...
# 1637   {'BusinessParking': '{'garage': False, 'street...
# 1890   {'RestaurantsReservations': 'True', 'NoiseLeve...
# 1905   {'GoodForMeal': '{'dessert': False, 'latenight...
# 1916   {'Alcohol': 'u'full_bar'', 'RestaurantsReserva...
# 1980   {'OutdoorSeating': 'False', 'GoodForMeal': '{'...
# 1994   {'BikeParking': 'True', 'RestaurantsPriceRange...
# 2043   {'HasTV': 'False', 'Ambience': '{'touristy': F...
# 2078   {'Alcohol': ''none'', 'RestaurantsTakeOut': 'T...
# 2229   {'BikeParking': 'True', 'NoiseLevel': 'u'quiet...
# 2261   {'WiFi': 'u'no'', 'RestaurantsDelivery': 'Fals...
# 2347   {'RestaurantsGoodForGroups': 'True', 'Restaura...
# ...                                                  ...
# 15354  {'RestaurantsAttire': ''casual'', 'Restaurants...
# 15396  {'OutdoorSeating': 'False', 'BikeParking': 'Fa...
# 15715  {'OutdoorSeating': 'False', 'WiFi': 'u'free'',...
# 15832  {'OutdoorSeating': 'True', 'Ambience': '{'tour...
# 16257  {'RestaurantsAttire': ''casual'', 'HasTV': 'Tr...
# 16277  {'WiFi': 'u'no'', 'Caters': 'False', 'Restaura...
# 16345  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 16408  {'Alcohol': ''beer_and_wine'', 'Ambience': '{'...
# 16416  {'Alcohol': 'u'beer_and_wine'', 'BusinessParki...
# 16569  {'RestaurantsAttire': 'u'casual'', 'WiFi': 'u'...
# 16826  {'RestaurantsReservations': 'True', 'WiFi': 'u...
# 17024  {'RestaurantsPriceRange2': '2', 'GoodForKids':...
# 17260  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...
# 17286  {'RestaurantsGoodForGroups': 'True', 'BYOBCork...
# 17308  {'BusinessParking': '{'garage': False, 'street...
# 17461  {'RestaurantsTableService': 'True', 'GoodForKi...
# 17750  {'RestaurantsPriceRange2': '2', 'RestaurantsRe...
# 17887  {'WiFi': ''free'', 'Alcohol': 'u'beer_and_wine...
# 17917  {'RestaurantsDelivery': 'True', 'WiFi': 'u'fre...
# 17924  {'RestaurantsGoodForGroups': 'True', 'GoodForK...
# 17948  {'BikeParking': 'False', 'BusinessAcceptsCredi...
# 17959  {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 18195  {'Caters': 'True', 'Ambience': '{'romantic': F...
# 18415  {'RestaurantsTableService': 'True', 'GoodForDa...
# 18490  {'GoodForKids': 'True', 'BikeParking': 'True',...
# 18595  {'RestaurantsPriceRange2': '1', 'Ambience': '{...
# 18748  {'HasTV': 'False', 'Ambience': '{'romantic': F...
# 18863  {'RestaurantsDelivery': 'False', 'RestaurantsT...
# 18991  {'GoodForMeal': '{'dessert': False, 'latenight...
# 19016  {'RestaurantsAttire': ''casual'', 'BusinessAcc...
#
#                   business_id  \
# 2      gnKjwL_1w79qoiV3IC_xQQ
# 73     v-scZMU6jhnmV955RSzGJw
# 80     PkDghu4aan2_wxrhXjTEgg
# 185    SJBzyJDCR_f6dx5tpYAABA
# 343    jX9DocoiY4Bo9EUkaTSqvg
# 346    ecJri9ozyke4dOCWulZiRQ
# 444    4B8VnRAstRRshxiUzm9yPw
# 507    QS3QxI7u5PRdtbGgI0-UsA
# 524    bPBZEDuHbE-I7bxUWIYMhQ
# 577    9ELnhtgMF8_h8Zky4A7BSA
# 706    1nF8Me63cpxIkFK8Ysx-DA
# 766    Z3UBeP5EoKIXIDmEdA3JmQ
# 1037   nrahyQyopCtajDqUtVVVfA
# 1057   VcZQXpk6vYAXwemOrC9PTw
# 1130   VUbACJQR-_dVwyPYMFSodg
# 1236   8fudA3iNJ1hNDwr5khJGlA
# 1308   nol16kQqVaKrxBOiJJyPrw
# 1309   WLEbbuly3H-_raBE1atQRg
# 1564   CDpoJiqgM04wqQTZ6QkTqQ
# 1637   mpG1R1ktTI3x1twNBsGvXQ
# 1890   y05fRF4JOUE3i58vpGN2vA
# 1905   4vTDFobDGaiI-diLF5TKkQ
# 1916   oU-Af-_1zT-ewuLfIubN2w
# 1980   Sq3LblLJhmYyo8wXFdOtbg
# 1994   F8nkAcuCNH-09AWnfv_oWw
# 2043   vfqUUh_5KF3R7mz2XiNXGg
# 2078   z4CYPDxL_L74GnaD35a9Yw
# 2229   p82Oz-NOHn-MAZQ0jQBkNg
# 2261   cMEln0QCOYFRykhvdkLJzg
# 2347   5yZ1XmDcOEsElDeb9PlPDQ
# ...                       ...
# 15354  7P9pfy7Lp7aH_Arh1OMOAA
# 15396  PFAvETr4Vf6UY548TWvhFA
# 15715  gV8o0KfI4TJte8TflamINg
# 15832  N2M0WyGCyTV5jMOYPH7odA
# 16257  b_kVn5GxxZcHB8ulBrBpXQ
# 16277  q9_gLvTNf11etVxbH7JY0Q
# 16345  qAzOcHnWerREl678su-p0A
# 16408  Xck2KzJcZDJGMtwxMwD71w
# 16416  5kpaX40N0Mj0lx0awd9PmQ
# 16569  6ExIH5FoPyMRhtz4p-2K1g
# 16826  nlwomMElt7sDwF_njfEEIw
# 17024  LCb2moBNkcBto_32rmZJ5A
# 17260  Y38vE7hg2VkFcMVABxgitQ
# 17286  4hG2j_ibsNblDgqei05U_g
# 17308  GDXftPS1_fTJUtZkaEUDhA
# 17461  g-I48SaHtdIGR5ZEoVeNFw
# 17750  AED5R0yXVzJvWAGEqWBG4A
# 17887  3b-jZX9Ms0U9B2Oy_ZmNMA
# 17917  ytge8aUw_wIWOhXrKM8_Hg
# 17924  1IHpn-2l9_r7mfFiU8xNvQ
# 17948  KB25wVbL7Lk22tN72DR0ww
# 17959  qGTd-E0vuSqaYOPDDcfqLA
# 18195  mUGDDv2j1qIzbh1JsAoBGQ
# 18415  grlL6zmHBOer9rPycsRhBA
# 18490  bFTrpstGo0INBIVMDumMKA
# 18595  rWmZAJMZ8NBw-_FbOYPnfA
# 18748  3Jyf-ILCandXRDXOzEfB4w
# 18863  pJVPEicWbvcz8ATQGick6g
# 18991  QIfG40R92HIMzk483cn4kQ
# 19016  gA9hCYY7MYl9oZ3aym5dvw
#
#                                               categories                 city  \
# 2                      Sushi Bars, Restaurants, Japanese            Charlotte
# 73                     Japanese, Sushi Bars, Restaurants           Pittsburgh
# 80     Nightlife, Italian, Restaurants, Japanese, Lou...              Calgary
# 185                    Sushi Bars, Japanese, Restaurants              Toronto
# 343    Restaurants, Hawaiian, Chinese, Japanese, Poke...            Henderson
# 346    Asian Fusion, Japanese, Restaurants, Ramen, Ta...             Chandler
# 444                    Restaurants, Sushi Bars, Japanese  Dollard-des-Ormeaux
# 507    Asian Fusion, Restaurants, Seafood, Sushi Bars...           Scottsdale
# 524                    Japanese, Restaurants, Sushi Bars              Calgary
# 577                                Restaurants, Japanese             Montréal
# 706                        Fondue, Japanese, Restaurants            Henderson
# 766    Poke, Asian Fusion, Food, Restaurants, Hawaiia...              Toronto
# 1037                   Japanese, Sushi Bars, Restaurants            Henderson
# 1057                               Japanese, Restaurants              Toronto
# 1130   Bars, Nightlife, Japanese, Sushi Bars, Lounges...            Middleton
# 1236   Asian Fusion, Restaurants, Japanese, Pan Asian...             Montréal
# 1308     Sushi Bars, Japanese, Restaurants, Asian Fusion              Calgary
# 1309                               Restaurants, Japanese          Mississauga
# 1564   Nightlife, Bars, Restaurants, Japanese, Sushi ...           Scottsdale
# 1637   Sushi Bars, Japanese, Asian Fusion, Restaurant...                Parma
# 1890                               Japanese, Restaurants              Vaughan
# 1905                               Japanese, Restaurants              Toronto
# 1916                   Japanese, Restaurants, Sushi Bars              Toronto
# 1980                   Japanese, Restaurants, Sushi Bars             Montréal
# 1994                   Restaurants, Japanese, Sushi Bars              Calgary
# 2043     Asian Fusion, Japanese, Sushi Bars, Restaurants            Las Vegas
# 2078               Noodles, Restaurants, Japanese, Ramen           Pittsburgh
# 2229     Sushi Bars, Restaurants, Japanese, Asian Fusion              Toronto
# 2261                               Japanese, Restaurants                Solon
# 2347                        Restaurants, Japanese, Ramen            Las Vegas
# ...                                                  ...                  ...
# 15354                Restaurants, Asian Fusion, Japanese          Mississauga
# 15396       Restaurants, Canadian (New), Japanese, Ramen        Richmond Hill
# 15715  Nightlife, Sushi Bars, Bars, Japanese, Restaur...              Calgary
# 15832  Sushi Bars, Asian Fusion, Japanese, Chinese, R...            Charlotte
# 16257     Sushi Bars, Japanese, Steakhouses, Restaurants               Denver
# 16277            Sushi Bars, Food, Japanese, Restaurants              Toronto
# 16345                     Chinese, Restaurants, Japanese           Pittsburgh
# 16408                  Japanese, Restaurants, Sushi Bars            Henderson
# 16416  Steakhouses, Seafood, Food, Teppanyaki, Specia...           Woodbridge
# 16569                  Sushi Bars, Restaurants, Japanese            Cleveland
# 16826      Japanese, Teppanyaki, Sushi Bars, Restaurants                 Mesa
# 17024         Japanese, Sushi Bars, Buffets, Restaurants              Toronto
# 17260                  Japanese, Restaurants, Vietnamese             Montréal
# 17286  Restaurants, Lounges, Sushi Bars, Japanese, Ni...            Las Vegas
# 17308  Restaurants, Juice Bars & Smoothies, Food, Jap...           Pittsburgh
# 17461         Seafood, Japanese, Restaurants, Sushi Bars              Phoenix
# 17750  Desserts, Food, Restaurants, Bakeries, Cafes, ...              Toronto
# 17887                  Japanese, Restaurants, Sushi Bars                Tempe
# 17917            Thai, Japanese, Restaurants, Sushi Bars          Mississauga
# 17924  Asian Fusion, Japanese, Sushi Bars, Restaurant...             Montréal
# 17948                              Restaurants, Japanese              Madison
# 17959                              Japanese, Restaurants               Whitby
# 18195                  Restaurants, Sushi Bars, Japanese              Toronto
# 18415  Bars, Sushi Bars, Nightlife, Restaurants, Japa...            Las Vegas
# 18490              Noodles, Japanese, Ramen, Restaurants            Cleveland
# 18595                              Restaurants, Japanese           Scottsdale
# 18748                              Restaurants, Japanese            Westmount
# 18863      Chinese, Japanese, Restaurants, Ramen, Diners             Montréal
# 18991                              Japanese, Restaurants              Calgary
# 19016                  Restaurants, Sushi Bars, Japanese             Glendale
#
#                                                    hours  is_open   latitude  \
# 2      {'Monday': '17:30-21:30', 'Wednesday': '17:30-...        1  35.092564
# 73     {'Monday': '11:0-20:0', 'Tuesday': '11:0-20:0'...        1  40.441062
# 80     {'Tuesday': '14:0-23:0', 'Wednesday': '14:0-23...        0  51.037778
# 185    {'Monday': '16:0-22:0', 'Tuesday': '11:30-22:0...        1  43.600523
# 343    {'Monday': '0:0-0:0', 'Tuesday': '11:0-19:0', ...        1  35.998220
# 346    {'Monday': '17:0-21:30', 'Tuesday': '17:0-21:3...        1  33.320006
# 444    {'Monday': '17:0-22:0', 'Tuesday': '17:0-23:0'...        1  45.484315
# 507    {'Monday': '0:0-0:0', 'Tuesday': '17:30-21:0',...        1  33.538029
# 524    {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  50.977178
# 577    {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...        0  45.523226
# 706    {'Monday': '17:0-21:30', 'Tuesday': '17:0-21:3...        1  36.011899
# 766    {'Tuesday': '12:0-21:0', 'Wednesday': '12:0-21...        0  43.664603
# 1037   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  36.011479
# 1057   {'Tuesday': '17:30-21:30', 'Wednesday': '17:30...        0  43.776815
# 1130   {'Monday': '16:30-22:0', 'Tuesday': '16:30-22:...        1  43.096098
# 1236   {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...        1  45.533148
# 1308   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  51.037608
# 1309   {'Monday': '11:30-22:30', 'Tuesday': '11:30-22...        0  43.614622
# 1564   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        0  33.582229
# 1637   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  41.359812
# 1890   {'Monday': '17:0-23:0', 'Tuesday': '17:0-22:0'...        0  43.818741
# 1905   {'Monday': '12:0-21:30', 'Wednesday': '12:0-21...        1  43.665152
# 1916   {'Tuesday': '11:30-23:0', 'Wednesday': '11:30-...        1  43.678695
# 1980   {'Monday': '11:0-21:30', 'Tuesday': '11:0-21:3...        1  45.548069
# 1994   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  50.989145
# 2043   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        0  36.006937
# 2078   {'Monday': '11:0-21:30', 'Tuesday': '11:0-21:3...        1  40.440519
# 2229   {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...        1  43.662417
# 2261   {'Monday': '17:0-21:30', 'Tuesday': '17:0-21:3...        1  41.393800
# 2347   {'Tuesday': '11:30-22:0', 'Wednesday': '11:30-...        0  36.125929
# ...                                                  ...      ...        ...
# 15354  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...        1  43.553904
# 15396  {'Tuesday': '17:0-21:0', 'Wednesday': '17:0-21...        1  43.841523
# 15715  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        0  51.086501
# 15832  {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...        0  35.117274
# 16257  {'Tuesday': '16:0-22:0', 'Wednesday': '16:0-22...        0  35.463160
# 16277  {'Monday': '18:0-23:0', 'Tuesday': '18:0-23:0'...        1  43.662727
# 16345  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  40.358953
# 16408  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...        0  36.071889
# 16416  {'Monday': '0:0-0:0', 'Tuesday': '17:0-21:0', ...        1  43.828842
# 16569  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...        0  41.500183
# 16826  {'Monday': '17:0-21:30', 'Tuesday': '17:0-21:3...        1  33.380086
# 17024  {'Tuesday': '17:0-22:30', 'Wednesday': '17:0-2...        1  43.701275
# 17260  {'Tuesday': '11:0-22:0', 'Wednesday': '11:0-22...        1  45.535452
# 17286  {'Monday': '12:0-22:0', 'Tuesday': '12:0-22:0'...        0  36.108713
# 17308  {'Monday': '11:0-21:0', 'Wednesday': '16:0-21:...        0  40.475584
# 17461  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  33.305825
# 17750  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...        1  43.650707
# 17887  {'Monday': '17:0-21:0', 'Tuesday': '17:0-21:0'...        0  33.335384
# 17917  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...        1  43.597904
# 17924  {'Tuesday': '17:0-22:0', 'Wednesday': '17:0-22...        0  45.545130
# 17948  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...        1  43.125334
# 17959  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  43.883870
# 18195  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  43.689307
# 18415  {'Monday': '0:0-0:0', 'Tuesday': '11:0-22:0', ...        1  36.167975
# 18490  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  41.499392
# 18595  {'Monday': '10:0-15:30', 'Tuesday': '10:0-15:3...        1  33.622040
# 18748  {'Monday': '17:30-21:30', 'Tuesday': '17:30-21...        1  45.486452
# 18863  {'Monday': '10:30-20:30', 'Tuesday': '10:30-20...        0  45.493982
# 18991  {'Monday': '17:0-21:0', 'Wednesday': '17:0-23:...        1  51.066697
# 19016  {'Monday': '0:0-0:0', 'Tuesday': '17:0-21:30',...        1  33.638374
#
#         longitude                                     name postal_code  \
# 2      -80.859132              Musashi Japanese Restaurant       28210
# 73     -80.002126                        No. 1 Sushi Sushi       15222
# 80    -114.073351                                 MiraKuru     T2S 0A9
# 185    -79.505516                         Kibo Sushi House     M8V 1J5
# 343   -115.102246                                China AAA       89052
# 346   -111.809675                          Nishikawa Ramen       85225
# 444    -73.795652                        Maiko Sushi - DDO     H9B 1Z8
# 507   -111.905676                     Sakana Sushi & Grill       85250
# 524   -114.013257                             Oishii Sushi     T2C 4E4
# 577    -73.551979                             Saiken Sushi     H2K 4C8
# 706   -115.062863                     Shabu Shabu Paradise       89012
# 766    -79.412934                        Big Tuna Poké Bar     M6G 1K5
# 1037  -114.992241                                The Sushi       89012
# 1057   -79.282992                                   Sagano     M1T 3G2
# 1130   -89.514471                                Takara 88       53562
# 1236   -73.619872                                Jiep Jiep     H2R 2W9
# 1308  -114.089432                             Fusion Sushi     T2T 0B6
# 1309   -79.663091                               Tako Sushi     L4Z 3K8
# 1564  -111.923257                                Squid Ink       85260
# 1637   -81.685649                 Blue Ginger Asian Bistro       44134
# 1890   -79.531028      New Generation Sushi and Teppanyaki     L4K 2M9
# 1905   -79.465012                              D & Y Sushi     M6P 1Y9
# 1916   -79.347051                Katsu Japanese Restaurant     M4K 1R1
# 1980   -73.606952                               Sushi Lobü     H2E 1T4
# 1994  -114.071465                  Sho Sushi Bar & Kitchen     T2H 0L9
# 2043  -115.146669           Tokyo Peking Asian Restaurants       89183
# 2078   -79.958567                       Zen's Noodle House       15213
# 2229   -79.422871                               Riki Sushi     M6G 1M1
# 2261   -81.445000                    Akira Hibachi & Sushi       44139
# 2347  -115.197631                              Yagyu Ramen       89102
# ...           ...                                      ...         ...
# 15354  -79.645339                                  Katsuya     L5C 4G7
# 15396  -79.397015                   Koi Sakana Ramen House     L4B 3Y7
# 15715 -114.128615                                   Kagura     T2L 2L5
# 15832  -80.856801                Umai Sushi & Asian Bistro       28210
# 16257  -80.993622                                   Yamato       28037
# 16277  -79.403279                                     Yasu         M5S
# 16345  -80.029218                             Asian Garden       15234
# 16408 -115.083353                           Sumo Sushi Bar       89014
# 16416  -79.549051                              Teppan Cave     L4H 3T8
# 16569  -81.699511                               Sushi Rock       44113
# 16826 -111.787866  Ah-So Teppanyaki & Sushi House of Japan       85204
# 17024  -79.397533                               Echo Sushi     M4S 1Z9
# 17260  -73.776309                              Zenbu Sushi     H4J 1E2
# 17286 -115.173192                             Social House       89158
# 17308  -79.919675                             Plate & Bowl       15206
# 17461 -111.992471                                Sushi Ken       85048
# 17750  -79.368797                           NEO COFFEE BAR     M5A 4P3
# 17887 -111.927076                                Sushi Kee       85284
# 17917  -79.735232                     Wind Japanese & Thai     L5N 1A6
# 17924  -73.600130                                     Nami     H2G 2X4
# 17948  -89.306164                              Sarku Japan       53704
# 17959  -78.912438                                   Shogun     L1N 7T2
# 18195  -79.295541                             Double Sushi     M4C 1M1
# 18415 -115.140442                              Bocho Sushi       89101
# 18490  -81.691391                  Otani Noodle - Downtown       44114
# 18595 -111.904414                            Samurai Sam's       85260
# 18748  -73.588712                       Kashima Restaurant     H3Z 2A3
# 18863  -73.578751                               Yuki Ramen     H3H 1L7
# 18991 -114.067777                         Umami Noodle Bar     T2M 0H9
# 19016 -112.183773              Tokyo Lobby Sushi and Grill       85308
#
#        review_count  stars state         0         1         2         3  \
# 2               170    4.0    NC -0.999814  0.999504  0.997142  0.999139
# 73              106    4.5    PA -0.999631 -0.999927  0.999002 -0.999869
# 80               16    3.5    AB  0.283822  0.257769  0.384145  0.186970
# 185              15    4.0    ON -0.980898  0.999363 -0.998411 -0.997496
# 343             149    4.5    NV -0.999990 -0.999936  0.995477 -0.999978
# 346             427    4.0    AZ  0.999996  0.670560  0.999998  0.999999
# 444              51    4.0    QC  0.999537 -0.984982  0.999888  0.999951
# 507             347    4.0    AZ -0.552663 -0.999998 -0.999890  0.999872
# 524              78    3.5    AB -0.416461  0.231266  0.992997 -0.774893
# 577               4    3.0    QC  0.358013 -0.892293 -0.872533 -0.730438
# 706             248    4.5    NV  0.999759 -0.999447 -0.999991 -1.000000
# 766              65    3.0    ON  0.337885 -0.576149  0.389260 -0.482044
# 1037            190    3.5    NV  0.999999  0.983773 -0.997080  0.057093
# 1057             25    3.0    ON  0.301506  0.817738 -0.496908  0.050854
# 1130             66    4.0    WI  0.952183  0.955756 -0.401230 -0.411865
# 1236             12    3.5    QC  0.967150  0.996340 -0.681698  0.999822
# 1308             26    2.5    AB -0.261273 -0.667741 -0.490442 -0.696095
# 1309             48    3.0    ON  0.980246  0.834124  0.545441  0.364309
# 1564            121    4.0    AZ  0.977577  0.999942 -0.999998  0.999992
# 1637            128    4.0    OH -0.999957 -0.996805  0.999997 -0.999983
# 1890             38    3.5    ON  0.999989 -0.999548 -0.954602  0.999367
# 1905             27    3.5    ON  0.670858  0.840669  0.998337 -0.500627
# 1916             86    3.0    ON -0.630123 -0.376614 -0.053043 -0.999172
# 1980             13    4.5    QC  0.798074  0.982977  0.928073 -0.994209
# 1994             64    3.5    AB -0.908262 -0.790495  0.287848 -0.157062
# 2043             24    5.0    NV  0.921161  0.841287  0.299680  0.441430
# 2078             77    3.5    PA -0.963899  0.997823 -0.004537 -0.999897
# 2229             11    4.0    ON  0.991352 -0.970368 -0.981050  0.796566
# 2261             58    3.5    OH -0.973687 -0.980531 -0.331439 -0.999713
# 2347            150    4.0    NV  0.999997  0.999984  0.998940  0.999998
# ...             ...    ...   ...       ...       ...       ...       ...
# 15354            59    4.5    ON -0.999753  0.998715 -0.998812  0.999984
# 15396           148    3.5    ON  0.899968  0.694376 -0.936073 -0.933934
# 15715            12    3.0    AB  0.214909 -0.532760  0.031088 -0.832611
# 15832            97    4.0    NC -0.998481 -0.999941  0.999990 -0.999999
# 16257            13    1.5    NC -0.388076 -0.512410 -0.852737  0.532570
# 16277           300    4.5    ON  0.999999 -0.473260  0.999999 -0.999999
# 16345            20    2.5    PA  0.955154  0.383228 -0.264669  0.253244
# 16408           138    3.5    NV  0.776043 -0.923788  0.999996  0.875417
# 16416            20    4.5    ON -0.674123  0.313096 -0.644192  0.790832
# 16569           106    3.5    OH  0.529548 -0.390103 -0.998981 -0.290202
# 16826           100    3.5    AZ  0.585226  0.999999  0.991599 -0.999992
# 17024           164    3.5    ON -0.155171 -0.992744 -0.865032 -0.487235
# 17260             7    4.5    QC  0.283011  0.350928 -0.606784  0.038083
# 17286           580    4.0    NV -0.999088  0.998109 -0.999906  0.493218
# 17308            22    4.0    PA -0.837927  0.051263 -0.014020  0.837218
# 17461           345    3.5    AZ  0.998564 -0.336062  0.539333 -0.991916
# 17750           147    4.0    ON  0.515070  0.999987  0.969445 -0.999986
# 17887            72    4.0    AZ -0.995352 -0.999843 -0.999865 -0.999889
# 17917            24    4.0    ON -0.603150  0.459422  0.836890 -0.048788
# 17924             5    4.0    QC  0.614996  0.692398 -0.546457 -0.803691
# 17948            11    4.5    WI -0.013212 -0.698319 -0.352034 -0.123684
# 17959            17    3.0    ON  0.233225 -0.655102  0.215919 -0.294175
# 18195            72    3.5    ON  0.891117  0.985159  0.999822  0.252858
# 18415           461    4.5    NV  0.999997 -0.999998 -0.580393 -0.999999
# 18490            57    4.0    OH -0.009385 -0.408027  0.252074 -0.999932
# 18595            20    4.0    AZ -0.019300 -0.269363 -0.204487  0.884714
# 18748            18    4.0    QC -0.938001  0.970763 -0.553684  0.714172
# 18863            23    4.0    QC  0.714148 -0.968784 -0.326398 -0.999120
# 18991            30    4.0    AB -0.312718  0.448182 -0.485707 -0.152123
# 19016           342    4.0    AZ -0.999999  0.999996 -0.233257  1.000000
#
#               4
# 2     -0.999999
# 73     0.999999
# 80     0.725683
# 185    0.983104
# 343   -0.999998
# 346    0.999987
# 444    0.999967
# 507    0.999999
# 524    0.994082
# 577    0.213198
# 706   -0.999998
# 766   -0.818139
# 1037   0.999995
# 1057  -0.019236
# 1130   0.047926
# 1236  -0.990062
# 1308   0.150422
# 1309   0.663649
# 1564   0.999976
# 1637   0.999999
# 1890  -0.999386
# 1905   0.977808
# 1916  -0.993163
# 1980   0.465308
# 1994   0.995344
# 2043   0.990680
# 2078  -0.924225
# 2229   0.986131
# 2261   0.369499
# 2347  -0.999998
# ...         ...
# 15354  0.998085
# 15396  0.892573
# 15715  0.726372
# 15832 -0.999690
# 16257 -0.617392
# 16277 -0.999999
# 16345 -0.992672
# 16408 -0.636122
# 16416  0.979241
# 16569  0.543690
# 16826 -0.999993
# 17024  0.816577
# 17260  0.878618
# 17286 -0.421883
# 17308 -0.509977
# 17461 -0.997968
# 17750  0.999996
# 17887  0.999646
# 17917  0.482363
# 17924 -0.338241
# 17948 -0.819993
# 17959 -0.877644
# 18195 -0.751651
# 18415  0.999920
# 18490  0.455995
# 18595  0.998055
# 18748  0.894291
# 18863  0.470760
# 18991 -0.478696
# 19016 -1.000000
#
# [180 rows x 19 columns]

# %% [markdown]
# ### Testing (Passing train)

# %%
bid
# Out:
# 12

# %%
chipotle = bus_values[bid]

# %%
chipotle
# Out:
# array([ 0.99997985, -1.        ,  0.78260916,  0.30094504,  0.99999946],
#       dtype=float32)

# %%
japaneselover = user_values[uid]

# %%
bus_values
# Out:
# array([[ 0.9999991 ,  0.9396781 ,  0.999999  ,  0.99999636,  0.42162743],
#        [-0.84611416, -0.9835101 ,  0.9993398 , -0.99999446, -0.99875456],
#        [ 0.99145293,  0.9980312 ,  0.8205256 , -0.99614197, -0.72551084],
#        ...,
#        [ 0.82006025, -0.57698023, -0.5382508 ,  0.7410189 , -0.57418895],
#        [-0.9881709 ,  0.9808874 , -0.7451318 , -0.9312196 ,  0.18285851],
#        [ 0.8986607 , -0.506382  ,  0.33877787, -0.63493055, -0.65729547]],
#       dtype=float32)

# %%
np.square(bus_values - japaneselover[None,:]).sum(1).argsort()
# Out:
# array([ 8157, 11393,  1223, ...,  1690,  3838,  1927])

# %%
np.square(bus_values - chipotle[None,:]).sum(1).argsort()
# Out:
# array([  12, 5142,   99, ...,  542, 4045, 1969])

# %%
def closest_businesses_to(business = None, user = None, df = None):
    if business is not None:
        target = bus_values[bus_fmap[business]]
    if user is not None:
        target = user_values[u_fmap[user]]
    if df is None:
        df = bus_values
    best_restaurants = np.square(df - target[None,:]).sum(1).argsort()
    return best_restaurants

# %%
midtown_japanese_restaurants = bus_values[:30,:]

# %%
closest_businesses_to(business = 'cHdJXLlKNWixBXpDwEGb_A')
# Out:
# array([  12, 5142,   99, ...,  542, 4045, 1969])

# %%
closest_businesses_to(user = 'ri7itn7-CdpsaPxTToK5cQ')
# Out:
# array([11129,  8000,  8024, ...,  2192,  2036,  2638])

# %%
closest_businesses_to(user = 'ri7itn7-CdpsaPxTToK5cQ', df = midtown_japanese_restaurants)
# Out:
# array([ 0,  6,  9,  4,  8, 24, 29, 17, 22, 27, 12, 26,  2, 14, 16, 23, 10,
#        20, 18,  3, 15, 28, 21, 11, 13,  7,  5,  1, 19, 25])

# %%
#df_user = pd.read_csv('data/user.csv', nrows = 100)

# df_review =  pd.read_csv('data/review.csv', usecols = ['business_id', 'user_id', 'stars'])
# user_cnts = df_review['user_id'].value_counts()
# top_users = user_cnts.loc[user_cnts>2].index
# df_review = df_review.loc[df_review['user_id'].isin(top_users)]
# df_review.to_csv('data/filtered_reviews.csv')

# %%
df_reviewSample = pd.read_csv('data/review_sample.csv')

# %%
df_reviewSample.head()
# Out:
#    Unnamed: 0             business_id  cool                 date  funny  \
# 0           0  ujmEBvifdJM6h6RLv4wQIg     0  2013-05-07 04:34:36      1
# 1          13  LUN6swQYa4xJKaM_UEUOEw     0  2018-04-27 20:25:26      0
# 2          48  OVTZNSkSfbl3gVB9XQIJfw     0  2010-01-08 04:28:23      0
# 3          62  SU56w479vUfFHsvmvQIf7A     6  2016-07-25 03:55:20      5
# 4          84  sk0stgY4NDJYOX1MbNJ3Pg     0  2018-09-25 03:58:48      0
#
#                 review_id  stars  \
# 0  Q1sbwvVQXV2734tPgoKj4Q    1.0
# 1  qlXw1JQ0UodW7qrmVgwCXw    4.0
# 2  u1jQX0KfnG3AHty4ifEpFA    4.0
# 3  E4LqIZ7DJd_R4ZHSNKx4RQ    4.0
# 4  SneRds-D0MCMWbIitd0AHg    1.0
#
#                                                 text  useful  \
# 0  Total bill for this horrible service? Over $8G...       6
# 1  Michael from Red Carpet VIP is amazing ! I rea...       0
# 2  notes: 1 visit, breakfast/lunch\noverall: Exce...       0
# 3  So good! They didn't make it to 5 stars due to...       7
# 4  At least the Pinks concession stand by Section...       0
#
#                   user_id
# 0  hG7b0MtEbXx5QzbzE6C_VA
# 1  bAhqAPoWaZYcyYi7bs024Q
# 2  8vIK6ndl8yzIdmSDnGp0tw
# 3  DoRCeCcJbrsM2BiAKj3trA
# 4  WThN-4czFfMs1vYhvaf_9A

# %%
df_reviewSample.count()
# Out:
# Unnamed: 0     668330
# business_id    668330
# cool           668330
# date           668330
# funny          668330
# review_id      668330
# stars          668330
# text           668330
# useful         668330
# user_id        668330
# dtype: int64

# %%
df_userSample = pd.read_csv('data/user_sample.csv')

# %%
df_userSample.head()
# Out:
#    Unnamed: 0  average_stars  compliment_cool  compliment_cute  \
# 0           0           4.03                1                0
# 1          13           3.95                4                0
# 2          48           3.66              822                9
# 3          62           4.44                0                0
# 4          84           3.22                0                0
#
#    compliment_funny  compliment_hot  compliment_list  compliment_more  \
# 0                 1               2                0                0
# 1                 4               0                0                1
# 2               822             480                5               46
# 3                 0               0                0                0
# 4                 0               0                0                0
#
#    compliment_note  compliment_photos         ...           cool  \
# 0                1                  0         ...             25
# 1                2                  1         ...             12
# 2              419                338         ...           9594
# 3                0                  0         ...              1
# 4                0                  0         ...              4
#
#                            elite  fans  \
# 0                 2015,2016,2017     5
# 1                            NaN     0
# 2  2013,2014,2015,2016,2017,2018   231
# 3                            NaN     2
# 4                            NaN     0
#
#                                              friends funny       name  \
# 0  c78V-rj8NQcQjOI8KP3UEA, alRMgPcngYSCJ5naFRBz5g...    17     Rashmi
# 1  _5p_nO7OczVP7czj_7T-RA, vux89VHowK-AlTpw_0J-wQ...    17      Emily
# 2  SxSeTYznS0YKSISgs5hj_Q, VtnCudEFLBjnxblLUAPYhA...  6997     Regina
# 3  xbcwzWSFu_OaYVPHrEV4IA, 1vv8nEe5Sxj1EVwKF6vbrA...     3    Lindsay
# 4  ve7sBZHI7y6buFY3KzQ9sA, UAzP14mLa8GkWzVUMoL5hg...     5  Priscilla
#
#   review_count  useful                 user_id        yelping_since
# 0           95      84  l6BmjZMeQD3rDxWUbiAiow  2013-10-08 23:11:33
# 1           22      31  US0VOSMFs9U0Nkl5Vx1EzA  2010-01-23 04:55:04
# 2         1053   11769  d7D4dYzF6THtOx9imf-wPw  2008-12-05 07:16:22
# 3           16       9  Z_ZkQgFtL2skSyZ9_9NUaQ  2015-10-26 01:06:15
# 4           16      34  on3cA28Qu-Eh50IuS2iq6w  2013-07-25 02:48:09
#
# [5 rows x 23 columns]

# %%
def find_ftres_with_nan(df):
    all_nan = df.columns[df.isnull().all()].tolist()
    some_nan = df.columns[df.isnull().any()].tolist()
    print("All NaN Features: ", len(all_nan), all_nan, "Some NaN Features: ", len(some_nan), some_nan)
    return all_nan, some_nan

# %%
df_businessSample = pd.read_csv('data/business_sample.csv',encoding = "ISO-8859-1",index_col=0)
all_nan, some_nan = find_ftres_with_nan(business)
# Out:
# All NaN Features:  0 [] Some NaN Features:  33 ['address', 'attributes', 'average_stars', 'business_id', 'categories', 'city', 'compliment_cool', 'compliment_cute', 'compliment_funny', 'compliment_hot', 'compliment_list', 'compliment_more', 'compliment_note', 'compliment_photos', 'compliment_plain', 'compliment_profile', 'compliment_writer', 'cool', 'elite', 'fans', 'friends', 'funny', 'hours', 'is_open', 'latitude', 'longitude', 'name', 'postal_code', 'stars', 'state', 'useful', 'user_id', 'yelping_since']

# %%
# Number of businesses that have both "food" and "restaurant" in their category:

# create a mask for restaurants
mask_restaurants = df_businessSample['categories'].str.contains('Restaurants')

# create a mask for food
mask_food = df_businessSample['categories'].str.contains('Food')

# apply both masks
restaurants_and_food = df_businessSample[mask_restaurants & mask_food]

# number of businesses that have food and restaurant in their category
restaurants_and_food['categories'].count()
# Out:
# 2141

# %%
df_reviewSample.head()
# Out:
#                business_id  cool                 date  funny  \
# 0   ujmEBvifdJM6h6RLv4wQIg     0  2013-05-07 04:34:36      1
# 13  LUN6swQYa4xJKaM_UEUOEw     0  2018-04-27 20:25:26      0
# 48  OVTZNSkSfbl3gVB9XQIJfw     0  2010-01-08 04:28:23      0
# 62  SU56w479vUfFHsvmvQIf7A     6  2016-07-25 03:55:20      5
# 84  sk0stgY4NDJYOX1MbNJ3Pg     0  2018-09-25 03:58:48      0
#
#                  review_id  stars  \
# 0   Q1sbwvVQXV2734tPgoKj4Q    1.0
# 13  qlXw1JQ0UodW7qrmVgwCXw    4.0
# 48  u1jQX0KfnG3AHty4ifEpFA    4.0
# 62  E4LqIZ7DJd_R4ZHSNKx4RQ    4.0
# 84  SneRds-D0MCMWbIitd0AHg    1.0
#
#                                                  text  useful  \
# 0   Total bill for this horrible service? Over $8G...       6
# 13  Michael from Red Carpet VIP is amazing ! I rea...       0
# 48  notes: 1 visit, breakfast/lunch\noverall: Exce...       0
# 62  So good! They didn't make it to 5 stars due to...       7
# 84  At least the Pinks concession stand by Section...       0
#
#                    user_id
# 0   hG7b0MtEbXx5QzbzE6C_VA
# 13  bAhqAPoWaZYcyYi7bs024Q
# 48  8vIK6ndl8yzIdmSDnGp0tw
# 62  DoRCeCcJbrsM2BiAKj3trA
# 84  WThN-4czFfMs1vYhvaf_9A

# %%
df_userSample.head()
# Out:
#    Unnamed: 0  average_stars  compliment_cool  compliment_cute  \
# 0           0           4.03                1                0
# 1          13           3.95                4                0
# 2          48           3.66              822                9
# 3          62           4.44                0                0
# 4          84           3.22                0                0
#
#    compliment_funny  compliment_hot  compliment_list  compliment_more  \
# 0                 1               2                0                0
# 1                 4               0                0                1
# 2               822             480                5               46
# 3                 0               0                0                0
# 4                 0               0                0                0
#
#    compliment_note  compliment_photos         ...           cool  \
# 0                1                  0         ...             25
# 1                2                  1         ...             12
# 2              419                338         ...           9594
# 3                0                  0         ...              1
# 4                0                  0         ...              4
#
#                            elite  fans  \
# 0                 2015,2016,2017     5
# 1                            NaN     0
# 2  2013,2014,2015,2016,2017,2018   231
# 3                            NaN     2
# 4                            NaN     0
#
#                                              friends funny       name  \
# 0  c78V-rj8NQcQjOI8KP3UEA, alRMgPcngYSCJ5naFRBz5g...    17     Rashmi
# 1  _5p_nO7OczVP7czj_7T-RA, vux89VHowK-AlTpw_0J-wQ...    17      Emily
# 2  SxSeTYznS0YKSISgs5hj_Q, VtnCudEFLBjnxblLUAPYhA...  6997     Regina
# 3  xbcwzWSFu_OaYVPHrEV4IA, 1vv8nEe5Sxj1EVwKF6vbrA...     3    Lindsay
# 4  ve7sBZHI7y6buFY3KzQ9sA, UAzP14mLa8GkWzVUMoL5hg...     5  Priscilla
#
#   review_count  useful                 user_id        yelping_since
# 0           95      84  l6BmjZMeQD3rDxWUbiAiow  2013-10-08 23:11:33
# 1           22      31  US0VOSMFs9U0Nkl5Vx1EzA  2010-01-23 04:55:04
# 2         1053   11769  d7D4dYzF6THtOx9imf-wPw  2008-12-05 07:16:22
# 3           16       9  Z_ZkQgFtL2skSyZ9_9NUaQ  2015-10-26 01:06:15
# 4           16      34  on3cA28Qu-Eh50IuS2iq6w  2013-07-25 02:48:09
#
# [5 rows x 23 columns]

# %%
#task 1
def get_restaurants(keyword):
    return restaurants_df.loc[restaurants_df['categories'].str.contains(keyword)]

# %%
get_restaurants('Japanese')
# Out:
#                                            address  \
# 1638819         4215 Spring Mountain Rd, Ste B106A
# 1639220                          300 Borough Drive
# 1645072                  5209 Boulevard DÃÂ©carie
# 1648686                       1101 Rutherford Road
# 1654446                             5904 Bryant St
# 1661360                 7510 Pineville Matthews Rd
# 1677832                          2900 Markham Road
# 1684215                       417 Rue Saint-Pierre
# 1684610                 7780 S Jones Blvd, Ste 103
# 1693914                            300 John Street
# 1695230                           3900 Paradise Rd
# 1698370                          1619 State Rt 303
# 1699151                 3555 S Durango Dr, Ste 101
# 1709154               5355 Ballantyne Commons Pkwy
# 1729829               8321 Kennedy Road, Unit 1065
# 1735568           4976 Premium Outlet Way, Ste 423
# 1745973  3049 S Las Vegas Blvd, Ste 20, Key Center
# 1748429              21-25 Heritage Meadows Way SE
# 1751232                        2197 Queen Street E
# 1755376            280 W Beaver Creek Road, Unit38
# 1769124                            500 Liberty Ave
# 1770430                           105 Cross Avenue
# 1772906                        2501 W Happy Valley
# 1774935                4750 Yonge Street, Unit 118
# 1778072                           3103 Kingston Rd
# 1780944                         8500 Warden Avenue
# 1785056    505 Highway 7 E, Unit 15, Commerce Gate
# 1803857                     3621 Hwy 7 E, Unit 105
# 1805134                              320 Atwood St
# 1813139           4545 Spring Mountain Rd, Ste 101
# 1819254                           4734 Liberty Ave
# 1824894                         467 Queen Street W
# 1828934             1910 Village Center Cir, Ste 9
# 1829216                9555 Yonge Street, Suite 12
#
#                                                 attributes  average_stars  \
# 1638819                                                NaN            NaN
# 1639220  {'BusinessParking': "{'garage': False, 'street...            NaN
# 1645072  {'WheelchairAccessible': 'None', 'BusinessPark...            NaN
# 1648686  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...            NaN
# 1654446  {'BusinessParking': "{'garage': False, 'street...            NaN
# 1661360  {'GoodForMeal': "{'dessert': False, 'latenight...            NaN
# 1677832  {'RestaurantsReservations': 'True', 'Restauran...            NaN
# 1684215  {'GoodForMeal': "{'dessert': False, 'latenight...            NaN
# 1684610  {'HasTV': 'False', 'RestaurantsReservations': ...            NaN
# 1693914  {'RestaurantsReservations': 'False', 'Restaura...            NaN
# 1695230  {'RestaurantsPriceRange2': '2', 'GoodForMeal':...            NaN
# 1698370  {'BikeParking': 'False', 'BusinessParking': "{...            NaN
# 1699151  {'RestaurantsAttire': "u'casual'", 'Restaurant...            NaN
# 1709154  {'HasTV': 'True', 'NoiseLevel': "u'average'", ...            NaN
# 1729829  {'RestaurantsTakeOut': 'True', 'RestaurantsPri...            NaN
# 1735568  {'RestaurantsAttire': "u'casual'", 'NoiseLevel...            NaN
# 1745973  {'BusinessParking': "{'garage': False, 'street...            NaN
# 1748429  {'RestaurantsTakeOut': 'False', 'RestaurantsRe...            NaN
# 1751232  {'RestaurantsTakeOut': 'True', 'RestaurantsPri...            NaN
# 1755376  {'GoodForKids': 'True', 'BikeParking': 'False'...            NaN
# 1769124  {'BusinessAcceptsCreditCards': 'True', 'Outdoo...            NaN
# 1770430  {'Caters': 'False', 'NoiseLevel': "u'loud'", '...            NaN
# 1772906  {'Caters': 'False', 'RestaurantsAttire': "'cas...            NaN
# 1774935  {'GoodForMeal': "{'dessert': False, 'latenight...            NaN
# 1778072  {'RestaurantsReservations': 'True', 'Restauran...            NaN
# 1780944  {'Ambience': "{'romantic': False, 'intimate': ...            NaN
# 1785056  {'DogsAllowed': 'True', 'RestaurantsPriceRange...            NaN
# 1803857  {'RestaurantsPriceRange2': '2', 'RestaurantsTa...            NaN
# 1805134  {'RestaurantsAttire': "u'casual'", 'Alcohol': ...            NaN
# 1813139  {'GoodForMeal': "{'dessert': False, 'latenight...            NaN
# 1819254  {'RestaurantsPriceRange2': '1', 'BusinessParki...            NaN
# 1824894  {'WiFi': "u'no'", 'BusinessParking': "{'garage...            NaN
# 1828934  {'WheelchairAccessible': 'True', 'RestaurantsT...            NaN
# 1829216  {'BikeParking': 'True', 'WiFi': "u'no'", 'Rest...            NaN
#
#                     business_id  \
# 1638819  bZs7FJ7fHIJxVecfp1qvug
# 1639220  a7mTbEi2N8Zd-r-8jlReww
# 1645072  5dzXrZr7MyTB92_MSqV3Lw
# 1648686  QIn3nMX3ywY8a2bCpyQcRA
# 1654446  GDXftPS1_fTJUtZkaEUDhA
# 1661360  19fdSca3MUoaGFNX2BrjTQ
# 1677832  fB-v-caPf0o3eUkp_2ua2Q
# 1684215  OSXpi4u9RZfWq1FZt5qG0w
# 1684610  eR7Iw_X54m3YLWkXp9y35Q
# 1693914  lu7vtrp_bE9PnxWfA8g4Pg
# 1695230  BcW7Z9lPmOB_8eS2lEuOqQ
# 1698370  CmIEkQZ87j1IGm9qWYqUdQ
# 1699151  bw7LEtZ5ozq8qOBA6FowYA
# 1709154  YzTafk0tQ-nAu1oICuuNFw
# 1729829  ZDPlCSHN2hdJSFVXFkaL7w
# 1735568  F7vD6BGJQ3nDdzlHTd_FIQ
# 1745973  2Xc6cpbFM6bqKkgz6bV9kQ
# 1748429  Qmu-DshGuoW1usHRIe7Y5w
# 1751232  YhLrPdDWKd26l-fIGewO1w
# 1755376  nFcS1gSkaAPSJB8jXZXlOw
# 1769124  rreIYrzI9U052p7nN_qogA
# 1770430  Y-MA4VmgoY2A3Jfasxpn1w
# 1772906  qL7oHKdDd4eM2NIE4SFYAg
# 1774935  pPgyuGtcNIBRfrPFu3Vceg
# 1778072  s5IlpMxrXEciJ-aVTjDryg
# 1780944  Vji_YCoJBoDTPkKy_Dmq7g
# 1785056  JpyHiBZtQel1b0OuvRz_pw
# 1803857  uwn8sfd0dLd1Vpn_E9zkmw
# 1805134  sH3zUEyNXNYzuaU9UomKqA
# 1813139  wZkjm9TGa7nXLYHxhIRO5w
# 1819254  F0-xC1-8aVxF-VdAcdouhA
# 1824894  bsFZnc2mYyGy5cFf5EWTWg
# 1828934  y-ZZe1dz8AMjiAwNVo3h_A
# 1829216  4ORWiWpjlb3Z76dPe3vYAQ
#
#                                                 categories           city  \
# 1638819  Ramen, Restaurants, Japanese, Tapas/Small Plat...      Las Vegas
# 1639220  Japanese, Korean, Restaurants, Barbeque, Fast ...        Toronto
# 1645072        Hawaiian, Restaurants, Japanese, Poke, Food    MontrÃÂ©al
# 1648686  Food, Japanese, Restaurants, Seafood Markets, ...      Thornhill
# 1654446  Restaurants, Juice Bars & Smoothies, Food, Jap...     Pittsburgh
# 1661360      Food, Japanese, Restaurants, Sushi Bars, Poke      Charlotte
# 1677832  Restaurants, Food, Seafood Markets, Specialty ...        Toronto
# 1684215   Coffee & Tea, Restaurants, Japanese, Cafes, Food    MontrÃÂ©al
# 1684610  Hawaiian, Specialty Food, Japanese, Ethnic Foo...      Las Vegas
# 1693914       Restaurants, Fast Food, Food Court, Japanese      Thornhill
# 1695230  Sushi Bars, Japanese, Steakhouses, Food, Resta...      Las Vegas
# 1698370  Sushi Bars, Japanese, Restaurants, Food, Steak...    Streetsboro
# 1699151          Japanese, Restaurants, Coffee & Tea, Food      Las Vegas
# 1709154   Restaurants, Sushi Bars, Live/Raw Food, Japanese      Charlotte
# 1729829              Food, Desserts, Japanese, Restaurants        Markham
# 1735568  Chinese, Japanese, Restaurants, Asian Fusion, ...       Chandler
# 1745973  Ethnic Food, Japanese, Restaurants, Sushi Bars...      Las Vegas
# 1748429          Asian Fusion, Japanese, Restaurants, Food        Calgary
# 1751232  Restaurants, Japanese, Ethnic Food, Specialty ...        Toronto
# 1755376  Canadian (New), Seafood, Restaurants, Live/Raw...  Richmond Hill
# 1769124  Thai, Poke, Japanese, Food, Restaurants, Sushi...     Pittsburgh
# 1770430  Seafood, Restaurants, Food, Barbeque, Japanese...       Oakville
# 1772906  Restaurants, Sushi Bars, Food, Specialty Food,...        Phoenix
# 1774935  Japanese, Restaurants, Poke, Hawaiian, Food, S...        Toronto
# 1778072               Chinese, Food, Japanese, Restaurants    Scarborough
# 1780944  Sushi Bars, Specialty Food, Restaurants, Food,...        Markham
# 1785056  Food, Restaurants, Ice Cream & Frozen Yogurt, ...        Markham
# 1803857       Cafes, Restaurants, Japanese, Food, Desserts        Markham
# 1805134               Japanese, Restaurants, Food, Burmese     Pittsburgh
# 1813139  Restaurants, Fast Food, Food, Poke, Japanese, ...      Las Vegas
# 1819254                   Restaurants, Japanese, Fast Food     Pittsburgh
# 1824894               Japanese, Restaurants, Buffets, Food        Toronto
# 1828934      Restaurants, Japanese, Food, Poke, Sushi Bars      Las Vegas
# 1829216       Restaurants, Japanese, Food, Desserts, Ramen  Richmond Hill
#
#          compliment_cool  compliment_cute  compliment_funny  compliment_hot  \
# 1638819              NaN              NaN               NaN             NaN
# 1639220              NaN              NaN               NaN             NaN
# 1645072              NaN              NaN               NaN             NaN
# 1648686              NaN              NaN               NaN             NaN
# 1654446              NaN              NaN               NaN             NaN
# 1661360              NaN              NaN               NaN             NaN
# 1677832              NaN              NaN               NaN             NaN
# 1684215              NaN              NaN               NaN             NaN
# 1684610              NaN              NaN               NaN             NaN
# 1693914              NaN              NaN               NaN             NaN
# 1695230              NaN              NaN               NaN             NaN
# 1698370              NaN              NaN               NaN             NaN
# 1699151              NaN              NaN               NaN             NaN
# 1709154              NaN              NaN               NaN             NaN
# 1729829              NaN              NaN               NaN             NaN
# 1735568              NaN              NaN               NaN             NaN
# 1745973              NaN              NaN               NaN             NaN
# 1748429              NaN              NaN               NaN             NaN
# 1751232              NaN              NaN               NaN             NaN
# 1755376              NaN              NaN               NaN             NaN
# 1769124              NaN              NaN               NaN             NaN
# 1770430              NaN              NaN               NaN             NaN
# 1772906              NaN              NaN               NaN             NaN
# 1774935              NaN              NaN               NaN             NaN
# 1778072              NaN              NaN               NaN             NaN
# 1780944              NaN              NaN               NaN             NaN
# 1785056              NaN              NaN               NaN             NaN
# 1803857              NaN              NaN               NaN             NaN
# 1805134              NaN              NaN               NaN             NaN
# 1813139              NaN              NaN               NaN             NaN
# 1819254              NaN              NaN               NaN             NaN
# 1824894              NaN              NaN               NaN             NaN
# 1828934              NaN              NaN               NaN             NaN
# 1829216              NaN              NaN               NaN             NaN
#
#              ...         latitude   longitude                         name  \
# 1638819      ...        36.125381 -115.195980                       Takopa
# 1639220      ...        43.775210  -79.257088        Koryo Korean Barbeque
# 1645072      ...        45.484839  -73.630869                 Le Poke Shop
# 1648686      ...        43.844860  -79.470476     Aroowha Sushi & Sake Bar
# 1654446      ...        40.475584  -79.919675                 Plate & Bowl
# 1661360      ...        35.088049  -80.845964            Umami PokÃÂ©Rito
# 1677832      ...        43.824650  -79.249080                    Sakana-Ya
# 1684215      ...        45.501661  -73.556605                       Flyjin
# 1684610      ...        36.047985 -115.224432             Tonkatsu Kiyoshi
# 1693914      ...        43.820492  -79.398466                 Banzai Sushi
# 1695230      ...        36.117758 -115.154519  Musashi Japanese Steakhouse
# 1698370      ...        41.240225  -81.337449    Toko Japanese Steak House
# 1699151      ...        36.125312 -115.279224               BeeGee Kitchen
# 1709154      ...        35.062725  -80.773882                    Sushi 101
# 1729829      ...        43.856041  -79.304458                  Millie Cafe
# 1735568      ...        33.281890 -111.973614                   Famous Wok
# 1745973      ...        36.131973 -115.163728            Rock n Roll Sushi
# 1748429      ...        50.987845 -114.044108                    Edo Japan
# 1751232      ...        43.670561  -79.296873  Bikkuri Japanese Restaurant
# 1755376      ...        43.843475  -79.387686                 Crab Harbour
# 1769124      ...        40.441237  -80.003478              Pittsburgh Poke
# 1770430      ...        43.454062  -79.686491                      Hibachi
# 1772906      ...        33.711217 -112.111434                    Bento Box
# 1774935      ...        43.759712  -79.410703                    Poke Eats
# 1778072      ...        43.727106  -79.229563  King's Garden Sushi and Wok
# 1780944      ...        43.854317  -79.335228                          EDO
# 1785056      ...        43.842468  -79.386914         Matcha Tea & Dessert
# 1803857      ...        43.853996  -79.337234             Patisserie Kirin
# 1805134      ...        40.439080  -79.955313                  Burma-Tokyo
# 1813139      ...        36.125636 -115.202487     California Sushi Burrito
# 1819254      ...        40.462448  -79.950226              Hibachi Express
# 1824894      ...        43.648377  -79.397401  Aji Sai Japanese Restaurant
# 1828934      ...        36.193225 -115.304038                 Tail and Fin
# 1829216      ...        43.859122  -79.434177               Sansotei Ramen
#
#          postal_code  review_count  stars  state  useful  user_id  \
# 1638819        89102            51    4.0     NV     NaN      NaN
# 1639220      M1P 4P5             7    3.5     ON     NaN      NaN
# 1645072      H3W 3C2             7    3.5     QC     NaN      NaN
# 1648686      L4J 0E2            90    4.0     ON     NaN      NaN
# 1654446        15206            22    4.0     PA     NaN      NaN
# 1661360        28226           115    4.5     NC     NaN      NaN
# 1677832      M1X 1E6             5    3.5     ON     NaN      NaN
# 1684215      H2Y 2M3            55    3.5     QC     NaN      NaN
# 1684610        89139           536    4.5     NV     NaN      NaN
# 1693914      L3T 5W4             6    4.5     ON     NaN      NaN
# 1695230        89169           683    4.0     NV     NaN      NaN
# 1698370        44241           102    4.0     OH     NaN      NaN
# 1699151        89147            32    3.5     NV     NaN      NaN
# 1709154        28277            97    3.5     NC     NaN      NaN
# 1729829      L3R 1J5            56    3.5     ON     NaN      NaN
# 1735568        85226            13    3.0     AZ     NaN      NaN
# 1745973        89109           112    3.0     NV     NaN      NaN
# 1748429          T2H             3    4.5     AB     NaN      NaN
# 1751232      M4E 1E5            40    2.5     ON     NaN      NaN
# 1755376      L4B 3B1            34    3.5     ON     NaN      NaN
# 1769124        15222           110    4.5     PA     NaN      NaN
# 1770430      L6J 2W6            31    3.5     ON     NaN      NaN
# 1772906        85085           135    3.5     AZ     NaN      NaN
# 1774935      M2N 6G5           103    4.0     ON     NaN      NaN
# 1778072      M1M 1P1            14    4.0     ON     NaN      NaN
# 1780944      L6G 1A5            12    3.5     ON     NaN      NaN
# 1785056      L3T 7T1           106    3.5     ON     NaN      NaN
# 1803857      L3R 0G6            47    4.0     ON     NaN      NaN
# 1805134        15213            37    4.0     PA     NaN      NaN
# 1813139        89102           137    4.5     NV     NaN      NaN
# 1819254        15224             4    4.5     PA     NaN      NaN
# 1824894          M5V           268    3.0     ON     NaN      NaN
# 1828934        89134           252    4.0     NV     NaN      NaN
# 1829216      L4C 9M5            61    4.0     ON     NaN      NaN
#
#          yelping_since
# 1638819            NaN
# 1639220            NaN
# 1645072            NaN
# 1648686            NaN
# 1654446            NaN
# 1661360            NaN
# 1677832            NaN
# 1684215            NaN
# 1684610            NaN
# 1693914            NaN
# 1695230            NaN
# 1698370            NaN
# 1699151            NaN
# 1709154            NaN
# 1729829            NaN
# 1735568            NaN
# 1745973            NaN
# 1748429            NaN
# 1751232            NaN
# 1755376            NaN
# 1769124            NaN
# 1770430            NaN
# 1772906            NaN
# 1774935            NaN
# 1778072            NaN
# 1780944            NaN
# 1785056            NaN
# 1803857            NaN
# 1805134            NaN
# 1813139            NaN
# 1819254            NaN
# 1824894            NaN
# 1828934            NaN
# 1829216            NaN
#
# [34 rows x 34 columns]

# %%
#task 2
def get_reviews_for(rest_id):
    return df_reviewSample.loc[df_reviewSample['business_id']==rest_id]

# %%
get_reviews_for('19fdSca3MUoaGFNX2BrjTQ')
# Out:
#                     business_id  cool                 date  funny  \
# 679434   19fdSca3MUoaGFNX2BrjTQ     0  2018-06-09 14:13:04      0
# 804232   19fdSca3MUoaGFNX2BrjTQ     0  2018-05-10 18:09:25      0
# 814150   19fdSca3MUoaGFNX2BrjTQ     1  2018-01-13 15:48:11      0
# 1000397  19fdSca3MUoaGFNX2BrjTQ     0  2018-08-30 01:30:04      0
# 1006603  19fdSca3MUoaGFNX2BrjTQ     0  2018-07-12 19:27:38      0
# 1201834  19fdSca3MUoaGFNX2BrjTQ     0  2018-01-30 19:27:07      0
# 1237683  19fdSca3MUoaGFNX2BrjTQ     0  2018-04-13 02:29:18      0
# 1308059  19fdSca3MUoaGFNX2BrjTQ     1  2018-01-06 21:55:16      0
#
#                       review_id  stars  \
# 679434   bDhAERq8suVl40xdk00zKQ    3.0
# 804232   TVzDDSiC6qQ2A2mjdwwV8w    5.0
# 814150   MWyp6vwBVbReDbJAYQUCpw    5.0
# 1000397  FgHiEau2OaB2sDkw4p15Dw    5.0
# 1006603  3HhyFikgJUW-SXWnp-dUtQ    5.0
# 1201834  tmT-drziC2y64jfXH3HTow    5.0
# 1237683  rWufRpJ9HWivqaa_5EW6uA    5.0
# 1308059  NOe4hvLsJqHHkwE8brfrPQ    5.0
#
#                                                       text  useful  \
# 679434   I was super excited to go here but was slightl...       0
# 804232   This is exactly what this area needs! You want...       0
# 814150   I happened upon this place randomly and just H...       1
# 1000397  Amazing! Quality ingredients, all sauces are h...       1
# 1006603  Incredible. I stopped in today and I'm blown a...       0
# 1201834  I just stopped in today as I was on my way bac...       0
# 1237683  Stopped in hereafter a workout session in the ...       1
# 1308059  Not one negative thing to say! Service was qui...       3
#
#                         user_id
# 679434   6aklT92xV0_duyUI9l84Pw
# 804232   96s7b2PBjmkzEeQTzmKp7w
# 814150   uBHRgjD2xy77JCVm7CwmOA
# 1000397  wlTd-6M1pkO7zs5CgopQOQ
# 1006603  oOB27OMd4k5oPTayEPClag
# 1201834  YYKuS5-8NGiAPNMwX9nO7g
# 1237683  7GIcGERUfVvOx_TNYomGcA
# 1308059  pz69IIgBrek4B__VV1-HIA

# %%
#task fun random crap:
#make word cloud for a user

# %%
#task 3
def get_recommendations_for(user_id, latlong or location):
    bids = closest_businesses_to(user = user_id)
    bnames = [bus_invmap[b] for b in bids]
    return restaurants_df.set_index('business_id').loc[bnames]

# %%
#dropna needs to occur way above

# %%
#task 3
def get_recommendations_for(user_id = None, bus_id = None):
    if user_id is not None:
        bids = closest_businesses_to(user = user_id)
    else:
        bids = closest_businesses_to(business = bus_id)
    bnames = [bus_invmap[b] for b in bids]
    return restaurants_df.set_index('business_id').loc[bnames]

# %%
get_recommendations_for(bus_id = 'a7mTbEi2N8Zd-r-8jlReww')
# Out:
# /Users/thomaslee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#                                   address  \
# business_id
# a7mTbEi2N8Zd-r-8jlReww  300 Borough Drive
# _NO1sGYVk4lIib9a2DCtdw                NaN
# Rmj0NYF_Id_2rZzocx-Vyw                NaN
# Oyo5CWthu2upxxaf69MfIg                NaN
# bFlP7uApDamdiVHwX8OwfA                NaN
# zcq94VmjgyQ7v3bW_xAfsw                NaN
# nSNNl7s0p3hSB3ZLPSVSlA                NaN
# ZKJcKRG6fQitU7q_Eq04hg                NaN
# IyoklPvMD14zdOxHlX_xHQ                NaN
# zWrwVNAvrtVAhcDRWJJMEw                NaN
# RBkzPjOduojmA3nvdBsnRg                NaN
# X__txEx12Sc97btJc4L_fA                NaN
# OszoMGV3waZNE0u4K0YgwQ                NaN
# 48u7-r6_wqvIHBcuzNR-Cw                NaN
# _72dMXdWbVAgwB-Bxwz-mw                NaN
# YESM3VH-O_j7LMpW8tPA3Q                NaN
# eQS4GqUh-D4Si-ERVa5IQw                NaN
# DZxE9J1G5t593ojY0qXkFg                NaN
# vPO6DqPOBL5faHKYFNrRfA                NaN
# ymn4YVFgXy_rLlnoatEqzQ                NaN
# 6EnpCPvBT-sO5iKM-SpZ1g                NaN
# pLgfzwwPEiq9leL1u7iNuw                NaN
# eY1WyHjXObOc-63nBv20Gg                NaN
# yEE8-vuc_-KFJpk6PY06qg                NaN
# 9zS4IkhwXrbp0uH0dTnrEg                NaN
# QSfFgtcIrFHMs3_TVXjCLA                NaN
# whsUOYXuIswjjvDglsTL7w                NaN
# tku3pYiZrQLCT12MXr-OHA                NaN
# PJZWfs8RSn4A5nvJ3Wzl1g                NaN
# WA4F_4f1YKONgep-YY0uuw                NaN
# ...                                   ...
# b_-CrqKnXinHPa5LWI2gbQ                NaN
# AvJgSdQ5ZetOFgaNfdZ32g                NaN
# STDooDA8ZDdRPOzAMa1f0Q                NaN
# 9l0QcFehRrxDZLy5_so_kg                NaN
# -000aQFeK6tqVLndf7xORg                NaN
# p6zSxr2nnRzJJ93LthQftg                NaN
# h7l3xt_CAaFMD63ZgdXXWw                NaN
# fFl7zlk8QnN2UOMIa38rcQ                NaN
# GEvolb_U74NXgfgdxrVtyQ                NaN
# IQgrWGRX6O0XvONGJtRTsw                NaN
# dC6erJ1htWZO9N-Z3BakZQ                NaN
# WICxQIYfM4dpIx16Tn5ofw                NaN
# zWB6hcE7Pxww0VoI2fYIWw                NaN
# ITZFaNBs54xradAO7o_QPA                NaN
# f0L6u85V1ergQUrk7nlNDw                NaN
# 0RNiVZcJwTIs-gdreHob1w                NaN
# SYGbbZlLk81_bOlBptbS7A                NaN
# yPSgeMxe7QL0mBeOlUwYgg                NaN
# UPh90LM8UMnVFQP6NGktrA                NaN
# 0p-3PlHw6FoWAs2ezJw3mA                NaN
# X4J2P7U2aWPE_Y7YJF4JOA                NaN
# RBAcL6hg2yoaTRv0kKUjPA                NaN
# kx9ncrovqxZrRXEKrR06QA                NaN
# HOarFvVeMrdrikfjf7-uGQ                NaN
# 9p0jhBSwTPXyUbaZe_1bTA                NaN
# PcW5yjx4rvc_vBrUc_fBSA                NaN
# 4wBzxxSdEXZ48EnY3XcOFQ                NaN
# aSB_HTwUzvN50-Rv9YiWSg                NaN
# _tpvRiE69BSU5IAcqcr5sw                NaN
# QEgfK_TKY8bwK-YzKDdkGw                NaN
#
#                                                                attributes  \
# business_id
# a7mTbEi2N8Zd-r-8jlReww  {'BusinessParking': "{'garage': False, 'street...
# _NO1sGYVk4lIib9a2DCtdw                                                NaN
# Rmj0NYF_Id_2rZzocx-Vyw                                                NaN
# Oyo5CWthu2upxxaf69MfIg                                                NaN
# bFlP7uApDamdiVHwX8OwfA                                                NaN
# zcq94VmjgyQ7v3bW_xAfsw                                                NaN
# nSNNl7s0p3hSB3ZLPSVSlA                                                NaN
# ZKJcKRG6fQitU7q_Eq04hg                                                NaN
# IyoklPvMD14zdOxHlX_xHQ                                                NaN
# zWrwVNAvrtVAhcDRWJJMEw                                                NaN
# RBkzPjOduojmA3nvdBsnRg                                                NaN
# X__txEx12Sc97btJc4L_fA                                                NaN
# OszoMGV3waZNE0u4K0YgwQ                                                NaN
# 48u7-r6_wqvIHBcuzNR-Cw                                                NaN
# _72dMXdWbVAgwB-Bxwz-mw                                                NaN
# YESM3VH-O_j7LMpW8tPA3Q                                                NaN
# eQS4GqUh-D4Si-ERVa5IQw                                                NaN
# DZxE9J1G5t593ojY0qXkFg                                                NaN
# vPO6DqPOBL5faHKYFNrRfA                                                NaN
# ymn4YVFgXy_rLlnoatEqzQ                                                NaN
# 6EnpCPvBT-sO5iKM-SpZ1g                                                NaN
# pLgfzwwPEiq9leL1u7iNuw                                                NaN
# eY1WyHjXObOc-63nBv20Gg                                                NaN
# yEE8-vuc_-KFJpk6PY06qg                                                NaN
# 9zS4IkhwXrbp0uH0dTnrEg                                                NaN
# QSfFgtcIrFHMs3_TVXjCLA                                                NaN
# whsUOYXuIswjjvDglsTL7w                                                NaN
# tku3pYiZrQLCT12MXr-OHA                                                NaN
# PJZWfs8RSn4A5nvJ3Wzl1g                                                NaN
# WA4F_4f1YKONgep-YY0uuw                                                NaN
# ...                                                                   ...
# b_-CrqKnXinHPa5LWI2gbQ                                                NaN
# AvJgSdQ5ZetOFgaNfdZ32g                                                NaN
# STDooDA8ZDdRPOzAMa1f0Q                                                NaN
# 9l0QcFehRrxDZLy5_so_kg                                                NaN
# -000aQFeK6tqVLndf7xORg                                                NaN
# p6zSxr2nnRzJJ93LthQftg                                                NaN
# h7l3xt_CAaFMD63ZgdXXWw                                                NaN
# fFl7zlk8QnN2UOMIa38rcQ                                                NaN
# GEvolb_U74NXgfgdxrVtyQ                                                NaN
# IQgrWGRX6O0XvONGJtRTsw                                                NaN
# dC6erJ1htWZO9N-Z3BakZQ                                                NaN
# WICxQIYfM4dpIx16Tn5ofw                                                NaN
# zWB6hcE7Pxww0VoI2fYIWw                                                NaN
# ITZFaNBs54xradAO7o_QPA                                                NaN
# f0L6u85V1ergQUrk7nlNDw                                                NaN
# 0RNiVZcJwTIs-gdreHob1w                                                NaN
# SYGbbZlLk81_bOlBptbS7A                                                NaN
# yPSgeMxe7QL0mBeOlUwYgg                                                NaN
# UPh90LM8UMnVFQP6NGktrA                                                NaN
# 0p-3PlHw6FoWAs2ezJw3mA                                                NaN
# X4J2P7U2aWPE_Y7YJF4JOA                                                NaN
# RBAcL6hg2yoaTRv0kKUjPA                                                NaN
# kx9ncrovqxZrRXEKrR06QA                                                NaN
# HOarFvVeMrdrikfjf7-uGQ                                                NaN
# 9p0jhBSwTPXyUbaZe_1bTA                                                NaN
# PcW5yjx4rvc_vBrUc_fBSA                                                NaN
# 4wBzxxSdEXZ48EnY3XcOFQ                                                NaN
# aSB_HTwUzvN50-Rv9YiWSg                                                NaN
# _tpvRiE69BSU5IAcqcr5sw                                                NaN
# QEgfK_TKY8bwK-YzKDdkGw                                                NaN
#
#                         average_stars  \
# business_id
# a7mTbEi2N8Zd-r-8jlReww            NaN
# _NO1sGYVk4lIib9a2DCtdw            NaN
# Rmj0NYF_Id_2rZzocx-Vyw            NaN
# Oyo5CWthu2upxxaf69MfIg            NaN
# bFlP7uApDamdiVHwX8OwfA            NaN
# zcq94VmjgyQ7v3bW_xAfsw            NaN
# nSNNl7s0p3hSB3ZLPSVSlA            NaN
# ZKJcKRG6fQitU7q_Eq04hg            NaN
# IyoklPvMD14zdOxHlX_xHQ            NaN
# zWrwVNAvrtVAhcDRWJJMEw            NaN
# RBkzPjOduojmA3nvdBsnRg            NaN
# X__txEx12Sc97btJc4L_fA            NaN
# OszoMGV3waZNE0u4K0YgwQ            NaN
# 48u7-r6_wqvIHBcuzNR-Cw            NaN
# _72dMXdWbVAgwB-Bxwz-mw            NaN
# YESM3VH-O_j7LMpW8tPA3Q            NaN
# eQS4GqUh-D4Si-ERVa5IQw            NaN
# DZxE9J1G5t593ojY0qXkFg            NaN
# vPO6DqPOBL5faHKYFNrRfA            NaN
# ymn4YVFgXy_rLlnoatEqzQ            NaN
# 6EnpCPvBT-sO5iKM-SpZ1g            NaN
# pLgfzwwPEiq9leL1u7iNuw            NaN
# eY1WyHjXObOc-63nBv20Gg            NaN
# yEE8-vuc_-KFJpk6PY06qg            NaN
# 9zS4IkhwXrbp0uH0dTnrEg            NaN
# QSfFgtcIrFHMs3_TVXjCLA            NaN
# whsUOYXuIswjjvDglsTL7w            NaN
# tku3pYiZrQLCT12MXr-OHA            NaN
# PJZWfs8RSn4A5nvJ3Wzl1g            NaN
# WA4F_4f1YKONgep-YY0uuw            NaN
# ...                               ...
# b_-CrqKnXinHPa5LWI2gbQ            NaN
# AvJgSdQ5ZetOFgaNfdZ32g            NaN
# STDooDA8ZDdRPOzAMa1f0Q            NaN
# 9l0QcFehRrxDZLy5_so_kg            NaN
# -000aQFeK6tqVLndf7xORg            NaN
# p6zSxr2nnRzJJ93LthQftg            NaN
# h7l3xt_CAaFMD63ZgdXXWw            NaN
# fFl7zlk8QnN2UOMIa38rcQ            NaN
# GEvolb_U74NXgfgdxrVtyQ            NaN
# IQgrWGRX6O0XvONGJtRTsw            NaN
# dC6erJ1htWZO9N-Z3BakZQ            NaN
# WICxQIYfM4dpIx16Tn5ofw            NaN
# zWB6hcE7Pxww0VoI2fYIWw            NaN
# ITZFaNBs54xradAO7o_QPA            NaN
# f0L6u85V1ergQUrk7nlNDw            NaN
# 0RNiVZcJwTIs-gdreHob1w            NaN
# SYGbbZlLk81_bOlBptbS7A            NaN
# yPSgeMxe7QL0mBeOlUwYgg            NaN
# UPh90LM8UMnVFQP6NGktrA            NaN
# 0p-3PlHw6FoWAs2ezJw3mA            NaN
# X4J2P7U2aWPE_Y7YJF4JOA            NaN
# RBAcL6hg2yoaTRv0kKUjPA            NaN
# kx9ncrovqxZrRXEKrR06QA            NaN
# HOarFvVeMrdrikfjf7-uGQ            NaN
# 9p0jhBSwTPXyUbaZe_1bTA            NaN
# PcW5yjx4rvc_vBrUc_fBSA            NaN
# 4wBzxxSdEXZ48EnY3XcOFQ            NaN
# aSB_HTwUzvN50-Rv9YiWSg            NaN
# _tpvRiE69BSU5IAcqcr5sw            NaN
# QEgfK_TKY8bwK-YzKDdkGw            NaN
#
#                                                                categories  \
# business_id
# a7mTbEi2N8Zd-r-8jlReww  Japanese, Korean, Restaurants, Barbeque, Fast ...
# _NO1sGYVk4lIib9a2DCtdw                                                NaN
# Rmj0NYF_Id_2rZzocx-Vyw                                                NaN
# Oyo5CWthu2upxxaf69MfIg                                                NaN
# bFlP7uApDamdiVHwX8OwfA                                                NaN
# zcq94VmjgyQ7v3bW_xAfsw                                                NaN
# nSNNl7s0p3hSB3ZLPSVSlA                                                NaN
# ZKJcKRG6fQitU7q_Eq04hg                                                NaN
# IyoklPvMD14zdOxHlX_xHQ                                                NaN
# zWrwVNAvrtVAhcDRWJJMEw                                                NaN
# RBkzPjOduojmA3nvdBsnRg                                                NaN
# X__txEx12Sc97btJc4L_fA                                                NaN
# OszoMGV3waZNE0u4K0YgwQ                                                NaN
# 48u7-r6_wqvIHBcuzNR-Cw                                                NaN
# _72dMXdWbVAgwB-Bxwz-mw                                                NaN
# YESM3VH-O_j7LMpW8tPA3Q                                                NaN
# eQS4GqUh-D4Si-ERVa5IQw                                                NaN
# DZxE9J1G5t593ojY0qXkFg                                                NaN
# vPO6DqPOBL5faHKYFNrRfA                                                NaN
# ymn4YVFgXy_rLlnoatEqzQ                                                NaN
# 6EnpCPvBT-sO5iKM-SpZ1g                                                NaN
# pLgfzwwPEiq9leL1u7iNuw                                                NaN
# eY1WyHjXObOc-63nBv20Gg                                                NaN
# yEE8-vuc_-KFJpk6PY06qg                                                NaN
# 9zS4IkhwXrbp0uH0dTnrEg                                                NaN
# QSfFgtcIrFHMs3_TVXjCLA                                                NaN
# whsUOYXuIswjjvDglsTL7w                                                NaN
# tku3pYiZrQLCT12MXr-OHA                                                NaN
# PJZWfs8RSn4A5nvJ3Wzl1g                                                NaN
# WA4F_4f1YKONgep-YY0uuw                                                NaN
# ...                                                                   ...
# b_-CrqKnXinHPa5LWI2gbQ                                                NaN
# AvJgSdQ5ZetOFgaNfdZ32g                                                NaN
# STDooDA8ZDdRPOzAMa1f0Q                                                NaN
# 9l0QcFehRrxDZLy5_so_kg                                                NaN
# -000aQFeK6tqVLndf7xORg                                                NaN
# p6zSxr2nnRzJJ93LthQftg                                                NaN
# h7l3xt_CAaFMD63ZgdXXWw                                                NaN
# fFl7zlk8QnN2UOMIa38rcQ                                                NaN
# GEvolb_U74NXgfgdxrVtyQ                                                NaN
# IQgrWGRX6O0XvONGJtRTsw                                                NaN
# dC6erJ1htWZO9N-Z3BakZQ                                                NaN
# WICxQIYfM4dpIx16Tn5ofw                                                NaN
# zWB6hcE7Pxww0VoI2fYIWw                                                NaN
# ITZFaNBs54xradAO7o_QPA                                                NaN
# f0L6u85V1ergQUrk7nlNDw                                                NaN
# 0RNiVZcJwTIs-gdreHob1w                                                NaN
# SYGbbZlLk81_bOlBptbS7A                                                NaN
# yPSgeMxe7QL0mBeOlUwYgg                                                NaN
# UPh90LM8UMnVFQP6NGktrA                                                NaN
# 0p-3PlHw6FoWAs2ezJw3mA                                                NaN
# X4J2P7U2aWPE_Y7YJF4JOA                                                NaN
# RBAcL6hg2yoaTRv0kKUjPA                                                NaN
# kx9ncrovqxZrRXEKrR06QA                                                NaN
# HOarFvVeMrdrikfjf7-uGQ                                                NaN
# 9p0jhBSwTPXyUbaZe_1bTA                                                NaN
# PcW5yjx4rvc_vBrUc_fBSA                                                NaN
# 4wBzxxSdEXZ48EnY3XcOFQ                                                NaN
# aSB_HTwUzvN50-Rv9YiWSg                                                NaN
# _tpvRiE69BSU5IAcqcr5sw                                                NaN
# QEgfK_TKY8bwK-YzKDdkGw                                                NaN
#
#                            city  compliment_cool  compliment_cute  \
# business_id
# a7mTbEi2N8Zd-r-8jlReww  Toronto              NaN              NaN
# _NO1sGYVk4lIib9a2DCtdw      NaN              NaN              NaN
# Rmj0NYF_Id_2rZzocx-Vyw      NaN              NaN              NaN
# Oyo5CWthu2upxxaf69MfIg      NaN              NaN              NaN
# bFlP7uApDamdiVHwX8OwfA      NaN              NaN              NaN
# zcq94VmjgyQ7v3bW_xAfsw      NaN              NaN              NaN
# nSNNl7s0p3hSB3ZLPSVSlA      NaN              NaN              NaN
# ZKJcKRG6fQitU7q_Eq04hg      NaN              NaN              NaN
# IyoklPvMD14zdOxHlX_xHQ      NaN              NaN              NaN
# zWrwVNAvrtVAhcDRWJJMEw      NaN              NaN              NaN
# RBkzPjOduojmA3nvdBsnRg      NaN              NaN              NaN
# X__txEx12Sc97btJc4L_fA      NaN              NaN              NaN
# OszoMGV3waZNE0u4K0YgwQ      NaN              NaN              NaN
# 48u7-r6_wqvIHBcuzNR-Cw      NaN              NaN              NaN
# _72dMXdWbVAgwB-Bxwz-mw      NaN              NaN              NaN
# YESM3VH-O_j7LMpW8tPA3Q      NaN              NaN              NaN
# eQS4GqUh-D4Si-ERVa5IQw      NaN              NaN              NaN
# DZxE9J1G5t593ojY0qXkFg      NaN              NaN              NaN
# vPO6DqPOBL5faHKYFNrRfA      NaN              NaN              NaN
# ymn4YVFgXy_rLlnoatEqzQ      NaN              NaN              NaN
# 6EnpCPvBT-sO5iKM-SpZ1g      NaN              NaN              NaN
# pLgfzwwPEiq9leL1u7iNuw      NaN              NaN              NaN
# eY1WyHjXObOc-63nBv20Gg      NaN              NaN              NaN
# yEE8-vuc_-KFJpk6PY06qg      NaN              NaN              NaN
# 9zS4IkhwXrbp0uH0dTnrEg      NaN              NaN              NaN
# QSfFgtcIrFHMs3_TVXjCLA      NaN              NaN              NaN
# whsUOYXuIswjjvDglsTL7w      NaN              NaN              NaN
# tku3pYiZrQLCT12MXr-OHA      NaN              NaN              NaN
# PJZWfs8RSn4A5nvJ3Wzl1g      NaN              NaN              NaN
# WA4F_4f1YKONgep-YY0uuw      NaN              NaN              NaN
# ...                         ...              ...              ...
# b_-CrqKnXinHPa5LWI2gbQ      NaN              NaN              NaN
# AvJgSdQ5ZetOFgaNfdZ32g      NaN              NaN              NaN
# STDooDA8ZDdRPOzAMa1f0Q      NaN              NaN              NaN
# 9l0QcFehRrxDZLy5_so_kg      NaN              NaN              NaN
# -000aQFeK6tqVLndf7xORg      NaN              NaN              NaN
# p6zSxr2nnRzJJ93LthQftg      NaN              NaN              NaN
# h7l3xt_CAaFMD63ZgdXXWw      NaN              NaN              NaN
# fFl7zlk8QnN2UOMIa38rcQ      NaN              NaN              NaN
# GEvolb_U74NXgfgdxrVtyQ      NaN              NaN              NaN
# IQgrWGRX6O0XvONGJtRTsw      NaN              NaN              NaN
# dC6erJ1htWZO9N-Z3BakZQ      NaN              NaN              NaN
# WICxQIYfM4dpIx16Tn5ofw      NaN              NaN              NaN
# zWB6hcE7Pxww0VoI2fYIWw      NaN              NaN              NaN
# ITZFaNBs54xradAO7o_QPA      NaN              NaN              NaN
# f0L6u85V1ergQUrk7nlNDw      NaN              NaN              NaN
# 0RNiVZcJwTIs-gdreHob1w      NaN              NaN              NaN
# SYGbbZlLk81_bOlBptbS7A      NaN              NaN              NaN
# yPSgeMxe7QL0mBeOlUwYgg      NaN              NaN              NaN
# UPh90LM8UMnVFQP6NGktrA      NaN              NaN              NaN
# 0p-3PlHw6FoWAs2ezJw3mA      NaN              NaN              NaN
# X4J2P7U2aWPE_Y7YJF4JOA      NaN              NaN              NaN
# RBAcL6hg2yoaTRv0kKUjPA      NaN              NaN              NaN
# kx9ncrovqxZrRXEKrR06QA      NaN              NaN              NaN
# HOarFvVeMrdrikfjf7-uGQ      NaN              NaN              NaN
# 9p0jhBSwTPXyUbaZe_1bTA      NaN              NaN              NaN
# PcW5yjx4rvc_vBrUc_fBSA      NaN              NaN              NaN
# 4wBzxxSdEXZ48EnY3XcOFQ      NaN              NaN              NaN
# aSB_HTwUzvN50-Rv9YiWSg      NaN              NaN              NaN
# _tpvRiE69BSU5IAcqcr5sw      NaN              NaN              NaN
# QEgfK_TKY8bwK-YzKDdkGw      NaN              NaN              NaN
#
#                         compliment_funny  compliment_hot  compliment_list  \
# business_id
# a7mTbEi2N8Zd-r-8jlReww               NaN             NaN              NaN
# _NO1sGYVk4lIib9a2DCtdw               NaN             NaN              NaN
# Rmj0NYF_Id_2rZzocx-Vyw               NaN             NaN              NaN
# Oyo5CWthu2upxxaf69MfIg               NaN             NaN              NaN
# bFlP7uApDamdiVHwX8OwfA               NaN             NaN              NaN
# zcq94VmjgyQ7v3bW_xAfsw               NaN             NaN              NaN
# nSNNl7s0p3hSB3ZLPSVSlA               NaN             NaN              NaN
# ZKJcKRG6fQitU7q_Eq04hg               NaN             NaN              NaN
# IyoklPvMD14zdOxHlX_xHQ               NaN             NaN              NaN
# zWrwVNAvrtVAhcDRWJJMEw               NaN             NaN              NaN
# RBkzPjOduojmA3nvdBsnRg               NaN             NaN              NaN
# X__txEx12Sc97btJc4L_fA               NaN             NaN              NaN
# OszoMGV3waZNE0u4K0YgwQ               NaN             NaN              NaN
# 48u7-r6_wqvIHBcuzNR-Cw               NaN             NaN              NaN
# _72dMXdWbVAgwB-Bxwz-mw               NaN             NaN              NaN
# YESM3VH-O_j7LMpW8tPA3Q               NaN             NaN              NaN
# eQS4GqUh-D4Si-ERVa5IQw               NaN             NaN              NaN
# DZxE9J1G5t593ojY0qXkFg               NaN             NaN              NaN
# vPO6DqPOBL5faHKYFNrRfA               NaN             NaN              NaN
# ymn4YVFgXy_rLlnoatEqzQ               NaN             NaN              NaN
# 6EnpCPvBT-sO5iKM-SpZ1g               NaN             NaN              NaN
# pLgfzwwPEiq9leL1u7iNuw               NaN             NaN              NaN
# eY1WyHjXObOc-63nBv20Gg               NaN             NaN              NaN
# yEE8-vuc_-KFJpk6PY06qg               NaN             NaN              NaN
# 9zS4IkhwXrbp0uH0dTnrEg               NaN             NaN              NaN
# QSfFgtcIrFHMs3_TVXjCLA               NaN             NaN              NaN
# whsUOYXuIswjjvDglsTL7w               NaN             NaN              NaN
# tku3pYiZrQLCT12MXr-OHA               NaN             NaN              NaN
# PJZWfs8RSn4A5nvJ3Wzl1g               NaN             NaN              NaN
# WA4F_4f1YKONgep-YY0uuw               NaN             NaN              NaN
# ...                                  ...             ...              ...
# b_-CrqKnXinHPa5LWI2gbQ               NaN             NaN              NaN
# AvJgSdQ5ZetOFgaNfdZ32g               NaN             NaN              NaN
# STDooDA8ZDdRPOzAMa1f0Q               NaN             NaN              NaN
# 9l0QcFehRrxDZLy5_so_kg               NaN             NaN              NaN
# -000aQFeK6tqVLndf7xORg               NaN             NaN              NaN
# p6zSxr2nnRzJJ93LthQftg               NaN             NaN              NaN
# h7l3xt_CAaFMD63ZgdXXWw               NaN             NaN              NaN
# fFl7zlk8QnN2UOMIa38rcQ               NaN             NaN              NaN
# GEvolb_U74NXgfgdxrVtyQ               NaN             NaN              NaN
# IQgrWGRX6O0XvONGJtRTsw               NaN             NaN              NaN
# dC6erJ1htWZO9N-Z3BakZQ               NaN             NaN              NaN
# WICxQIYfM4dpIx16Tn5ofw               NaN             NaN              NaN
# zWB6hcE7Pxww0VoI2fYIWw               NaN             NaN              NaN
# ITZFaNBs54xradAO7o_QPA               NaN             NaN              NaN
# f0L6u85V1ergQUrk7nlNDw               NaN             NaN              NaN
# 0RNiVZcJwTIs-gdreHob1w               NaN             NaN              NaN
# SYGbbZlLk81_bOlBptbS7A               NaN             NaN              NaN
# yPSgeMxe7QL0mBeOlUwYgg               NaN             NaN              NaN
# UPh90LM8UMnVFQP6NGktrA               NaN             NaN              NaN
# 0p-3PlHw6FoWAs2ezJw3mA               NaN             NaN              NaN
# X4J2P7U2aWPE_Y7YJF4JOA               NaN             NaN              NaN
# RBAcL6hg2yoaTRv0kKUjPA               NaN             NaN              NaN
# kx9ncrovqxZrRXEKrR06QA               NaN             NaN              NaN
# HOarFvVeMrdrikfjf7-uGQ               NaN             NaN              NaN
# 9p0jhBSwTPXyUbaZe_1bTA               NaN             NaN              NaN
# PcW5yjx4rvc_vBrUc_fBSA               NaN             NaN              NaN
# 4wBzxxSdEXZ48EnY3XcOFQ               NaN             NaN              NaN
# aSB_HTwUzvN50-Rv9YiWSg               NaN             NaN              NaN
# _tpvRiE69BSU5IAcqcr5sw               NaN             NaN              NaN
# QEgfK_TKY8bwK-YzKDdkGw               NaN             NaN              NaN
#
#                             ...        latitude  longitude  \
# business_id                 ...
# a7mTbEi2N8Zd-r-8jlReww      ...        43.77521 -79.257088
# _NO1sGYVk4lIib9a2DCtdw      ...             NaN        NaN
# Rmj0NYF_Id_2rZzocx-Vyw      ...             NaN        NaN
# Oyo5CWthu2upxxaf69MfIg      ...             NaN        NaN
# bFlP7uApDamdiVHwX8OwfA      ...             NaN        NaN
# zcq94VmjgyQ7v3bW_xAfsw      ...             NaN        NaN
# nSNNl7s0p3hSB3ZLPSVSlA      ...             NaN        NaN
# ZKJcKRG6fQitU7q_Eq04hg      ...             NaN        NaN
# IyoklPvMD14zdOxHlX_xHQ      ...             NaN        NaN
# zWrwVNAvrtVAhcDRWJJMEw      ...             NaN        NaN
# RBkzPjOduojmA3nvdBsnRg      ...             NaN        NaN
# X__txEx12Sc97btJc4L_fA      ...             NaN        NaN
# OszoMGV3waZNE0u4K0YgwQ      ...             NaN        NaN
# 48u7-r6_wqvIHBcuzNR-Cw      ...             NaN        NaN
# _72dMXdWbVAgwB-Bxwz-mw      ...             NaN        NaN
# YESM3VH-O_j7LMpW8tPA3Q      ...             NaN        NaN
# eQS4GqUh-D4Si-ERVa5IQw      ...             NaN        NaN
# DZxE9J1G5t593ojY0qXkFg      ...             NaN        NaN
# vPO6DqPOBL5faHKYFNrRfA      ...             NaN        NaN
# ymn4YVFgXy_rLlnoatEqzQ      ...             NaN        NaN
# 6EnpCPvBT-sO5iKM-SpZ1g      ...             NaN        NaN
# pLgfzwwPEiq9leL1u7iNuw      ...             NaN        NaN
# eY1WyHjXObOc-63nBv20Gg      ...             NaN        NaN
# yEE8-vuc_-KFJpk6PY06qg      ...             NaN        NaN
# 9zS4IkhwXrbp0uH0dTnrEg      ...             NaN        NaN
# QSfFgtcIrFHMs3_TVXjCLA      ...             NaN        NaN
# whsUOYXuIswjjvDglsTL7w      ...             NaN        NaN
# tku3pYiZrQLCT12MXr-OHA      ...             NaN        NaN
# PJZWfs8RSn4A5nvJ3Wzl1g      ...             NaN        NaN
# WA4F_4f1YKONgep-YY0uuw      ...             NaN        NaN
# ...                         ...             ...        ...
# b_-CrqKnXinHPa5LWI2gbQ      ...             NaN        NaN
# AvJgSdQ5ZetOFgaNfdZ32g      ...             NaN        NaN
# STDooDA8ZDdRPOzAMa1f0Q      ...             NaN        NaN
# 9l0QcFehRrxDZLy5_so_kg      ...             NaN        NaN
# -000aQFeK6tqVLndf7xORg      ...             NaN        NaN
# p6zSxr2nnRzJJ93LthQftg      ...             NaN        NaN
# h7l3xt_CAaFMD63ZgdXXWw      ...             NaN        NaN
# fFl7zlk8QnN2UOMIa38rcQ      ...             NaN        NaN
# GEvolb_U74NXgfgdxrVtyQ      ...             NaN        NaN
# IQgrWGRX6O0XvONGJtRTsw      ...             NaN        NaN
# dC6erJ1htWZO9N-Z3BakZQ      ...             NaN        NaN
# WICxQIYfM4dpIx16Tn5ofw      ...             NaN        NaN
# zWB6hcE7Pxww0VoI2fYIWw      ...             NaN        NaN
# ITZFaNBs54xradAO7o_QPA      ...             NaN        NaN
# f0L6u85V1ergQUrk7nlNDw      ...             NaN        NaN
# 0RNiVZcJwTIs-gdreHob1w      ...             NaN        NaN
# SYGbbZlLk81_bOlBptbS7A      ...             NaN        NaN
# yPSgeMxe7QL0mBeOlUwYgg      ...             NaN        NaN
# UPh90LM8UMnVFQP6NGktrA      ...             NaN        NaN
# 0p-3PlHw6FoWAs2ezJw3mA      ...             NaN        NaN
# X4J2P7U2aWPE_Y7YJF4JOA      ...             NaN        NaN
# RBAcL6hg2yoaTRv0kKUjPA      ...             NaN        NaN
# kx9ncrovqxZrRXEKrR06QA      ...             NaN        NaN
# HOarFvVeMrdrikfjf7-uGQ      ...             NaN        NaN
# 9p0jhBSwTPXyUbaZe_1bTA      ...             NaN        NaN
# PcW5yjx4rvc_vBrUc_fBSA      ...             NaN        NaN
# 4wBzxxSdEXZ48EnY3XcOFQ      ...             NaN        NaN
# aSB_HTwUzvN50-Rv9YiWSg      ...             NaN        NaN
# _tpvRiE69BSU5IAcqcr5sw      ...             NaN        NaN
# QEgfK_TKY8bwK-YzKDdkGw      ...             NaN        NaN
#
#                                          name  postal_code  review_count  \
# business_id
# a7mTbEi2N8Zd-r-8jlReww  Koryo Korean Barbeque      M1P 4P5           7.0
# _NO1sGYVk4lIib9a2DCtdw                    NaN          NaN           NaN
# Rmj0NYF_Id_2rZzocx-Vyw                    NaN          NaN           NaN
# Oyo5CWthu2upxxaf69MfIg                    NaN          NaN           NaN
# bFlP7uApDamdiVHwX8OwfA                    NaN          NaN           NaN
# zcq94VmjgyQ7v3bW_xAfsw                    NaN          NaN           NaN
# nSNNl7s0p3hSB3ZLPSVSlA                    NaN          NaN           NaN
# ZKJcKRG6fQitU7q_Eq04hg                    NaN          NaN           NaN
# IyoklPvMD14zdOxHlX_xHQ                    NaN          NaN           NaN
# zWrwVNAvrtVAhcDRWJJMEw                    NaN          NaN           NaN
# RBkzPjOduojmA3nvdBsnRg                    NaN          NaN           NaN
# X__txEx12Sc97btJc4L_fA                    NaN          NaN           NaN
# OszoMGV3waZNE0u4K0YgwQ                    NaN          NaN           NaN
# 48u7-r6_wqvIHBcuzNR-Cw                    NaN          NaN           NaN
# _72dMXdWbVAgwB-Bxwz-mw                    NaN          NaN           NaN
# YESM3VH-O_j7LMpW8tPA3Q                    NaN          NaN           NaN
# eQS4GqUh-D4Si-ERVa5IQw                    NaN          NaN           NaN
# DZxE9J1G5t593ojY0qXkFg                    NaN          NaN           NaN
# vPO6DqPOBL5faHKYFNrRfA                    NaN          NaN           NaN
# ymn4YVFgXy_rLlnoatEqzQ                    NaN          NaN           NaN
# 6EnpCPvBT-sO5iKM-SpZ1g                    NaN          NaN           NaN
# pLgfzwwPEiq9leL1u7iNuw                    NaN          NaN           NaN
# eY1WyHjXObOc-63nBv20Gg                    NaN          NaN           NaN
# yEE8-vuc_-KFJpk6PY06qg                    NaN          NaN           NaN
# 9zS4IkhwXrbp0uH0dTnrEg                    NaN          NaN           NaN
# QSfFgtcIrFHMs3_TVXjCLA                    NaN          NaN           NaN
# whsUOYXuIswjjvDglsTL7w                    NaN          NaN           NaN
# tku3pYiZrQLCT12MXr-OHA                    NaN          NaN           NaN
# PJZWfs8RSn4A5nvJ3Wzl1g                    NaN          NaN           NaN
# WA4F_4f1YKONgep-YY0uuw                    NaN          NaN           NaN
# ...                                       ...          ...           ...
# b_-CrqKnXinHPa5LWI2gbQ                    NaN          NaN           NaN
# AvJgSdQ5ZetOFgaNfdZ32g                    NaN          NaN           NaN
# STDooDA8ZDdRPOzAMa1f0Q                    NaN          NaN           NaN
# 9l0QcFehRrxDZLy5_so_kg                    NaN          NaN           NaN
# -000aQFeK6tqVLndf7xORg                    NaN          NaN           NaN
# p6zSxr2nnRzJJ93LthQftg                    NaN          NaN           NaN
# h7l3xt_CAaFMD63ZgdXXWw                    NaN          NaN           NaN
# fFl7zlk8QnN2UOMIa38rcQ                    NaN          NaN           NaN
# GEvolb_U74NXgfgdxrVtyQ                    NaN          NaN           NaN
# IQgrWGRX6O0XvONGJtRTsw                    NaN          NaN           NaN
# dC6erJ1htWZO9N-Z3BakZQ                    NaN          NaN           NaN
# WICxQIYfM4dpIx16Tn5ofw                    NaN          NaN           NaN
# zWB6hcE7Pxww0VoI2fYIWw                    NaN          NaN           NaN
# ITZFaNBs54xradAO7o_QPA                    NaN          NaN           NaN
# f0L6u85V1ergQUrk7nlNDw                    NaN          NaN           NaN
# 0RNiVZcJwTIs-gdreHob1w                    NaN          NaN           NaN
# SYGbbZlLk81_bOlBptbS7A                    NaN          NaN           NaN
# yPSgeMxe7QL0mBeOlUwYgg                    NaN          NaN           NaN
# UPh90LM8UMnVFQP6NGktrA                    NaN          NaN           NaN
# 0p-3PlHw6FoWAs2ezJw3mA                    NaN          NaN           NaN
# X4J2P7U2aWPE_Y7YJF4JOA                    NaN          NaN           NaN
# RBAcL6hg2yoaTRv0kKUjPA                    NaN          NaN           NaN
# kx9ncrovqxZrRXEKrR06QA                    NaN          NaN           NaN
# HOarFvVeMrdrikfjf7-uGQ                    NaN          NaN           NaN
# 9p0jhBSwTPXyUbaZe_1bTA                    NaN          NaN           NaN
# PcW5yjx4rvc_vBrUc_fBSA                    NaN          NaN           NaN
# 4wBzxxSdEXZ48EnY3XcOFQ                    NaN          NaN           NaN
# aSB_HTwUzvN50-Rv9YiWSg                    NaN          NaN           NaN
# _tpvRiE69BSU5IAcqcr5sw                    NaN          NaN           NaN
# QEgfK_TKY8bwK-YzKDdkGw                    NaN          NaN           NaN
#
#                         stars  state  useful  user_id  yelping_since
# business_id
# a7mTbEi2N8Zd-r-8jlReww    3.5     ON     NaN      NaN            NaN
# _NO1sGYVk4lIib9a2DCtdw    NaN    NaN     NaN      NaN            NaN
# Rmj0NYF_Id_2rZzocx-Vyw    NaN    NaN     NaN      NaN            NaN
# Oyo5CWthu2upxxaf69MfIg    NaN    NaN     NaN      NaN            NaN
# bFlP7uApDamdiVHwX8OwfA    NaN    NaN     NaN      NaN            NaN
# zcq94VmjgyQ7v3bW_xAfsw    NaN    NaN     NaN      NaN            NaN
# nSNNl7s0p3hSB3ZLPSVSlA    NaN    NaN     NaN      NaN            NaN
# ZKJcKRG6fQitU7q_Eq04hg    NaN    NaN     NaN      NaN            NaN
# IyoklPvMD14zdOxHlX_xHQ    NaN    NaN     NaN      NaN            NaN
# zWrwVNAvrtVAhcDRWJJMEw    NaN    NaN     NaN      NaN            NaN
# RBkzPjOduojmA3nvdBsnRg    NaN    NaN     NaN      NaN            NaN
# X__txEx12Sc97btJc4L_fA    NaN    NaN     NaN      NaN            NaN
# OszoMGV3waZNE0u4K0YgwQ    NaN    NaN     NaN      NaN            NaN
# 48u7-r6_wqvIHBcuzNR-Cw    NaN    NaN     NaN      NaN            NaN
# _72dMXdWbVAgwB-Bxwz-mw    NaN    NaN     NaN      NaN            NaN
# YESM3VH-O_j7LMpW8tPA3Q    NaN    NaN     NaN      NaN            NaN
# eQS4GqUh-D4Si-ERVa5IQw    NaN    NaN     NaN      NaN            NaN
# DZxE9J1G5t593ojY0qXkFg    NaN    NaN     NaN      NaN            NaN
# vPO6DqPOBL5faHKYFNrRfA    NaN    NaN     NaN      NaN            NaN
# ymn4YVFgXy_rLlnoatEqzQ    NaN    NaN     NaN      NaN            NaN
# 6EnpCPvBT-sO5iKM-SpZ1g    NaN    NaN     NaN      NaN            NaN
# pLgfzwwPEiq9leL1u7iNuw    NaN    NaN     NaN      NaN            NaN
# eY1WyHjXObOc-63nBv20Gg    NaN    NaN     NaN      NaN            NaN
# yEE8-vuc_-KFJpk6PY06qg    NaN    NaN     NaN      NaN            NaN
# 9zS4IkhwXrbp0uH0dTnrEg    NaN    NaN     NaN      NaN            NaN
# QSfFgtcIrFHMs3_TVXjCLA    NaN    NaN     NaN      NaN            NaN
# whsUOYXuIswjjvDglsTL7w    NaN    NaN     NaN      NaN            NaN
# tku3pYiZrQLCT12MXr-OHA    NaN    NaN     NaN      NaN            NaN
# PJZWfs8RSn4A5nvJ3Wzl1g    NaN    NaN     NaN      NaN            NaN
# WA4F_4f1YKONgep-YY0uuw    NaN    NaN     NaN      NaN            NaN
# ...                       ...    ...     ...      ...            ...
# b_-CrqKnXinHPa5LWI2gbQ    NaN    NaN     NaN      NaN            NaN
# AvJgSdQ5ZetOFgaNfdZ32g    NaN    NaN     NaN      NaN            NaN
# STDooDA8ZDdRPOzAMa1f0Q    NaN    NaN     NaN      NaN            NaN
# 9l0QcFehRrxDZLy5_so_kg    NaN    NaN     NaN      NaN            NaN
# -000aQFeK6tqVLndf7xORg    NaN    NaN     NaN      NaN            NaN
# p6zSxr2nnRzJJ93LthQftg    NaN    NaN     NaN      NaN            NaN
# h7l3xt_CAaFMD63ZgdXXWw    NaN    NaN     NaN      NaN            NaN
# fFl7zlk8QnN2UOMIa38rcQ    NaN    NaN     NaN      NaN            NaN
# GEvolb_U74NXgfgdxrVtyQ    NaN    NaN     NaN      NaN            NaN
# IQgrWGRX6O0XvONGJtRTsw    NaN    NaN     NaN      NaN            NaN
# dC6erJ1htWZO9N-Z3BakZQ    NaN    NaN     NaN      NaN            NaN
# WICxQIYfM4dpIx16Tn5ofw    NaN    NaN     NaN      NaN            NaN
# zWB6hcE7Pxww0VoI2fYIWw    NaN    NaN     NaN      NaN            NaN
# ITZFaNBs54xradAO7o_QPA    NaN    NaN     NaN      NaN            NaN
# f0L6u85V1ergQUrk7nlNDw    NaN    NaN     NaN      NaN            NaN
# 0RNiVZcJwTIs-gdreHob1w    NaN    NaN     NaN      NaN            NaN
# SYGbbZlLk81_bOlBptbS7A    NaN    NaN     NaN      NaN            NaN
# yPSgeMxe7QL0mBeOlUwYgg    NaN    NaN     NaN      NaN            NaN
# UPh90LM8UMnVFQP6NGktrA    NaN    NaN     NaN      NaN            NaN
# 0p-3PlHw6FoWAs2ezJw3mA    NaN    NaN     NaN      NaN            NaN
# X4J2P7U2aWPE_Y7YJF4JOA    NaN    NaN     NaN      NaN            NaN
# RBAcL6hg2yoaTRv0kKUjPA    NaN    NaN     NaN      NaN            NaN
# kx9ncrovqxZrRXEKrR06QA    NaN    NaN     NaN      NaN            NaN
# HOarFvVeMrdrikfjf7-uGQ    NaN    NaN     NaN      NaN            NaN
# 9p0jhBSwTPXyUbaZe_1bTA    NaN    NaN     NaN      NaN            NaN
# PcW5yjx4rvc_vBrUc_fBSA    NaN    NaN     NaN      NaN            NaN
# 4wBzxxSdEXZ48EnY3XcOFQ    NaN    NaN     NaN      NaN            NaN
# aSB_HTwUzvN50-Rv9YiWSg    NaN    NaN     NaN      NaN            NaN
# _tpvRiE69BSU5IAcqcr5sw    NaN    NaN     NaN      NaN            NaN
# QEgfK_TKY8bwK-YzKDdkGw    NaN    NaN     NaN      NaN            NaN
#
# [13589 rows x 33 columns]

# %%
get_recommendations_for(user_id= '96s7b2PBjmkzEeQTzmKp7w')
# Out:
# /Users/thomaslee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#                                    address  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A                 NaN
# SfP326rcU5sjwGx_dQP2RQ                 NaN
# DSCbB5lJLKnuxQKadFWrSw                 NaN
# TMI7DZ7Bng19adXy32E5UQ  10140 Yonge Street
# 3FB8FiwImxq5eL2GlBF3EQ                 NaN
# ZUJkwu_NS4L41AXEbGqHBQ                 NaN
# Be7Mwq06nf1eNLblo1ekow                 NaN
# lB2bnoWizz44ubSypZcwTA                 NaN
# Tq_S8F5B2fSeHqLZghOqQg                 NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ                 NaN
# Ri_K4vaiRNQjlyutXgadog                 NaN
# c_XbaJqhm-5ycSBOkVUBmg                 NaN
# ULAw5sRA8S2H4gK5paywVA                 NaN
# WbQgJOU0vNMYcWkwcC2Jew                 NaN
# J-A-VaoAvm3hMIb7VBJqHQ                 NaN
# Bh-G9_WLTreZh2bv-3_ZMQ                 NaN
# N0tp1hviGIgq8HIwvHTT9g                 NaN
# uJgxCC03SWlwAkttc4exJQ                 NaN
# 3WgRLMKmEIV2gLyFw4IKMA                 NaN
# EmKn83E_Fs73KJ2x7d55UQ                 NaN
# EreR7S8ZgCtc-s2IysYtqw                 NaN
# pcuuO_p4z6T_uEylouim7A                 NaN
# ARdkHJ748cC_7_fwViQxng                 NaN
# B0WJTnfCA3LY7mEBziC0Fg                 NaN
# eQL6UKYvkWERh21rF0Blnw                 NaN
# K2uJfgsKunCuNKALv_mGUQ                 NaN
# KgFmLr-HZeUZc7nsjMkSRw                 NaN
# yC4nbyZd2x3_a5IYHpjxWA                 NaN
# prUaUYJGqvcRrJYYMnNVXQ                 NaN
# 5n2dA_QqO4c_7pSK0Of6AQ                 NaN
# ...                                    ...
# 5V8zdJIbpGJ_BBgjbnHUmg                 NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ                 NaN
# fhdqLktxyn6T0vKvbqO1qA                 NaN
# -gRDDhLdkAfki50Dt5P9Og                 NaN
# j0i_MEV3XgGh4WegkthkiQ                 NaN
# dmgtqr_MWXENsZ_7yzxWHw                 NaN
# laBHq-98LF93adYf2Bl0cw                 NaN
# z6puJBjp677RIcu8pQbjFA                 NaN
# OhJHQhBB1V09mkI-r4o5MA                 NaN
# J1hR6fcmGWUACBXQVQkhjw                 NaN
# 1l23jN7IXzZ_UxJM3uFnhQ                 NaN
# LhEKSw3h_vGG3ihKjiOItw                 NaN
# W2D2eDrP9hGXWYli-4QJdg                 NaN
# TwYdL1qY7FFBl1BqCo-CJw                 NaN
# IsNyYU75dVu0Nnoo8bO4gA                 NaN
# URCmJ-uP_2FyHrShsRPycA                 NaN
# 5Heya5sQcGNdLI_IvEhzXw                 NaN
# 7z2x16M7IuG8KPfMsyVrKA                 NaN
# 8CSp_Zt1xbwFOkDOzu1jWA                 NaN
# WO1kqacT_65MYW8DTeydkQ                 NaN
# isw3cS3hOKdKeBgi3lF3-A                 NaN
# pKiSzUlBBRNEdTML24piXA                 NaN
# 2AtpxRG3opD2M7gtRvUUaw                 NaN
# HFDZeMrm13xX5yJvpaRaIQ                 NaN
# _oucYTswnckrgRuCzW3oVw                 NaN
# 3aRt8JPhjkfvbhqb3kJsbg                 NaN
# R3FZENdOY_TTKykKsJIuRA                 NaN
# EVl5rbR90yb9vqyq4o5K3A                 NaN
# HTngUd7s8kLBiAbEtd65Ug                 NaN
# yKaIT0fnxEj0YVr1DMHvuQ                 NaN
#
#                                                                attributes  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A                                                NaN
# SfP326rcU5sjwGx_dQP2RQ                                                NaN
# DSCbB5lJLKnuxQKadFWrSw                                                NaN
# TMI7DZ7Bng19adXy32E5UQ  {'HasTV': 'False', 'BikeParking': 'True', 'Noi...
# 3FB8FiwImxq5eL2GlBF3EQ                                                NaN
# ZUJkwu_NS4L41AXEbGqHBQ                                                NaN
# Be7Mwq06nf1eNLblo1ekow                                                NaN
# lB2bnoWizz44ubSypZcwTA                                                NaN
# Tq_S8F5B2fSeHqLZghOqQg                                                NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ                                                NaN
# Ri_K4vaiRNQjlyutXgadog                                                NaN
# c_XbaJqhm-5ycSBOkVUBmg                                                NaN
# ULAw5sRA8S2H4gK5paywVA                                                NaN
# WbQgJOU0vNMYcWkwcC2Jew                                                NaN
# J-A-VaoAvm3hMIb7VBJqHQ                                                NaN
# Bh-G9_WLTreZh2bv-3_ZMQ                                                NaN
# N0tp1hviGIgq8HIwvHTT9g                                                NaN
# uJgxCC03SWlwAkttc4exJQ                                                NaN
# 3WgRLMKmEIV2gLyFw4IKMA                                                NaN
# EmKn83E_Fs73KJ2x7d55UQ                                                NaN
# EreR7S8ZgCtc-s2IysYtqw                                                NaN
# pcuuO_p4z6T_uEylouim7A                                                NaN
# ARdkHJ748cC_7_fwViQxng                                                NaN
# B0WJTnfCA3LY7mEBziC0Fg                                                NaN
# eQL6UKYvkWERh21rF0Blnw                                                NaN
# K2uJfgsKunCuNKALv_mGUQ                                                NaN
# KgFmLr-HZeUZc7nsjMkSRw                                                NaN
# yC4nbyZd2x3_a5IYHpjxWA                                                NaN
# prUaUYJGqvcRrJYYMnNVXQ                                                NaN
# 5n2dA_QqO4c_7pSK0Of6AQ                                                NaN
# ...                                                                   ...
# 5V8zdJIbpGJ_BBgjbnHUmg                                                NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ                                                NaN
# fhdqLktxyn6T0vKvbqO1qA                                                NaN
# -gRDDhLdkAfki50Dt5P9Og                                                NaN
# j0i_MEV3XgGh4WegkthkiQ                                                NaN
# dmgtqr_MWXENsZ_7yzxWHw                                                NaN
# laBHq-98LF93adYf2Bl0cw                                                NaN
# z6puJBjp677RIcu8pQbjFA                                                NaN
# OhJHQhBB1V09mkI-r4o5MA                                                NaN
# J1hR6fcmGWUACBXQVQkhjw                                                NaN
# 1l23jN7IXzZ_UxJM3uFnhQ                                                NaN
# LhEKSw3h_vGG3ihKjiOItw                                                NaN
# W2D2eDrP9hGXWYli-4QJdg                                                NaN
# TwYdL1qY7FFBl1BqCo-CJw                                                NaN
# IsNyYU75dVu0Nnoo8bO4gA                                                NaN
# URCmJ-uP_2FyHrShsRPycA                                                NaN
# 5Heya5sQcGNdLI_IvEhzXw                                                NaN
# 7z2x16M7IuG8KPfMsyVrKA                                                NaN
# 8CSp_Zt1xbwFOkDOzu1jWA                                                NaN
# WO1kqacT_65MYW8DTeydkQ                                                NaN
# isw3cS3hOKdKeBgi3lF3-A                                                NaN
# pKiSzUlBBRNEdTML24piXA                                                NaN
# 2AtpxRG3opD2M7gtRvUUaw                                                NaN
# HFDZeMrm13xX5yJvpaRaIQ                                                NaN
# _oucYTswnckrgRuCzW3oVw                                                NaN
# 3aRt8JPhjkfvbhqb3kJsbg                                                NaN
# R3FZENdOY_TTKykKsJIuRA                                                NaN
# EVl5rbR90yb9vqyq4o5K3A                                                NaN
# HTngUd7s8kLBiAbEtd65Ug                                                NaN
# yKaIT0fnxEj0YVr1DMHvuQ                                                NaN
#
#                         average_stars  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A            NaN
# SfP326rcU5sjwGx_dQP2RQ            NaN
# DSCbB5lJLKnuxQKadFWrSw            NaN
# TMI7DZ7Bng19adXy32E5UQ            NaN
# 3FB8FiwImxq5eL2GlBF3EQ            NaN
# ZUJkwu_NS4L41AXEbGqHBQ            NaN
# Be7Mwq06nf1eNLblo1ekow            NaN
# lB2bnoWizz44ubSypZcwTA            NaN
# Tq_S8F5B2fSeHqLZghOqQg            NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ            NaN
# Ri_K4vaiRNQjlyutXgadog            NaN
# c_XbaJqhm-5ycSBOkVUBmg            NaN
# ULAw5sRA8S2H4gK5paywVA            NaN
# WbQgJOU0vNMYcWkwcC2Jew            NaN
# J-A-VaoAvm3hMIb7VBJqHQ            NaN
# Bh-G9_WLTreZh2bv-3_ZMQ            NaN
# N0tp1hviGIgq8HIwvHTT9g            NaN
# uJgxCC03SWlwAkttc4exJQ            NaN
# 3WgRLMKmEIV2gLyFw4IKMA            NaN
# EmKn83E_Fs73KJ2x7d55UQ            NaN
# EreR7S8ZgCtc-s2IysYtqw            NaN
# pcuuO_p4z6T_uEylouim7A            NaN
# ARdkHJ748cC_7_fwViQxng            NaN
# B0WJTnfCA3LY7mEBziC0Fg            NaN
# eQL6UKYvkWERh21rF0Blnw            NaN
# K2uJfgsKunCuNKALv_mGUQ            NaN
# KgFmLr-HZeUZc7nsjMkSRw            NaN
# yC4nbyZd2x3_a5IYHpjxWA            NaN
# prUaUYJGqvcRrJYYMnNVXQ            NaN
# 5n2dA_QqO4c_7pSK0Of6AQ            NaN
# ...                               ...
# 5V8zdJIbpGJ_BBgjbnHUmg            NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ            NaN
# fhdqLktxyn6T0vKvbqO1qA            NaN
# -gRDDhLdkAfki50Dt5P9Og            NaN
# j0i_MEV3XgGh4WegkthkiQ            NaN
# dmgtqr_MWXENsZ_7yzxWHw            NaN
# laBHq-98LF93adYf2Bl0cw            NaN
# z6puJBjp677RIcu8pQbjFA            NaN
# OhJHQhBB1V09mkI-r4o5MA            NaN
# J1hR6fcmGWUACBXQVQkhjw            NaN
# 1l23jN7IXzZ_UxJM3uFnhQ            NaN
# LhEKSw3h_vGG3ihKjiOItw            NaN
# W2D2eDrP9hGXWYli-4QJdg            NaN
# TwYdL1qY7FFBl1BqCo-CJw            NaN
# IsNyYU75dVu0Nnoo8bO4gA            NaN
# URCmJ-uP_2FyHrShsRPycA            NaN
# 5Heya5sQcGNdLI_IvEhzXw            NaN
# 7z2x16M7IuG8KPfMsyVrKA            NaN
# 8CSp_Zt1xbwFOkDOzu1jWA            NaN
# WO1kqacT_65MYW8DTeydkQ            NaN
# isw3cS3hOKdKeBgi3lF3-A            NaN
# pKiSzUlBBRNEdTML24piXA            NaN
# 2AtpxRG3opD2M7gtRvUUaw            NaN
# HFDZeMrm13xX5yJvpaRaIQ            NaN
# _oucYTswnckrgRuCzW3oVw            NaN
# 3aRt8JPhjkfvbhqb3kJsbg            NaN
# R3FZENdOY_TTKykKsJIuRA            NaN
# EVl5rbR90yb9vqyq4o5K3A            NaN
# HTngUd7s8kLBiAbEtd65Ug            NaN
# yKaIT0fnxEj0YVr1DMHvuQ            NaN
#
#                                                             categories  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A                                             NaN
# SfP326rcU5sjwGx_dQP2RQ                                             NaN
# DSCbB5lJLKnuxQKadFWrSw                                             NaN
# TMI7DZ7Bng19adXy32E5UQ  Canadian (New), Restaurants, Diners, Fast Food
# 3FB8FiwImxq5eL2GlBF3EQ                                             NaN
# ZUJkwu_NS4L41AXEbGqHBQ                                             NaN
# Be7Mwq06nf1eNLblo1ekow                                             NaN
# lB2bnoWizz44ubSypZcwTA                                             NaN
# Tq_S8F5B2fSeHqLZghOqQg                                             NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ                                             NaN
# Ri_K4vaiRNQjlyutXgadog                                             NaN
# c_XbaJqhm-5ycSBOkVUBmg                                             NaN
# ULAw5sRA8S2H4gK5paywVA                                             NaN
# WbQgJOU0vNMYcWkwcC2Jew                                             NaN
# J-A-VaoAvm3hMIb7VBJqHQ                                             NaN
# Bh-G9_WLTreZh2bv-3_ZMQ                                             NaN
# N0tp1hviGIgq8HIwvHTT9g                                             NaN
# uJgxCC03SWlwAkttc4exJQ                                             NaN
# 3WgRLMKmEIV2gLyFw4IKMA                                             NaN
# EmKn83E_Fs73KJ2x7d55UQ                                             NaN
# EreR7S8ZgCtc-s2IysYtqw                                             NaN
# pcuuO_p4z6T_uEylouim7A                                             NaN
# ARdkHJ748cC_7_fwViQxng                                             NaN
# B0WJTnfCA3LY7mEBziC0Fg                                             NaN
# eQL6UKYvkWERh21rF0Blnw                                             NaN
# K2uJfgsKunCuNKALv_mGUQ                                             NaN
# KgFmLr-HZeUZc7nsjMkSRw                                             NaN
# yC4nbyZd2x3_a5IYHpjxWA                                             NaN
# prUaUYJGqvcRrJYYMnNVXQ                                             NaN
# 5n2dA_QqO4c_7pSK0Of6AQ                                             NaN
# ...                                                                ...
# 5V8zdJIbpGJ_BBgjbnHUmg                                             NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ                                             NaN
# fhdqLktxyn6T0vKvbqO1qA                                             NaN
# -gRDDhLdkAfki50Dt5P9Og                                             NaN
# j0i_MEV3XgGh4WegkthkiQ                                             NaN
# dmgtqr_MWXENsZ_7yzxWHw                                             NaN
# laBHq-98LF93adYf2Bl0cw                                             NaN
# z6puJBjp677RIcu8pQbjFA                                             NaN
# OhJHQhBB1V09mkI-r4o5MA                                             NaN
# J1hR6fcmGWUACBXQVQkhjw                                             NaN
# 1l23jN7IXzZ_UxJM3uFnhQ                                             NaN
# LhEKSw3h_vGG3ihKjiOItw                                             NaN
# W2D2eDrP9hGXWYli-4QJdg                                             NaN
# TwYdL1qY7FFBl1BqCo-CJw                                             NaN
# IsNyYU75dVu0Nnoo8bO4gA                                             NaN
# URCmJ-uP_2FyHrShsRPycA                                             NaN
# 5Heya5sQcGNdLI_IvEhzXw                                             NaN
# 7z2x16M7IuG8KPfMsyVrKA                                             NaN
# 8CSp_Zt1xbwFOkDOzu1jWA                                             NaN
# WO1kqacT_65MYW8DTeydkQ                                             NaN
# isw3cS3hOKdKeBgi3lF3-A                                             NaN
# pKiSzUlBBRNEdTML24piXA                                             NaN
# 2AtpxRG3opD2M7gtRvUUaw                                             NaN
# HFDZeMrm13xX5yJvpaRaIQ                                             NaN
# _oucYTswnckrgRuCzW3oVw                                             NaN
# 3aRt8JPhjkfvbhqb3kJsbg                                             NaN
# R3FZENdOY_TTKykKsJIuRA                                             NaN
# EVl5rbR90yb9vqyq4o5K3A                                             NaN
# HTngUd7s8kLBiAbEtd65Ug                                             NaN
# yKaIT0fnxEj0YVr1DMHvuQ                                             NaN
#
#                                  city  compliment_cool  compliment_cute  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A            NaN              NaN              NaN
# SfP326rcU5sjwGx_dQP2RQ            NaN              NaN              NaN
# DSCbB5lJLKnuxQKadFWrSw            NaN              NaN              NaN
# TMI7DZ7Bng19adXy32E5UQ  Richmond Hill              NaN              NaN
# 3FB8FiwImxq5eL2GlBF3EQ            NaN              NaN              NaN
# ZUJkwu_NS4L41AXEbGqHBQ            NaN              NaN              NaN
# Be7Mwq06nf1eNLblo1ekow            NaN              NaN              NaN
# lB2bnoWizz44ubSypZcwTA            NaN              NaN              NaN
# Tq_S8F5B2fSeHqLZghOqQg            NaN              NaN              NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ            NaN              NaN              NaN
# Ri_K4vaiRNQjlyutXgadog            NaN              NaN              NaN
# c_XbaJqhm-5ycSBOkVUBmg            NaN              NaN              NaN
# ULAw5sRA8S2H4gK5paywVA            NaN              NaN              NaN
# WbQgJOU0vNMYcWkwcC2Jew            NaN              NaN              NaN
# J-A-VaoAvm3hMIb7VBJqHQ            NaN              NaN              NaN
# Bh-G9_WLTreZh2bv-3_ZMQ            NaN              NaN              NaN
# N0tp1hviGIgq8HIwvHTT9g            NaN              NaN              NaN
# uJgxCC03SWlwAkttc4exJQ            NaN              NaN              NaN
# 3WgRLMKmEIV2gLyFw4IKMA            NaN              NaN              NaN
# EmKn83E_Fs73KJ2x7d55UQ            NaN              NaN              NaN
# EreR7S8ZgCtc-s2IysYtqw            NaN              NaN              NaN
# pcuuO_p4z6T_uEylouim7A            NaN              NaN              NaN
# ARdkHJ748cC_7_fwViQxng            NaN              NaN              NaN
# B0WJTnfCA3LY7mEBziC0Fg            NaN              NaN              NaN
# eQL6UKYvkWERh21rF0Blnw            NaN              NaN              NaN
# K2uJfgsKunCuNKALv_mGUQ            NaN              NaN              NaN
# KgFmLr-HZeUZc7nsjMkSRw            NaN              NaN              NaN
# yC4nbyZd2x3_a5IYHpjxWA            NaN              NaN              NaN
# prUaUYJGqvcRrJYYMnNVXQ            NaN              NaN              NaN
# 5n2dA_QqO4c_7pSK0Of6AQ            NaN              NaN              NaN
# ...                               ...              ...              ...
# 5V8zdJIbpGJ_BBgjbnHUmg            NaN              NaN              NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ            NaN              NaN              NaN
# fhdqLktxyn6T0vKvbqO1qA            NaN              NaN              NaN
# -gRDDhLdkAfki50Dt5P9Og            NaN              NaN              NaN
# j0i_MEV3XgGh4WegkthkiQ            NaN              NaN              NaN
# dmgtqr_MWXENsZ_7yzxWHw            NaN              NaN              NaN
# laBHq-98LF93adYf2Bl0cw            NaN              NaN              NaN
# z6puJBjp677RIcu8pQbjFA            NaN              NaN              NaN
# OhJHQhBB1V09mkI-r4o5MA            NaN              NaN              NaN
# J1hR6fcmGWUACBXQVQkhjw            NaN              NaN              NaN
# 1l23jN7IXzZ_UxJM3uFnhQ            NaN              NaN              NaN
# LhEKSw3h_vGG3ihKjiOItw            NaN              NaN              NaN
# W2D2eDrP9hGXWYli-4QJdg            NaN              NaN              NaN
# TwYdL1qY7FFBl1BqCo-CJw            NaN              NaN              NaN
# IsNyYU75dVu0Nnoo8bO4gA            NaN              NaN              NaN
# URCmJ-uP_2FyHrShsRPycA            NaN              NaN              NaN
# 5Heya5sQcGNdLI_IvEhzXw            NaN              NaN              NaN
# 7z2x16M7IuG8KPfMsyVrKA            NaN              NaN              NaN
# 8CSp_Zt1xbwFOkDOzu1jWA            NaN              NaN              NaN
# WO1kqacT_65MYW8DTeydkQ            NaN              NaN              NaN
# isw3cS3hOKdKeBgi3lF3-A            NaN              NaN              NaN
# pKiSzUlBBRNEdTML24piXA            NaN              NaN              NaN
# 2AtpxRG3opD2M7gtRvUUaw            NaN              NaN              NaN
# HFDZeMrm13xX5yJvpaRaIQ            NaN              NaN              NaN
# _oucYTswnckrgRuCzW3oVw            NaN              NaN              NaN
# 3aRt8JPhjkfvbhqb3kJsbg            NaN              NaN              NaN
# R3FZENdOY_TTKykKsJIuRA            NaN              NaN              NaN
# EVl5rbR90yb9vqyq4o5K3A            NaN              NaN              NaN
# HTngUd7s8kLBiAbEtd65Ug            NaN              NaN              NaN
# yKaIT0fnxEj0YVr1DMHvuQ            NaN              NaN              NaN
#
#                         compliment_funny  compliment_hot  compliment_list  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A               NaN             NaN              NaN
# SfP326rcU5sjwGx_dQP2RQ               NaN             NaN              NaN
# DSCbB5lJLKnuxQKadFWrSw               NaN             NaN              NaN
# TMI7DZ7Bng19adXy32E5UQ               NaN             NaN              NaN
# 3FB8FiwImxq5eL2GlBF3EQ               NaN             NaN              NaN
# ZUJkwu_NS4L41AXEbGqHBQ               NaN             NaN              NaN
# Be7Mwq06nf1eNLblo1ekow               NaN             NaN              NaN
# lB2bnoWizz44ubSypZcwTA               NaN             NaN              NaN
# Tq_S8F5B2fSeHqLZghOqQg               NaN             NaN              NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ               NaN             NaN              NaN
# Ri_K4vaiRNQjlyutXgadog               NaN             NaN              NaN
# c_XbaJqhm-5ycSBOkVUBmg               NaN             NaN              NaN
# ULAw5sRA8S2H4gK5paywVA               NaN             NaN              NaN
# WbQgJOU0vNMYcWkwcC2Jew               NaN             NaN              NaN
# J-A-VaoAvm3hMIb7VBJqHQ               NaN             NaN              NaN
# Bh-G9_WLTreZh2bv-3_ZMQ               NaN             NaN              NaN
# N0tp1hviGIgq8HIwvHTT9g               NaN             NaN              NaN
# uJgxCC03SWlwAkttc4exJQ               NaN             NaN              NaN
# 3WgRLMKmEIV2gLyFw4IKMA               NaN             NaN              NaN
# EmKn83E_Fs73KJ2x7d55UQ               NaN             NaN              NaN
# EreR7S8ZgCtc-s2IysYtqw               NaN             NaN              NaN
# pcuuO_p4z6T_uEylouim7A               NaN             NaN              NaN
# ARdkHJ748cC_7_fwViQxng               NaN             NaN              NaN
# B0WJTnfCA3LY7mEBziC0Fg               NaN             NaN              NaN
# eQL6UKYvkWERh21rF0Blnw               NaN             NaN              NaN
# K2uJfgsKunCuNKALv_mGUQ               NaN             NaN              NaN
# KgFmLr-HZeUZc7nsjMkSRw               NaN             NaN              NaN
# yC4nbyZd2x3_a5IYHpjxWA               NaN             NaN              NaN
# prUaUYJGqvcRrJYYMnNVXQ               NaN             NaN              NaN
# 5n2dA_QqO4c_7pSK0Of6AQ               NaN             NaN              NaN
# ...                                  ...             ...              ...
# 5V8zdJIbpGJ_BBgjbnHUmg               NaN             NaN              NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ               NaN             NaN              NaN
# fhdqLktxyn6T0vKvbqO1qA               NaN             NaN              NaN
# -gRDDhLdkAfki50Dt5P9Og               NaN             NaN              NaN
# j0i_MEV3XgGh4WegkthkiQ               NaN             NaN              NaN
# dmgtqr_MWXENsZ_7yzxWHw               NaN             NaN              NaN
# laBHq-98LF93adYf2Bl0cw               NaN             NaN              NaN
# z6puJBjp677RIcu8pQbjFA               NaN             NaN              NaN
# OhJHQhBB1V09mkI-r4o5MA               NaN             NaN              NaN
# J1hR6fcmGWUACBXQVQkhjw               NaN             NaN              NaN
# 1l23jN7IXzZ_UxJM3uFnhQ               NaN             NaN              NaN
# LhEKSw3h_vGG3ihKjiOItw               NaN             NaN              NaN
# W2D2eDrP9hGXWYli-4QJdg               NaN             NaN              NaN
# TwYdL1qY7FFBl1BqCo-CJw               NaN             NaN              NaN
# IsNyYU75dVu0Nnoo8bO4gA               NaN             NaN              NaN
# URCmJ-uP_2FyHrShsRPycA               NaN             NaN              NaN
# 5Heya5sQcGNdLI_IvEhzXw               NaN             NaN              NaN
# 7z2x16M7IuG8KPfMsyVrKA               NaN             NaN              NaN
# 8CSp_Zt1xbwFOkDOzu1jWA               NaN             NaN              NaN
# WO1kqacT_65MYW8DTeydkQ               NaN             NaN              NaN
# isw3cS3hOKdKeBgi3lF3-A               NaN             NaN              NaN
# pKiSzUlBBRNEdTML24piXA               NaN             NaN              NaN
# 2AtpxRG3opD2M7gtRvUUaw               NaN             NaN              NaN
# HFDZeMrm13xX5yJvpaRaIQ               NaN             NaN              NaN
# _oucYTswnckrgRuCzW3oVw               NaN             NaN              NaN
# 3aRt8JPhjkfvbhqb3kJsbg               NaN             NaN              NaN
# R3FZENdOY_TTKykKsJIuRA               NaN             NaN              NaN
# EVl5rbR90yb9vqyq4o5K3A               NaN             NaN              NaN
# HTngUd7s8kLBiAbEtd65Ug               NaN             NaN              NaN
# yKaIT0fnxEj0YVr1DMHvuQ               NaN             NaN              NaN
#
#                             ...         latitude  longitude  \
# business_id                 ...
# yWwIUmeenyAO7nwc7U0U5A      ...              NaN        NaN
# SfP326rcU5sjwGx_dQP2RQ      ...              NaN        NaN
# DSCbB5lJLKnuxQKadFWrSw      ...              NaN        NaN
# TMI7DZ7Bng19adXy32E5UQ      ...        43.874637 -79.438233
# 3FB8FiwImxq5eL2GlBF3EQ      ...              NaN        NaN
# ZUJkwu_NS4L41AXEbGqHBQ      ...              NaN        NaN
# Be7Mwq06nf1eNLblo1ekow      ...              NaN        NaN
# lB2bnoWizz44ubSypZcwTA      ...              NaN        NaN
# Tq_S8F5B2fSeHqLZghOqQg      ...              NaN        NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ      ...              NaN        NaN
# Ri_K4vaiRNQjlyutXgadog      ...              NaN        NaN
# c_XbaJqhm-5ycSBOkVUBmg      ...              NaN        NaN
# ULAw5sRA8S2H4gK5paywVA      ...              NaN        NaN
# WbQgJOU0vNMYcWkwcC2Jew      ...              NaN        NaN
# J-A-VaoAvm3hMIb7VBJqHQ      ...              NaN        NaN
# Bh-G9_WLTreZh2bv-3_ZMQ      ...              NaN        NaN
# N0tp1hviGIgq8HIwvHTT9g      ...              NaN        NaN
# uJgxCC03SWlwAkttc4exJQ      ...              NaN        NaN
# 3WgRLMKmEIV2gLyFw4IKMA      ...              NaN        NaN
# EmKn83E_Fs73KJ2x7d55UQ      ...              NaN        NaN
# EreR7S8ZgCtc-s2IysYtqw      ...              NaN        NaN
# pcuuO_p4z6T_uEylouim7A      ...              NaN        NaN
# ARdkHJ748cC_7_fwViQxng      ...              NaN        NaN
# B0WJTnfCA3LY7mEBziC0Fg      ...              NaN        NaN
# eQL6UKYvkWERh21rF0Blnw      ...              NaN        NaN
# K2uJfgsKunCuNKALv_mGUQ      ...              NaN        NaN
# KgFmLr-HZeUZc7nsjMkSRw      ...              NaN        NaN
# yC4nbyZd2x3_a5IYHpjxWA      ...              NaN        NaN
# prUaUYJGqvcRrJYYMnNVXQ      ...              NaN        NaN
# 5n2dA_QqO4c_7pSK0Of6AQ      ...              NaN        NaN
# ...                         ...              ...        ...
# 5V8zdJIbpGJ_BBgjbnHUmg      ...              NaN        NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ      ...              NaN        NaN
# fhdqLktxyn6T0vKvbqO1qA      ...              NaN        NaN
# -gRDDhLdkAfki50Dt5P9Og      ...              NaN        NaN
# j0i_MEV3XgGh4WegkthkiQ      ...              NaN        NaN
# dmgtqr_MWXENsZ_7yzxWHw      ...              NaN        NaN
# laBHq-98LF93adYf2Bl0cw      ...              NaN        NaN
# z6puJBjp677RIcu8pQbjFA      ...              NaN        NaN
# OhJHQhBB1V09mkI-r4o5MA      ...              NaN        NaN
# J1hR6fcmGWUACBXQVQkhjw      ...              NaN        NaN
# 1l23jN7IXzZ_UxJM3uFnhQ      ...              NaN        NaN
# LhEKSw3h_vGG3ihKjiOItw      ...              NaN        NaN
# W2D2eDrP9hGXWYli-4QJdg      ...              NaN        NaN
# TwYdL1qY7FFBl1BqCo-CJw      ...              NaN        NaN
# IsNyYU75dVu0Nnoo8bO4gA      ...              NaN        NaN
# URCmJ-uP_2FyHrShsRPycA      ...              NaN        NaN
# 5Heya5sQcGNdLI_IvEhzXw      ...              NaN        NaN
# 7z2x16M7IuG8KPfMsyVrKA      ...              NaN        NaN
# 8CSp_Zt1xbwFOkDOzu1jWA      ...              NaN        NaN
# WO1kqacT_65MYW8DTeydkQ      ...              NaN        NaN
# isw3cS3hOKdKeBgi3lF3-A      ...              NaN        NaN
# pKiSzUlBBRNEdTML24piXA      ...              NaN        NaN
# 2AtpxRG3opD2M7gtRvUUaw      ...              NaN        NaN
# HFDZeMrm13xX5yJvpaRaIQ      ...              NaN        NaN
# _oucYTswnckrgRuCzW3oVw      ...              NaN        NaN
# 3aRt8JPhjkfvbhqb3kJsbg      ...              NaN        NaN
# R3FZENdOY_TTKykKsJIuRA      ...              NaN        NaN
# EVl5rbR90yb9vqyq4o5K3A      ...              NaN        NaN
# HTngUd7s8kLBiAbEtd65Ug      ...              NaN        NaN
# yKaIT0fnxEj0YVr1DMHvuQ      ...              NaN        NaN
#
#                                         name  postal_code  review_count  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A                   NaN          NaN           NaN
# SfP326rcU5sjwGx_dQP2RQ                   NaN          NaN           NaN
# DSCbB5lJLKnuxQKadFWrSw                   NaN          NaN           NaN
# TMI7DZ7Bng19adXy32E5UQ  3 Coins Open Kitchen      L4C 1T6          32.0
# 3FB8FiwImxq5eL2GlBF3EQ                   NaN          NaN           NaN
# ZUJkwu_NS4L41AXEbGqHBQ                   NaN          NaN           NaN
# Be7Mwq06nf1eNLblo1ekow                   NaN          NaN           NaN
# lB2bnoWizz44ubSypZcwTA                   NaN          NaN           NaN
# Tq_S8F5B2fSeHqLZghOqQg                   NaN          NaN           NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ                   NaN          NaN           NaN
# Ri_K4vaiRNQjlyutXgadog                   NaN          NaN           NaN
# c_XbaJqhm-5ycSBOkVUBmg                   NaN          NaN           NaN
# ULAw5sRA8S2H4gK5paywVA                   NaN          NaN           NaN
# WbQgJOU0vNMYcWkwcC2Jew                   NaN          NaN           NaN
# J-A-VaoAvm3hMIb7VBJqHQ                   NaN          NaN           NaN
# Bh-G9_WLTreZh2bv-3_ZMQ                   NaN          NaN           NaN
# N0tp1hviGIgq8HIwvHTT9g                   NaN          NaN           NaN
# uJgxCC03SWlwAkttc4exJQ                   NaN          NaN           NaN
# 3WgRLMKmEIV2gLyFw4IKMA                   NaN          NaN           NaN
# EmKn83E_Fs73KJ2x7d55UQ                   NaN          NaN           NaN
# EreR7S8ZgCtc-s2IysYtqw                   NaN          NaN           NaN
# pcuuO_p4z6T_uEylouim7A                   NaN          NaN           NaN
# ARdkHJ748cC_7_fwViQxng                   NaN          NaN           NaN
# B0WJTnfCA3LY7mEBziC0Fg                   NaN          NaN           NaN
# eQL6UKYvkWERh21rF0Blnw                   NaN          NaN           NaN
# K2uJfgsKunCuNKALv_mGUQ                   NaN          NaN           NaN
# KgFmLr-HZeUZc7nsjMkSRw                   NaN          NaN           NaN
# yC4nbyZd2x3_a5IYHpjxWA                   NaN          NaN           NaN
# prUaUYJGqvcRrJYYMnNVXQ                   NaN          NaN           NaN
# 5n2dA_QqO4c_7pSK0Of6AQ                   NaN          NaN           NaN
# ...                                      ...          ...           ...
# 5V8zdJIbpGJ_BBgjbnHUmg                   NaN          NaN           NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ                   NaN          NaN           NaN
# fhdqLktxyn6T0vKvbqO1qA                   NaN          NaN           NaN
# -gRDDhLdkAfki50Dt5P9Og                   NaN          NaN           NaN
# j0i_MEV3XgGh4WegkthkiQ                   NaN          NaN           NaN
# dmgtqr_MWXENsZ_7yzxWHw                   NaN          NaN           NaN
# laBHq-98LF93adYf2Bl0cw                   NaN          NaN           NaN
# z6puJBjp677RIcu8pQbjFA                   NaN          NaN           NaN
# OhJHQhBB1V09mkI-r4o5MA                   NaN          NaN           NaN
# J1hR6fcmGWUACBXQVQkhjw                   NaN          NaN           NaN
# 1l23jN7IXzZ_UxJM3uFnhQ                   NaN          NaN           NaN
# LhEKSw3h_vGG3ihKjiOItw                   NaN          NaN           NaN
# W2D2eDrP9hGXWYli-4QJdg                   NaN          NaN           NaN
# TwYdL1qY7FFBl1BqCo-CJw                   NaN          NaN           NaN
# IsNyYU75dVu0Nnoo8bO4gA                   NaN          NaN           NaN
# URCmJ-uP_2FyHrShsRPycA                   NaN          NaN           NaN
# 5Heya5sQcGNdLI_IvEhzXw                   NaN          NaN           NaN
# 7z2x16M7IuG8KPfMsyVrKA                   NaN          NaN           NaN
# 8CSp_Zt1xbwFOkDOzu1jWA                   NaN          NaN           NaN
# WO1kqacT_65MYW8DTeydkQ                   NaN          NaN           NaN
# isw3cS3hOKdKeBgi3lF3-A                   NaN          NaN           NaN
# pKiSzUlBBRNEdTML24piXA                   NaN          NaN           NaN
# 2AtpxRG3opD2M7gtRvUUaw                   NaN          NaN           NaN
# HFDZeMrm13xX5yJvpaRaIQ                   NaN          NaN           NaN
# _oucYTswnckrgRuCzW3oVw                   NaN          NaN           NaN
# 3aRt8JPhjkfvbhqb3kJsbg                   NaN          NaN           NaN
# R3FZENdOY_TTKykKsJIuRA                   NaN          NaN           NaN
# EVl5rbR90yb9vqyq4o5K3A                   NaN          NaN           NaN
# HTngUd7s8kLBiAbEtd65Ug                   NaN          NaN           NaN
# yKaIT0fnxEj0YVr1DMHvuQ                   NaN          NaN           NaN
#
#                         stars  state  useful  user_id  yelping_since
# business_id
# yWwIUmeenyAO7nwc7U0U5A    NaN    NaN     NaN      NaN            NaN
# SfP326rcU5sjwGx_dQP2RQ    NaN    NaN     NaN      NaN            NaN
# DSCbB5lJLKnuxQKadFWrSw    NaN    NaN     NaN      NaN            NaN
# TMI7DZ7Bng19adXy32E5UQ    4.0     ON     NaN      NaN            NaN
# 3FB8FiwImxq5eL2GlBF3EQ    NaN    NaN     NaN      NaN            NaN
# ZUJkwu_NS4L41AXEbGqHBQ    NaN    NaN     NaN      NaN            NaN
# Be7Mwq06nf1eNLblo1ekow    NaN    NaN     NaN      NaN            NaN
# lB2bnoWizz44ubSypZcwTA    NaN    NaN     NaN      NaN            NaN
# Tq_S8F5B2fSeHqLZghOqQg    NaN    NaN     NaN      NaN            NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ    NaN    NaN     NaN      NaN            NaN
# Ri_K4vaiRNQjlyutXgadog    NaN    NaN     NaN      NaN            NaN
# c_XbaJqhm-5ycSBOkVUBmg    NaN    NaN     NaN      NaN            NaN
# ULAw5sRA8S2H4gK5paywVA    NaN    NaN     NaN      NaN            NaN
# WbQgJOU0vNMYcWkwcC2Jew    NaN    NaN     NaN      NaN            NaN
# J-A-VaoAvm3hMIb7VBJqHQ    NaN    NaN     NaN      NaN            NaN
# Bh-G9_WLTreZh2bv-3_ZMQ    NaN    NaN     NaN      NaN            NaN
# N0tp1hviGIgq8HIwvHTT9g    NaN    NaN     NaN      NaN            NaN
# uJgxCC03SWlwAkttc4exJQ    NaN    NaN     NaN      NaN            NaN
# 3WgRLMKmEIV2gLyFw4IKMA    NaN    NaN     NaN      NaN            NaN
# EmKn83E_Fs73KJ2x7d55UQ    NaN    NaN     NaN      NaN            NaN
# EreR7S8ZgCtc-s2IysYtqw    NaN    NaN     NaN      NaN            NaN
# pcuuO_p4z6T_uEylouim7A    NaN    NaN     NaN      NaN            NaN
# ARdkHJ748cC_7_fwViQxng    NaN    NaN     NaN      NaN            NaN
# B0WJTnfCA3LY7mEBziC0Fg    NaN    NaN     NaN      NaN            NaN
# eQL6UKYvkWERh21rF0Blnw    NaN    NaN     NaN      NaN            NaN
# K2uJfgsKunCuNKALv_mGUQ    NaN    NaN     NaN      NaN            NaN
# KgFmLr-HZeUZc7nsjMkSRw    NaN    NaN     NaN      NaN            NaN
# yC4nbyZd2x3_a5IYHpjxWA    NaN    NaN     NaN      NaN            NaN
# prUaUYJGqvcRrJYYMnNVXQ    NaN    NaN     NaN      NaN            NaN
# 5n2dA_QqO4c_7pSK0Of6AQ    NaN    NaN     NaN      NaN            NaN
# ...                       ...    ...     ...      ...            ...
# 5V8zdJIbpGJ_BBgjbnHUmg    NaN    NaN     NaN      NaN            NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ    NaN    NaN     NaN      NaN            NaN
# fhdqLktxyn6T0vKvbqO1qA    NaN    NaN     NaN      NaN            NaN
# -gRDDhLdkAfki50Dt5P9Og    NaN    NaN     NaN      NaN            NaN
# j0i_MEV3XgGh4WegkthkiQ    NaN    NaN     NaN      NaN            NaN
# dmgtqr_MWXENsZ_7yzxWHw    NaN    NaN     NaN      NaN            NaN
# laBHq-98LF93adYf2Bl0cw    NaN    NaN     NaN      NaN            NaN
# z6puJBjp677RIcu8pQbjFA    NaN    NaN     NaN      NaN            NaN
# OhJHQhBB1V09mkI-r4o5MA    NaN    NaN     NaN      NaN            NaN
# J1hR6fcmGWUACBXQVQkhjw    NaN    NaN     NaN      NaN            NaN
# 1l23jN7IXzZ_UxJM3uFnhQ    NaN    NaN     NaN      NaN            NaN
# LhEKSw3h_vGG3ihKjiOItw    NaN    NaN     NaN      NaN            NaN
# W2D2eDrP9hGXWYli-4QJdg    NaN    NaN     NaN      NaN            NaN
# TwYdL1qY7FFBl1BqCo-CJw    NaN    NaN     NaN      NaN            NaN
# IsNyYU75dVu0Nnoo8bO4gA    NaN    NaN     NaN      NaN            NaN
# URCmJ-uP_2FyHrShsRPycA    NaN    NaN     NaN      NaN            NaN
# 5Heya5sQcGNdLI_IvEhzXw    NaN    NaN     NaN      NaN            NaN
# 7z2x16M7IuG8KPfMsyVrKA    NaN    NaN     NaN      NaN            NaN
# 8CSp_Zt1xbwFOkDOzu1jWA    NaN    NaN     NaN      NaN            NaN
# WO1kqacT_65MYW8DTeydkQ    NaN    NaN     NaN      NaN            NaN
# isw3cS3hOKdKeBgi3lF3-A    NaN    NaN     NaN      NaN            NaN
# pKiSzUlBBRNEdTML24piXA    NaN    NaN     NaN      NaN            NaN
# 2AtpxRG3opD2M7gtRvUUaw    NaN    NaN     NaN      NaN            NaN
# HFDZeMrm13xX5yJvpaRaIQ    NaN    NaN     NaN      NaN            NaN
# _oucYTswnckrgRuCzW3oVw    NaN    NaN     NaN      NaN            NaN
# 3aRt8JPhjkfvbhqb3kJsbg    NaN    NaN     NaN      NaN            NaN
# R3FZENdOY_TTKykKsJIuRA    NaN    NaN     NaN      NaN            NaN
# EVl5rbR90yb9vqyq4o5K3A    NaN    NaN     NaN      NaN            NaN
# HTngUd7s8kLBiAbEtd65Ug    NaN    NaN     NaN      NaN            NaN
# yKaIT0fnxEj0YVr1DMHvuQ    NaN    NaN     NaN      NaN            NaN
#
# [13589 rows x 33 columns]

# %%
get_recommendations_for('96s7b2PBjmkzEeQTzmKp7w')
# Out:
# /Users/thomaslee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#                                    address  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A                 NaN
# SfP326rcU5sjwGx_dQP2RQ                 NaN
# DSCbB5lJLKnuxQKadFWrSw                 NaN
# TMI7DZ7Bng19adXy32E5UQ  10140 Yonge Street
# 3FB8FiwImxq5eL2GlBF3EQ                 NaN
# ZUJkwu_NS4L41AXEbGqHBQ                 NaN
# Be7Mwq06nf1eNLblo1ekow                 NaN
# lB2bnoWizz44ubSypZcwTA                 NaN
# Tq_S8F5B2fSeHqLZghOqQg                 NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ                 NaN
# Ri_K4vaiRNQjlyutXgadog                 NaN
# c_XbaJqhm-5ycSBOkVUBmg                 NaN
# ULAw5sRA8S2H4gK5paywVA                 NaN
# WbQgJOU0vNMYcWkwcC2Jew                 NaN
# J-A-VaoAvm3hMIb7VBJqHQ                 NaN
# Bh-G9_WLTreZh2bv-3_ZMQ                 NaN
# N0tp1hviGIgq8HIwvHTT9g                 NaN
# uJgxCC03SWlwAkttc4exJQ                 NaN
# 3WgRLMKmEIV2gLyFw4IKMA                 NaN
# EmKn83E_Fs73KJ2x7d55UQ                 NaN
# EreR7S8ZgCtc-s2IysYtqw                 NaN
# pcuuO_p4z6T_uEylouim7A                 NaN
# ARdkHJ748cC_7_fwViQxng                 NaN
# B0WJTnfCA3LY7mEBziC0Fg                 NaN
# eQL6UKYvkWERh21rF0Blnw                 NaN
# K2uJfgsKunCuNKALv_mGUQ                 NaN
# KgFmLr-HZeUZc7nsjMkSRw                 NaN
# yC4nbyZd2x3_a5IYHpjxWA                 NaN
# prUaUYJGqvcRrJYYMnNVXQ                 NaN
# 5n2dA_QqO4c_7pSK0Of6AQ                 NaN
# ...                                    ...
# 5V8zdJIbpGJ_BBgjbnHUmg                 NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ                 NaN
# fhdqLktxyn6T0vKvbqO1qA                 NaN
# -gRDDhLdkAfki50Dt5P9Og                 NaN
# j0i_MEV3XgGh4WegkthkiQ                 NaN
# dmgtqr_MWXENsZ_7yzxWHw                 NaN
# laBHq-98LF93adYf2Bl0cw                 NaN
# z6puJBjp677RIcu8pQbjFA                 NaN
# OhJHQhBB1V09mkI-r4o5MA                 NaN
# J1hR6fcmGWUACBXQVQkhjw                 NaN
# 1l23jN7IXzZ_UxJM3uFnhQ                 NaN
# LhEKSw3h_vGG3ihKjiOItw                 NaN
# W2D2eDrP9hGXWYli-4QJdg                 NaN
# TwYdL1qY7FFBl1BqCo-CJw                 NaN
# IsNyYU75dVu0Nnoo8bO4gA                 NaN
# URCmJ-uP_2FyHrShsRPycA                 NaN
# 5Heya5sQcGNdLI_IvEhzXw                 NaN
# 7z2x16M7IuG8KPfMsyVrKA                 NaN
# 8CSp_Zt1xbwFOkDOzu1jWA                 NaN
# WO1kqacT_65MYW8DTeydkQ                 NaN
# isw3cS3hOKdKeBgi3lF3-A                 NaN
# pKiSzUlBBRNEdTML24piXA                 NaN
# 2AtpxRG3opD2M7gtRvUUaw                 NaN
# HFDZeMrm13xX5yJvpaRaIQ                 NaN
# _oucYTswnckrgRuCzW3oVw                 NaN
# 3aRt8JPhjkfvbhqb3kJsbg                 NaN
# R3FZENdOY_TTKykKsJIuRA                 NaN
# EVl5rbR90yb9vqyq4o5K3A                 NaN
# HTngUd7s8kLBiAbEtd65Ug                 NaN
# yKaIT0fnxEj0YVr1DMHvuQ                 NaN
#
#                                                                attributes  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A                                                NaN
# SfP326rcU5sjwGx_dQP2RQ                                                NaN
# DSCbB5lJLKnuxQKadFWrSw                                                NaN
# TMI7DZ7Bng19adXy32E5UQ  {'HasTV': 'False', 'BikeParking': 'True', 'Noi...
# 3FB8FiwImxq5eL2GlBF3EQ                                                NaN
# ZUJkwu_NS4L41AXEbGqHBQ                                                NaN
# Be7Mwq06nf1eNLblo1ekow                                                NaN
# lB2bnoWizz44ubSypZcwTA                                                NaN
# Tq_S8F5B2fSeHqLZghOqQg                                                NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ                                                NaN
# Ri_K4vaiRNQjlyutXgadog                                                NaN
# c_XbaJqhm-5ycSBOkVUBmg                                                NaN
# ULAw5sRA8S2H4gK5paywVA                                                NaN
# WbQgJOU0vNMYcWkwcC2Jew                                                NaN
# J-A-VaoAvm3hMIb7VBJqHQ                                                NaN
# Bh-G9_WLTreZh2bv-3_ZMQ                                                NaN
# N0tp1hviGIgq8HIwvHTT9g                                                NaN
# uJgxCC03SWlwAkttc4exJQ                                                NaN
# 3WgRLMKmEIV2gLyFw4IKMA                                                NaN
# EmKn83E_Fs73KJ2x7d55UQ                                                NaN
# EreR7S8ZgCtc-s2IysYtqw                                                NaN
# pcuuO_p4z6T_uEylouim7A                                                NaN
# ARdkHJ748cC_7_fwViQxng                                                NaN
# B0WJTnfCA3LY7mEBziC0Fg                                                NaN
# eQL6UKYvkWERh21rF0Blnw                                                NaN
# K2uJfgsKunCuNKALv_mGUQ                                                NaN
# KgFmLr-HZeUZc7nsjMkSRw                                                NaN
# yC4nbyZd2x3_a5IYHpjxWA                                                NaN
# prUaUYJGqvcRrJYYMnNVXQ                                                NaN
# 5n2dA_QqO4c_7pSK0Of6AQ                                                NaN
# ...                                                                   ...
# 5V8zdJIbpGJ_BBgjbnHUmg                                                NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ                                                NaN
# fhdqLktxyn6T0vKvbqO1qA                                                NaN
# -gRDDhLdkAfki50Dt5P9Og                                                NaN
# j0i_MEV3XgGh4WegkthkiQ                                                NaN
# dmgtqr_MWXENsZ_7yzxWHw                                                NaN
# laBHq-98LF93adYf2Bl0cw                                                NaN
# z6puJBjp677RIcu8pQbjFA                                                NaN
# OhJHQhBB1V09mkI-r4o5MA                                                NaN
# J1hR6fcmGWUACBXQVQkhjw                                                NaN
# 1l23jN7IXzZ_UxJM3uFnhQ                                                NaN
# LhEKSw3h_vGG3ihKjiOItw                                                NaN
# W2D2eDrP9hGXWYli-4QJdg                                                NaN
# TwYdL1qY7FFBl1BqCo-CJw                                                NaN
# IsNyYU75dVu0Nnoo8bO4gA                                                NaN
# URCmJ-uP_2FyHrShsRPycA                                                NaN
# 5Heya5sQcGNdLI_IvEhzXw                                                NaN
# 7z2x16M7IuG8KPfMsyVrKA                                                NaN
# 8CSp_Zt1xbwFOkDOzu1jWA                                                NaN
# WO1kqacT_65MYW8DTeydkQ                                                NaN
# isw3cS3hOKdKeBgi3lF3-A                                                NaN
# pKiSzUlBBRNEdTML24piXA                                                NaN
# 2AtpxRG3opD2M7gtRvUUaw                                                NaN
# HFDZeMrm13xX5yJvpaRaIQ                                                NaN
# _oucYTswnckrgRuCzW3oVw                                                NaN
# 3aRt8JPhjkfvbhqb3kJsbg                                                NaN
# R3FZENdOY_TTKykKsJIuRA                                                NaN
# EVl5rbR90yb9vqyq4o5K3A                                                NaN
# HTngUd7s8kLBiAbEtd65Ug                                                NaN
# yKaIT0fnxEj0YVr1DMHvuQ                                                NaN
#
#                         average_stars  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A            NaN
# SfP326rcU5sjwGx_dQP2RQ            NaN
# DSCbB5lJLKnuxQKadFWrSw            NaN
# TMI7DZ7Bng19adXy32E5UQ            NaN
# 3FB8FiwImxq5eL2GlBF3EQ            NaN
# ZUJkwu_NS4L41AXEbGqHBQ            NaN
# Be7Mwq06nf1eNLblo1ekow            NaN
# lB2bnoWizz44ubSypZcwTA            NaN
# Tq_S8F5B2fSeHqLZghOqQg            NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ            NaN
# Ri_K4vaiRNQjlyutXgadog            NaN
# c_XbaJqhm-5ycSBOkVUBmg            NaN
# ULAw5sRA8S2H4gK5paywVA            NaN
# WbQgJOU0vNMYcWkwcC2Jew            NaN
# J-A-VaoAvm3hMIb7VBJqHQ            NaN
# Bh-G9_WLTreZh2bv-3_ZMQ            NaN
# N0tp1hviGIgq8HIwvHTT9g            NaN
# uJgxCC03SWlwAkttc4exJQ            NaN
# 3WgRLMKmEIV2gLyFw4IKMA            NaN
# EmKn83E_Fs73KJ2x7d55UQ            NaN
# EreR7S8ZgCtc-s2IysYtqw            NaN
# pcuuO_p4z6T_uEylouim7A            NaN
# ARdkHJ748cC_7_fwViQxng            NaN
# B0WJTnfCA3LY7mEBziC0Fg            NaN
# eQL6UKYvkWERh21rF0Blnw            NaN
# K2uJfgsKunCuNKALv_mGUQ            NaN
# KgFmLr-HZeUZc7nsjMkSRw            NaN
# yC4nbyZd2x3_a5IYHpjxWA            NaN
# prUaUYJGqvcRrJYYMnNVXQ            NaN
# 5n2dA_QqO4c_7pSK0Of6AQ            NaN
# ...                               ...
# 5V8zdJIbpGJ_BBgjbnHUmg            NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ            NaN
# fhdqLktxyn6T0vKvbqO1qA            NaN
# -gRDDhLdkAfki50Dt5P9Og            NaN
# j0i_MEV3XgGh4WegkthkiQ            NaN
# dmgtqr_MWXENsZ_7yzxWHw            NaN
# laBHq-98LF93adYf2Bl0cw            NaN
# z6puJBjp677RIcu8pQbjFA            NaN
# OhJHQhBB1V09mkI-r4o5MA            NaN
# J1hR6fcmGWUACBXQVQkhjw            NaN
# 1l23jN7IXzZ_UxJM3uFnhQ            NaN
# LhEKSw3h_vGG3ihKjiOItw            NaN
# W2D2eDrP9hGXWYli-4QJdg            NaN
# TwYdL1qY7FFBl1BqCo-CJw            NaN
# IsNyYU75dVu0Nnoo8bO4gA            NaN
# URCmJ-uP_2FyHrShsRPycA            NaN
# 5Heya5sQcGNdLI_IvEhzXw            NaN
# 7z2x16M7IuG8KPfMsyVrKA            NaN
# 8CSp_Zt1xbwFOkDOzu1jWA            NaN
# WO1kqacT_65MYW8DTeydkQ            NaN
# isw3cS3hOKdKeBgi3lF3-A            NaN
# pKiSzUlBBRNEdTML24piXA            NaN
# 2AtpxRG3opD2M7gtRvUUaw            NaN
# HFDZeMrm13xX5yJvpaRaIQ            NaN
# _oucYTswnckrgRuCzW3oVw            NaN
# 3aRt8JPhjkfvbhqb3kJsbg            NaN
# R3FZENdOY_TTKykKsJIuRA            NaN
# EVl5rbR90yb9vqyq4o5K3A            NaN
# HTngUd7s8kLBiAbEtd65Ug            NaN
# yKaIT0fnxEj0YVr1DMHvuQ            NaN
#
#                                                             categories  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A                                             NaN
# SfP326rcU5sjwGx_dQP2RQ                                             NaN
# DSCbB5lJLKnuxQKadFWrSw                                             NaN
# TMI7DZ7Bng19adXy32E5UQ  Canadian (New), Restaurants, Diners, Fast Food
# 3FB8FiwImxq5eL2GlBF3EQ                                             NaN
# ZUJkwu_NS4L41AXEbGqHBQ                                             NaN
# Be7Mwq06nf1eNLblo1ekow                                             NaN
# lB2bnoWizz44ubSypZcwTA                                             NaN
# Tq_S8F5B2fSeHqLZghOqQg                                             NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ                                             NaN
# Ri_K4vaiRNQjlyutXgadog                                             NaN
# c_XbaJqhm-5ycSBOkVUBmg                                             NaN
# ULAw5sRA8S2H4gK5paywVA                                             NaN
# WbQgJOU0vNMYcWkwcC2Jew                                             NaN
# J-A-VaoAvm3hMIb7VBJqHQ                                             NaN
# Bh-G9_WLTreZh2bv-3_ZMQ                                             NaN
# N0tp1hviGIgq8HIwvHTT9g                                             NaN
# uJgxCC03SWlwAkttc4exJQ                                             NaN
# 3WgRLMKmEIV2gLyFw4IKMA                                             NaN
# EmKn83E_Fs73KJ2x7d55UQ                                             NaN
# EreR7S8ZgCtc-s2IysYtqw                                             NaN
# pcuuO_p4z6T_uEylouim7A                                             NaN
# ARdkHJ748cC_7_fwViQxng                                             NaN
# B0WJTnfCA3LY7mEBziC0Fg                                             NaN
# eQL6UKYvkWERh21rF0Blnw                                             NaN
# K2uJfgsKunCuNKALv_mGUQ                                             NaN
# KgFmLr-HZeUZc7nsjMkSRw                                             NaN
# yC4nbyZd2x3_a5IYHpjxWA                                             NaN
# prUaUYJGqvcRrJYYMnNVXQ                                             NaN
# 5n2dA_QqO4c_7pSK0Of6AQ                                             NaN
# ...                                                                ...
# 5V8zdJIbpGJ_BBgjbnHUmg                                             NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ                                             NaN
# fhdqLktxyn6T0vKvbqO1qA                                             NaN
# -gRDDhLdkAfki50Dt5P9Og                                             NaN
# j0i_MEV3XgGh4WegkthkiQ                                             NaN
# dmgtqr_MWXENsZ_7yzxWHw                                             NaN
# laBHq-98LF93adYf2Bl0cw                                             NaN
# z6puJBjp677RIcu8pQbjFA                                             NaN
# OhJHQhBB1V09mkI-r4o5MA                                             NaN
# J1hR6fcmGWUACBXQVQkhjw                                             NaN
# 1l23jN7IXzZ_UxJM3uFnhQ                                             NaN
# LhEKSw3h_vGG3ihKjiOItw                                             NaN
# W2D2eDrP9hGXWYli-4QJdg                                             NaN
# TwYdL1qY7FFBl1BqCo-CJw                                             NaN
# IsNyYU75dVu0Nnoo8bO4gA                                             NaN
# URCmJ-uP_2FyHrShsRPycA                                             NaN
# 5Heya5sQcGNdLI_IvEhzXw                                             NaN
# 7z2x16M7IuG8KPfMsyVrKA                                             NaN
# 8CSp_Zt1xbwFOkDOzu1jWA                                             NaN
# WO1kqacT_65MYW8DTeydkQ                                             NaN
# isw3cS3hOKdKeBgi3lF3-A                                             NaN
# pKiSzUlBBRNEdTML24piXA                                             NaN
# 2AtpxRG3opD2M7gtRvUUaw                                             NaN
# HFDZeMrm13xX5yJvpaRaIQ                                             NaN
# _oucYTswnckrgRuCzW3oVw                                             NaN
# 3aRt8JPhjkfvbhqb3kJsbg                                             NaN
# R3FZENdOY_TTKykKsJIuRA                                             NaN
# EVl5rbR90yb9vqyq4o5K3A                                             NaN
# HTngUd7s8kLBiAbEtd65Ug                                             NaN
# yKaIT0fnxEj0YVr1DMHvuQ                                             NaN
#
#                                  city  compliment_cool  compliment_cute  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A            NaN              NaN              NaN
# SfP326rcU5sjwGx_dQP2RQ            NaN              NaN              NaN
# DSCbB5lJLKnuxQKadFWrSw            NaN              NaN              NaN
# TMI7DZ7Bng19adXy32E5UQ  Richmond Hill              NaN              NaN
# 3FB8FiwImxq5eL2GlBF3EQ            NaN              NaN              NaN
# ZUJkwu_NS4L41AXEbGqHBQ            NaN              NaN              NaN
# Be7Mwq06nf1eNLblo1ekow            NaN              NaN              NaN
# lB2bnoWizz44ubSypZcwTA            NaN              NaN              NaN
# Tq_S8F5B2fSeHqLZghOqQg            NaN              NaN              NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ            NaN              NaN              NaN
# Ri_K4vaiRNQjlyutXgadog            NaN              NaN              NaN
# c_XbaJqhm-5ycSBOkVUBmg            NaN              NaN              NaN
# ULAw5sRA8S2H4gK5paywVA            NaN              NaN              NaN
# WbQgJOU0vNMYcWkwcC2Jew            NaN              NaN              NaN
# J-A-VaoAvm3hMIb7VBJqHQ            NaN              NaN              NaN
# Bh-G9_WLTreZh2bv-3_ZMQ            NaN              NaN              NaN
# N0tp1hviGIgq8HIwvHTT9g            NaN              NaN              NaN
# uJgxCC03SWlwAkttc4exJQ            NaN              NaN              NaN
# 3WgRLMKmEIV2gLyFw4IKMA            NaN              NaN              NaN
# EmKn83E_Fs73KJ2x7d55UQ            NaN              NaN              NaN
# EreR7S8ZgCtc-s2IysYtqw            NaN              NaN              NaN
# pcuuO_p4z6T_uEylouim7A            NaN              NaN              NaN
# ARdkHJ748cC_7_fwViQxng            NaN              NaN              NaN
# B0WJTnfCA3LY7mEBziC0Fg            NaN              NaN              NaN
# eQL6UKYvkWERh21rF0Blnw            NaN              NaN              NaN
# K2uJfgsKunCuNKALv_mGUQ            NaN              NaN              NaN
# KgFmLr-HZeUZc7nsjMkSRw            NaN              NaN              NaN
# yC4nbyZd2x3_a5IYHpjxWA            NaN              NaN              NaN
# prUaUYJGqvcRrJYYMnNVXQ            NaN              NaN              NaN
# 5n2dA_QqO4c_7pSK0Of6AQ            NaN              NaN              NaN
# ...                               ...              ...              ...
# 5V8zdJIbpGJ_BBgjbnHUmg            NaN              NaN              NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ            NaN              NaN              NaN
# fhdqLktxyn6T0vKvbqO1qA            NaN              NaN              NaN
# -gRDDhLdkAfki50Dt5P9Og            NaN              NaN              NaN
# j0i_MEV3XgGh4WegkthkiQ            NaN              NaN              NaN
# dmgtqr_MWXENsZ_7yzxWHw            NaN              NaN              NaN
# laBHq-98LF93adYf2Bl0cw            NaN              NaN              NaN
# z6puJBjp677RIcu8pQbjFA            NaN              NaN              NaN
# OhJHQhBB1V09mkI-r4o5MA            NaN              NaN              NaN
# J1hR6fcmGWUACBXQVQkhjw            NaN              NaN              NaN
# 1l23jN7IXzZ_UxJM3uFnhQ            NaN              NaN              NaN
# LhEKSw3h_vGG3ihKjiOItw            NaN              NaN              NaN
# W2D2eDrP9hGXWYli-4QJdg            NaN              NaN              NaN
# TwYdL1qY7FFBl1BqCo-CJw            NaN              NaN              NaN
# IsNyYU75dVu0Nnoo8bO4gA            NaN              NaN              NaN
# URCmJ-uP_2FyHrShsRPycA            NaN              NaN              NaN
# 5Heya5sQcGNdLI_IvEhzXw            NaN              NaN              NaN
# 7z2x16M7IuG8KPfMsyVrKA            NaN              NaN              NaN
# 8CSp_Zt1xbwFOkDOzu1jWA            NaN              NaN              NaN
# WO1kqacT_65MYW8DTeydkQ            NaN              NaN              NaN
# isw3cS3hOKdKeBgi3lF3-A            NaN              NaN              NaN
# pKiSzUlBBRNEdTML24piXA            NaN              NaN              NaN
# 2AtpxRG3opD2M7gtRvUUaw            NaN              NaN              NaN
# HFDZeMrm13xX5yJvpaRaIQ            NaN              NaN              NaN
# _oucYTswnckrgRuCzW3oVw            NaN              NaN              NaN
# 3aRt8JPhjkfvbhqb3kJsbg            NaN              NaN              NaN
# R3FZENdOY_TTKykKsJIuRA            NaN              NaN              NaN
# EVl5rbR90yb9vqyq4o5K3A            NaN              NaN              NaN
# HTngUd7s8kLBiAbEtd65Ug            NaN              NaN              NaN
# yKaIT0fnxEj0YVr1DMHvuQ            NaN              NaN              NaN
#
#                         compliment_funny  compliment_hot  compliment_list  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A               NaN             NaN              NaN
# SfP326rcU5sjwGx_dQP2RQ               NaN             NaN              NaN
# DSCbB5lJLKnuxQKadFWrSw               NaN             NaN              NaN
# TMI7DZ7Bng19adXy32E5UQ               NaN             NaN              NaN
# 3FB8FiwImxq5eL2GlBF3EQ               NaN             NaN              NaN
# ZUJkwu_NS4L41AXEbGqHBQ               NaN             NaN              NaN
# Be7Mwq06nf1eNLblo1ekow               NaN             NaN              NaN
# lB2bnoWizz44ubSypZcwTA               NaN             NaN              NaN
# Tq_S8F5B2fSeHqLZghOqQg               NaN             NaN              NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ               NaN             NaN              NaN
# Ri_K4vaiRNQjlyutXgadog               NaN             NaN              NaN
# c_XbaJqhm-5ycSBOkVUBmg               NaN             NaN              NaN
# ULAw5sRA8S2H4gK5paywVA               NaN             NaN              NaN
# WbQgJOU0vNMYcWkwcC2Jew               NaN             NaN              NaN
# J-A-VaoAvm3hMIb7VBJqHQ               NaN             NaN              NaN
# Bh-G9_WLTreZh2bv-3_ZMQ               NaN             NaN              NaN
# N0tp1hviGIgq8HIwvHTT9g               NaN             NaN              NaN
# uJgxCC03SWlwAkttc4exJQ               NaN             NaN              NaN
# 3WgRLMKmEIV2gLyFw4IKMA               NaN             NaN              NaN
# EmKn83E_Fs73KJ2x7d55UQ               NaN             NaN              NaN
# EreR7S8ZgCtc-s2IysYtqw               NaN             NaN              NaN
# pcuuO_p4z6T_uEylouim7A               NaN             NaN              NaN
# ARdkHJ748cC_7_fwViQxng               NaN             NaN              NaN
# B0WJTnfCA3LY7mEBziC0Fg               NaN             NaN              NaN
# eQL6UKYvkWERh21rF0Blnw               NaN             NaN              NaN
# K2uJfgsKunCuNKALv_mGUQ               NaN             NaN              NaN
# KgFmLr-HZeUZc7nsjMkSRw               NaN             NaN              NaN
# yC4nbyZd2x3_a5IYHpjxWA               NaN             NaN              NaN
# prUaUYJGqvcRrJYYMnNVXQ               NaN             NaN              NaN
# 5n2dA_QqO4c_7pSK0Of6AQ               NaN             NaN              NaN
# ...                                  ...             ...              ...
# 5V8zdJIbpGJ_BBgjbnHUmg               NaN             NaN              NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ               NaN             NaN              NaN
# fhdqLktxyn6T0vKvbqO1qA               NaN             NaN              NaN
# -gRDDhLdkAfki50Dt5P9Og               NaN             NaN              NaN
# j0i_MEV3XgGh4WegkthkiQ               NaN             NaN              NaN
# dmgtqr_MWXENsZ_7yzxWHw               NaN             NaN              NaN
# laBHq-98LF93adYf2Bl0cw               NaN             NaN              NaN
# z6puJBjp677RIcu8pQbjFA               NaN             NaN              NaN
# OhJHQhBB1V09mkI-r4o5MA               NaN             NaN              NaN
# J1hR6fcmGWUACBXQVQkhjw               NaN             NaN              NaN
# 1l23jN7IXzZ_UxJM3uFnhQ               NaN             NaN              NaN
# LhEKSw3h_vGG3ihKjiOItw               NaN             NaN              NaN
# W2D2eDrP9hGXWYli-4QJdg               NaN             NaN              NaN
# TwYdL1qY7FFBl1BqCo-CJw               NaN             NaN              NaN
# IsNyYU75dVu0Nnoo8bO4gA               NaN             NaN              NaN
# URCmJ-uP_2FyHrShsRPycA               NaN             NaN              NaN
# 5Heya5sQcGNdLI_IvEhzXw               NaN             NaN              NaN
# 7z2x16M7IuG8KPfMsyVrKA               NaN             NaN              NaN
# 8CSp_Zt1xbwFOkDOzu1jWA               NaN             NaN              NaN
# WO1kqacT_65MYW8DTeydkQ               NaN             NaN              NaN
# isw3cS3hOKdKeBgi3lF3-A               NaN             NaN              NaN
# pKiSzUlBBRNEdTML24piXA               NaN             NaN              NaN
# 2AtpxRG3opD2M7gtRvUUaw               NaN             NaN              NaN
# HFDZeMrm13xX5yJvpaRaIQ               NaN             NaN              NaN
# _oucYTswnckrgRuCzW3oVw               NaN             NaN              NaN
# 3aRt8JPhjkfvbhqb3kJsbg               NaN             NaN              NaN
# R3FZENdOY_TTKykKsJIuRA               NaN             NaN              NaN
# EVl5rbR90yb9vqyq4o5K3A               NaN             NaN              NaN
# HTngUd7s8kLBiAbEtd65Ug               NaN             NaN              NaN
# yKaIT0fnxEj0YVr1DMHvuQ               NaN             NaN              NaN
#
#                             ...         latitude  longitude  \
# business_id                 ...
# yWwIUmeenyAO7nwc7U0U5A      ...              NaN        NaN
# SfP326rcU5sjwGx_dQP2RQ      ...              NaN        NaN
# DSCbB5lJLKnuxQKadFWrSw      ...              NaN        NaN
# TMI7DZ7Bng19adXy32E5UQ      ...        43.874637 -79.438233
# 3FB8FiwImxq5eL2GlBF3EQ      ...              NaN        NaN
# ZUJkwu_NS4L41AXEbGqHBQ      ...              NaN        NaN
# Be7Mwq06nf1eNLblo1ekow      ...              NaN        NaN
# lB2bnoWizz44ubSypZcwTA      ...              NaN        NaN
# Tq_S8F5B2fSeHqLZghOqQg      ...              NaN        NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ      ...              NaN        NaN
# Ri_K4vaiRNQjlyutXgadog      ...              NaN        NaN
# c_XbaJqhm-5ycSBOkVUBmg      ...              NaN        NaN
# ULAw5sRA8S2H4gK5paywVA      ...              NaN        NaN
# WbQgJOU0vNMYcWkwcC2Jew      ...              NaN        NaN
# J-A-VaoAvm3hMIb7VBJqHQ      ...              NaN        NaN
# Bh-G9_WLTreZh2bv-3_ZMQ      ...              NaN        NaN
# N0tp1hviGIgq8HIwvHTT9g      ...              NaN        NaN
# uJgxCC03SWlwAkttc4exJQ      ...              NaN        NaN
# 3WgRLMKmEIV2gLyFw4IKMA      ...              NaN        NaN
# EmKn83E_Fs73KJ2x7d55UQ      ...              NaN        NaN
# EreR7S8ZgCtc-s2IysYtqw      ...              NaN        NaN
# pcuuO_p4z6T_uEylouim7A      ...              NaN        NaN
# ARdkHJ748cC_7_fwViQxng      ...              NaN        NaN
# B0WJTnfCA3LY7mEBziC0Fg      ...              NaN        NaN
# eQL6UKYvkWERh21rF0Blnw      ...              NaN        NaN
# K2uJfgsKunCuNKALv_mGUQ      ...              NaN        NaN
# KgFmLr-HZeUZc7nsjMkSRw      ...              NaN        NaN
# yC4nbyZd2x3_a5IYHpjxWA      ...              NaN        NaN
# prUaUYJGqvcRrJYYMnNVXQ      ...              NaN        NaN
# 5n2dA_QqO4c_7pSK0Of6AQ      ...              NaN        NaN
# ...                         ...              ...        ...
# 5V8zdJIbpGJ_BBgjbnHUmg      ...              NaN        NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ      ...              NaN        NaN
# fhdqLktxyn6T0vKvbqO1qA      ...              NaN        NaN
# -gRDDhLdkAfki50Dt5P9Og      ...              NaN        NaN
# j0i_MEV3XgGh4WegkthkiQ      ...              NaN        NaN
# dmgtqr_MWXENsZ_7yzxWHw      ...              NaN        NaN
# laBHq-98LF93adYf2Bl0cw      ...              NaN        NaN
# z6puJBjp677RIcu8pQbjFA      ...              NaN        NaN
# OhJHQhBB1V09mkI-r4o5MA      ...              NaN        NaN
# J1hR6fcmGWUACBXQVQkhjw      ...              NaN        NaN
# 1l23jN7IXzZ_UxJM3uFnhQ      ...              NaN        NaN
# LhEKSw3h_vGG3ihKjiOItw      ...              NaN        NaN
# W2D2eDrP9hGXWYli-4QJdg      ...              NaN        NaN
# TwYdL1qY7FFBl1BqCo-CJw      ...              NaN        NaN
# IsNyYU75dVu0Nnoo8bO4gA      ...              NaN        NaN
# URCmJ-uP_2FyHrShsRPycA      ...              NaN        NaN
# 5Heya5sQcGNdLI_IvEhzXw      ...              NaN        NaN
# 7z2x16M7IuG8KPfMsyVrKA      ...              NaN        NaN
# 8CSp_Zt1xbwFOkDOzu1jWA      ...              NaN        NaN
# WO1kqacT_65MYW8DTeydkQ      ...              NaN        NaN
# isw3cS3hOKdKeBgi3lF3-A      ...              NaN        NaN
# pKiSzUlBBRNEdTML24piXA      ...              NaN        NaN
# 2AtpxRG3opD2M7gtRvUUaw      ...              NaN        NaN
# HFDZeMrm13xX5yJvpaRaIQ      ...              NaN        NaN
# _oucYTswnckrgRuCzW3oVw      ...              NaN        NaN
# 3aRt8JPhjkfvbhqb3kJsbg      ...              NaN        NaN
# R3FZENdOY_TTKykKsJIuRA      ...              NaN        NaN
# EVl5rbR90yb9vqyq4o5K3A      ...              NaN        NaN
# HTngUd7s8kLBiAbEtd65Ug      ...              NaN        NaN
# yKaIT0fnxEj0YVr1DMHvuQ      ...              NaN        NaN
#
#                                         name  postal_code  review_count  \
# business_id
# yWwIUmeenyAO7nwc7U0U5A                   NaN          NaN           NaN
# SfP326rcU5sjwGx_dQP2RQ                   NaN          NaN           NaN
# DSCbB5lJLKnuxQKadFWrSw                   NaN          NaN           NaN
# TMI7DZ7Bng19adXy32E5UQ  3 Coins Open Kitchen      L4C 1T6          32.0
# 3FB8FiwImxq5eL2GlBF3EQ                   NaN          NaN           NaN
# ZUJkwu_NS4L41AXEbGqHBQ                   NaN          NaN           NaN
# Be7Mwq06nf1eNLblo1ekow                   NaN          NaN           NaN
# lB2bnoWizz44ubSypZcwTA                   NaN          NaN           NaN
# Tq_S8F5B2fSeHqLZghOqQg                   NaN          NaN           NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ                   NaN          NaN           NaN
# Ri_K4vaiRNQjlyutXgadog                   NaN          NaN           NaN
# c_XbaJqhm-5ycSBOkVUBmg                   NaN          NaN           NaN
# ULAw5sRA8S2H4gK5paywVA                   NaN          NaN           NaN
# WbQgJOU0vNMYcWkwcC2Jew                   NaN          NaN           NaN
# J-A-VaoAvm3hMIb7VBJqHQ                   NaN          NaN           NaN
# Bh-G9_WLTreZh2bv-3_ZMQ                   NaN          NaN           NaN
# N0tp1hviGIgq8HIwvHTT9g                   NaN          NaN           NaN
# uJgxCC03SWlwAkttc4exJQ                   NaN          NaN           NaN
# 3WgRLMKmEIV2gLyFw4IKMA                   NaN          NaN           NaN
# EmKn83E_Fs73KJ2x7d55UQ                   NaN          NaN           NaN
# EreR7S8ZgCtc-s2IysYtqw                   NaN          NaN           NaN
# pcuuO_p4z6T_uEylouim7A                   NaN          NaN           NaN
# ARdkHJ748cC_7_fwViQxng                   NaN          NaN           NaN
# B0WJTnfCA3LY7mEBziC0Fg                   NaN          NaN           NaN
# eQL6UKYvkWERh21rF0Blnw                   NaN          NaN           NaN
# K2uJfgsKunCuNKALv_mGUQ                   NaN          NaN           NaN
# KgFmLr-HZeUZc7nsjMkSRw                   NaN          NaN           NaN
# yC4nbyZd2x3_a5IYHpjxWA                   NaN          NaN           NaN
# prUaUYJGqvcRrJYYMnNVXQ                   NaN          NaN           NaN
# 5n2dA_QqO4c_7pSK0Of6AQ                   NaN          NaN           NaN
# ...                                      ...          ...           ...
# 5V8zdJIbpGJ_BBgjbnHUmg                   NaN          NaN           NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ                   NaN          NaN           NaN
# fhdqLktxyn6T0vKvbqO1qA                   NaN          NaN           NaN
# -gRDDhLdkAfki50Dt5P9Og                   NaN          NaN           NaN
# j0i_MEV3XgGh4WegkthkiQ                   NaN          NaN           NaN
# dmgtqr_MWXENsZ_7yzxWHw                   NaN          NaN           NaN
# laBHq-98LF93adYf2Bl0cw                   NaN          NaN           NaN
# z6puJBjp677RIcu8pQbjFA                   NaN          NaN           NaN
# OhJHQhBB1V09mkI-r4o5MA                   NaN          NaN           NaN
# J1hR6fcmGWUACBXQVQkhjw                   NaN          NaN           NaN
# 1l23jN7IXzZ_UxJM3uFnhQ                   NaN          NaN           NaN
# LhEKSw3h_vGG3ihKjiOItw                   NaN          NaN           NaN
# W2D2eDrP9hGXWYli-4QJdg                   NaN          NaN           NaN
# TwYdL1qY7FFBl1BqCo-CJw                   NaN          NaN           NaN
# IsNyYU75dVu0Nnoo8bO4gA                   NaN          NaN           NaN
# URCmJ-uP_2FyHrShsRPycA                   NaN          NaN           NaN
# 5Heya5sQcGNdLI_IvEhzXw                   NaN          NaN           NaN
# 7z2x16M7IuG8KPfMsyVrKA                   NaN          NaN           NaN
# 8CSp_Zt1xbwFOkDOzu1jWA                   NaN          NaN           NaN
# WO1kqacT_65MYW8DTeydkQ                   NaN          NaN           NaN
# isw3cS3hOKdKeBgi3lF3-A                   NaN          NaN           NaN
# pKiSzUlBBRNEdTML24piXA                   NaN          NaN           NaN
# 2AtpxRG3opD2M7gtRvUUaw                   NaN          NaN           NaN
# HFDZeMrm13xX5yJvpaRaIQ                   NaN          NaN           NaN
# _oucYTswnckrgRuCzW3oVw                   NaN          NaN           NaN
# 3aRt8JPhjkfvbhqb3kJsbg                   NaN          NaN           NaN
# R3FZENdOY_TTKykKsJIuRA                   NaN          NaN           NaN
# EVl5rbR90yb9vqyq4o5K3A                   NaN          NaN           NaN
# HTngUd7s8kLBiAbEtd65Ug                   NaN          NaN           NaN
# yKaIT0fnxEj0YVr1DMHvuQ                   NaN          NaN           NaN
#
#                         stars  state  useful  user_id  yelping_since
# business_id
# yWwIUmeenyAO7nwc7U0U5A    NaN    NaN     NaN      NaN            NaN
# SfP326rcU5sjwGx_dQP2RQ    NaN    NaN     NaN      NaN            NaN
# DSCbB5lJLKnuxQKadFWrSw    NaN    NaN     NaN      NaN            NaN
# TMI7DZ7Bng19adXy32E5UQ    4.0     ON     NaN      NaN            NaN
# 3FB8FiwImxq5eL2GlBF3EQ    NaN    NaN     NaN      NaN            NaN
# ZUJkwu_NS4L41AXEbGqHBQ    NaN    NaN     NaN      NaN            NaN
# Be7Mwq06nf1eNLblo1ekow    NaN    NaN     NaN      NaN            NaN
# lB2bnoWizz44ubSypZcwTA    NaN    NaN     NaN      NaN            NaN
# Tq_S8F5B2fSeHqLZghOqQg    NaN    NaN     NaN      NaN            NaN
# 2VDzYl-dSl1lqp2Ucxh3cQ    NaN    NaN     NaN      NaN            NaN
# Ri_K4vaiRNQjlyutXgadog    NaN    NaN     NaN      NaN            NaN
# c_XbaJqhm-5ycSBOkVUBmg    NaN    NaN     NaN      NaN            NaN
# ULAw5sRA8S2H4gK5paywVA    NaN    NaN     NaN      NaN            NaN
# WbQgJOU0vNMYcWkwcC2Jew    NaN    NaN     NaN      NaN            NaN
# J-A-VaoAvm3hMIb7VBJqHQ    NaN    NaN     NaN      NaN            NaN
# Bh-G9_WLTreZh2bv-3_ZMQ    NaN    NaN     NaN      NaN            NaN
# N0tp1hviGIgq8HIwvHTT9g    NaN    NaN     NaN      NaN            NaN
# uJgxCC03SWlwAkttc4exJQ    NaN    NaN     NaN      NaN            NaN
# 3WgRLMKmEIV2gLyFw4IKMA    NaN    NaN     NaN      NaN            NaN
# EmKn83E_Fs73KJ2x7d55UQ    NaN    NaN     NaN      NaN            NaN
# EreR7S8ZgCtc-s2IysYtqw    NaN    NaN     NaN      NaN            NaN
# pcuuO_p4z6T_uEylouim7A    NaN    NaN     NaN      NaN            NaN
# ARdkHJ748cC_7_fwViQxng    NaN    NaN     NaN      NaN            NaN
# B0WJTnfCA3LY7mEBziC0Fg    NaN    NaN     NaN      NaN            NaN
# eQL6UKYvkWERh21rF0Blnw    NaN    NaN     NaN      NaN            NaN
# K2uJfgsKunCuNKALv_mGUQ    NaN    NaN     NaN      NaN            NaN
# KgFmLr-HZeUZc7nsjMkSRw    NaN    NaN     NaN      NaN            NaN
# yC4nbyZd2x3_a5IYHpjxWA    NaN    NaN     NaN      NaN            NaN
# prUaUYJGqvcRrJYYMnNVXQ    NaN    NaN     NaN      NaN            NaN
# 5n2dA_QqO4c_7pSK0Of6AQ    NaN    NaN     NaN      NaN            NaN
# ...                       ...    ...     ...      ...            ...
# 5V8zdJIbpGJ_BBgjbnHUmg    NaN    NaN     NaN      NaN            NaN
# 8rtd2ZoeNMHjCQQnWuZ-bQ    NaN    NaN     NaN      NaN            NaN
# fhdqLktxyn6T0vKvbqO1qA    NaN    NaN     NaN      NaN            NaN
# -gRDDhLdkAfki50Dt5P9Og    NaN    NaN     NaN      NaN            NaN
# j0i_MEV3XgGh4WegkthkiQ    NaN    NaN     NaN      NaN            NaN
# dmgtqr_MWXENsZ_7yzxWHw    NaN    NaN     NaN      NaN            NaN
# laBHq-98LF93adYf2Bl0cw    NaN    NaN     NaN      NaN            NaN
# z6puJBjp677RIcu8pQbjFA    NaN    NaN     NaN      NaN            NaN
# OhJHQhBB1V09mkI-r4o5MA    NaN    NaN     NaN      NaN            NaN
# J1hR6fcmGWUACBXQVQkhjw    NaN    NaN     NaN      NaN            NaN
# 1l23jN7IXzZ_UxJM3uFnhQ    NaN    NaN     NaN      NaN            NaN
# LhEKSw3h_vGG3ihKjiOItw    NaN    NaN     NaN      NaN            NaN
# W2D2eDrP9hGXWYli-4QJdg    NaN    NaN     NaN      NaN            NaN
# TwYdL1qY7FFBl1BqCo-CJw    NaN    NaN     NaN      NaN            NaN
# IsNyYU75dVu0Nnoo8bO4gA    NaN    NaN     NaN      NaN            NaN
# URCmJ-uP_2FyHrShsRPycA    NaN    NaN     NaN      NaN            NaN
# 5Heya5sQcGNdLI_IvEhzXw    NaN    NaN     NaN      NaN            NaN
# 7z2x16M7IuG8KPfMsyVrKA    NaN    NaN     NaN      NaN            NaN
# 8CSp_Zt1xbwFOkDOzu1jWA    NaN    NaN     NaN      NaN            NaN
# WO1kqacT_65MYW8DTeydkQ    NaN    NaN     NaN      NaN            NaN
# isw3cS3hOKdKeBgi3lF3-A    NaN    NaN     NaN      NaN            NaN
# pKiSzUlBBRNEdTML24piXA    NaN    NaN     NaN      NaN            NaN
# 2AtpxRG3opD2M7gtRvUUaw    NaN    NaN     NaN      NaN            NaN
# HFDZeMrm13xX5yJvpaRaIQ    NaN    NaN     NaN      NaN            NaN
# _oucYTswnckrgRuCzW3oVw    NaN    NaN     NaN      NaN            NaN
# 3aRt8JPhjkfvbhqb3kJsbg    NaN    NaN     NaN      NaN            NaN
# R3FZENdOY_TTKykKsJIuRA    NaN    NaN     NaN      NaN            NaN
# EVl5rbR90yb9vqyq4o5K3A    NaN    NaN     NaN      NaN            NaN
# HTngUd7s8kLBiAbEtd65Ug    NaN    NaN     NaN      NaN            NaN
# yKaIT0fnxEj0YVr1DMHvuQ    NaN    NaN     NaN      NaN            NaN
#
# [13589 rows x 33 columns]

# %%
# Dropping NaN columns 
df_user96 = df_all.dropna()

# %%
df_user96.head()
# Out:
#                                 address  \
# 1                  30 Eglinton Avenue W
# 2             10110 Johnston Rd, Ste 15
# 4        4209 Stuart Andrew Blvd, Ste F
# 7  4545 E Tropicana Rd Ste 8, Tropicana
# 9                       21689 Lorain Rd
#
#                                           attributes             business_id  \
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
# 7  {'RestaurantsPriceRange2': '3', 'GoodForKids':...  gbQN7vr_caG_A1ugSmGhWg
# 9  {'ByAppointmentOnly': 'False', 'BusinessAccept...  4GBVPIYRvzGh4K4TkRQ_rw
#
#                                           categories           city  \
# 1  Specialty Food, Restaurants, Dim Sum, Imported...    Mississauga
# 2                  Sushi Bars, Restaurants, Japanese      Charlotte
# 4  Plumbing, Shopping, Local Services, Home Servi...      Charlotte
# 7  Hair Salons, Hair Stylists, Barbers, Men's Hai...      Las Vegas
# 9      Beauty & Spas, Nail Salons, Day Spas, Massage  Fairview Park
#
#                                                hours  is_open   latitude  \
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...        1  43.605499
# 2  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...        1  35.092564
# 4  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...        1  35.190012
# 7  {'Monday': '10:0-19:0', 'Tuesday': '10:0-19:0'...        1  36.099872
# 9  {'Tuesday': '9:0-21:0', 'Wednesday': '9:0-21:0...        1  41.440825
#
#     longitude                         name postal_code  review_count  stars  \
# 1  -79.652289   Emerald Chinese Restaurant     L5R 3E7           128    2.5
# 2  -80.859132  Musashi Japanese Restaurant       28210           170    4.0
# 4  -80.887223          Queen City Plumbing       28217             4    4.0
# 7 -115.074574                    Supercuts       89121             3    3.5
# 9  -81.854097          Options Salon & Spa       44126             8    4.5
#
#   state         0         1         2         3         4
# 1    ON -0.193446  0.955682 -0.430761 -0.339235 -0.135455
# 2    NC -0.999814  0.999504  0.997142  0.999139 -0.999999
# 4    NC  0.711320 -0.885359  0.364526  0.424743 -0.867387
# 7    NV -0.046117  0.524608  0.838130 -0.468762 -0.132092
# 9    OH  0.302838  0.672846  0.201119 -0.888239 -0.320828

# %%
df_user96.count()
# Out:
# address               149
# attributes            150
# average_stars           0
# categories            151
# city                  151
# compliment_cool         0
# compliment_cute         0
# compliment_funny        0
# compliment_hot          0
# compliment_list         0
# compliment_more         0
# compliment_note         0
# compliment_photos       0
# compliment_plain        0
# compliment_profile      0
# compliment_writer       0
# cool                    0
# elite                   0
# fans                    0
# friends                 0
# funny                   0
# hours                 124
# is_open               151
# latitude              151
# longitude             151
# name                  151
# postal_code           151
# review_count          151
# stars                 151
# state                 151
# useful                  0
# user_id                 0
# yelping_since           0
# dtype: int64

# %%
get_reviews_for('19fdSca3MUoaGFNX2BrjTQ')

get_restaurants('Japanese')
# Out:
#                     business_id  cool                 date  funny  \
# 679434   19fdSca3MUoaGFNX2BrjTQ     0  2018-06-09 14:13:04      0
# 804232   19fdSca3MUoaGFNX2BrjTQ     0  2018-05-10 18:09:25      0
# 814150   19fdSca3MUoaGFNX2BrjTQ     1  2018-01-13 15:48:11      0
# 1000397  19fdSca3MUoaGFNX2BrjTQ     0  2018-08-30 01:30:04      0
# 1006603  19fdSca3MUoaGFNX2BrjTQ     0  2018-07-12 19:27:38      0
# 1201834  19fdSca3MUoaGFNX2BrjTQ     0  2018-01-30 19:27:07      0
# 1237683  19fdSca3MUoaGFNX2BrjTQ     0  2018-04-13 02:29:18      0
# 1308059  19fdSca3MUoaGFNX2BrjTQ     1  2018-01-06 21:55:16      0
#
#                       review_id  stars  \
# 679434   bDhAERq8suVl40xdk00zKQ    3.0
# 804232   TVzDDSiC6qQ2A2mjdwwV8w    5.0
# 814150   MWyp6vwBVbReDbJAYQUCpw    5.0
# 1000397  FgHiEau2OaB2sDkw4p15Dw    5.0
# 1006603  3HhyFikgJUW-SXWnp-dUtQ    5.0
# 1201834  tmT-drziC2y64jfXH3HTow    5.0
# 1237683  rWufRpJ9HWivqaa_5EW6uA    5.0
# 1308059  NOe4hvLsJqHHkwE8brfrPQ    5.0
#
#                                                       text  useful  \
# 679434   I was super excited to go here but was slightl...       0
# 804232   This is exactly what this area needs! You want...       0
# 814150   I happened upon this place randomly and just H...       1
# 1000397  Amazing! Quality ingredients, all sauces are h...       1
# 1006603  Incredible. I stopped in today and I'm blown a...       0
# 1201834  I just stopped in today as I was on my way bac...       0
# 1237683  Stopped in hereafter a workout session in the ...       1
# 1308059  Not one negative thing to say! Service was qui...       3
#
#                         user_id
# 679434   6aklT92xV0_duyUI9l84Pw
# 804232   96s7b2PBjmkzEeQTzmKp7w
# 814150   uBHRgjD2xy77JCVm7CwmOA
# 1000397  wlTd-6M1pkO7zs5CgopQOQ
# 1006603  oOB27OMd4k5oPTayEPClag
# 1201834  YYKuS5-8NGiAPNMwX9nO7g
# 1237683  7GIcGERUfVvOx_TNYomGcA
# 1308059  pz69IIgBrek4B__VV1-HIA

# %%
restaurants_df.head()
# Out:
#                        address  \
# 1637167    1170 Queen Street W
# 1637311  241 W Charleston Blvd
# 1637502        12061 Perry Hwy
# 1637809    1150 College Street
# 1638108      541-543 Carnot Rd
#
#                                                 attributes  average_stars  \
# 1637167  {'WiFi': "u'no'", 'BikeParking': 'True', 'Rest...            NaN
# 1637311  {'BusinessParking': "{'garage': False, 'street...            NaN
# 1637502  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...            NaN
# 1637809  {'BusinessParking': "{'garage': False, 'street...            NaN
# 1638108  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...            NaN
#
#                     business_id  \
# 1637167  NDuUMJfrWk52RA-H-OtrpA
# 1637311  v7ZFEEqJBg_r8NCwHRP_2A
# 1637502  El6Bum4I-0VWJRgzbtscJQ
# 1637809  4w-q_Wc77JzQZSIehKFTzA
# 1638108  5G9aIrRiCD4TZCC5j2D39A
#
#                                                 categories       city  \
# 1637167  Juice Bars & Smoothies, Food, Restaurants, Fas...    Toronto
# 1637311  Food, Pizza, Wine Bars, Bars, Restaurants, Nig...  Las Vegas
# 1637502  Fast Food, Sandwiches, Restaurants, Food, Food...    Wexford
# 1637809  Juice Bars & Smoothies, Restaurants, Sandwiche...    Toronto
# 1638108  Bagels, Donuts, Coffee & Tea, Breakfast & Brun...       Moon
#
#          compliment_cool  compliment_cute  compliment_funny  compliment_hot  \
# 1637167              NaN              NaN               NaN             NaN
# 1637311              NaN              NaN               NaN             NaN
# 1637502              NaN              NaN               NaN             NaN
# 1637809              NaN              NaN               NaN             NaN
# 1638108              NaN              NaN               NaN             NaN
#
#              ...         latitude   longitude            name  postal_code  \
# 1637167      ...        43.642889  -79.425429  Bolt Fresh Bar      M6J 1J5
# 1637311      ...        36.158264 -115.157967   Bistro Divino        89102
# 1637502      ...        40.632056  -80.058551    Jimmy John's        15090
# 1637809      ...        43.652361  -79.433924  Brockton Haunt      M6H 1B6
# 1638108      ...        40.515767  -80.221657  Dunkin' Donuts        15108
#
#          review_count  stars  state  useful  user_id  yelping_since
# 1637167            57    3.0     ON     NaN      NaN            NaN
# 1637311             3    4.5     NV     NaN      NaN            NaN
# 1637502            11    3.0     PA     NaN      NaN            NaN
# 1637809            25    4.0     ON     NaN      NaN            NaN
# 1638108             8    4.0     PA     NaN      NaN            NaN
#
# [5 rows x 34 columns]

# %%
# an example row
restaurants_and_food.head(1)['categories'].values
# Out:
# array(['Juice Bars & Smoothies, Food, Restaurants, Fast Food, Vegan'],
#       dtype=object)

# %%
df_category = restaurants_and_food['categories'].apply(lambda x: x[1:-1].split(',')).apply(pd.Series)
uniqueCategories = pd.DataFrame(df_category.stack().str.strip().unique())

# %%
categoriesToRemove = ['Grocery','Drugstores','Convenience Stores','Beauty & Spas','Photography Stores & Services',
                      'Cosmetics & Beauty Supply','Discount Store','Fashion','Department Stores','Gas Stations',
                      'Automotive','Music & Video','Event Planning & Services','Mobile Phones','Health & Medical',
                      'Weight Loss Centers','Home & Garden','Kitchen & Bath','Jewelry',"Children's Clothing",
                      'Accessories','Home Decor','Bus Tours','Auto Glass Services','Auto Detailing',
                      'Oil Change Stations', 'Auto Repair','Body Shops','Car Window Tinting','Car Wash',
                      'Gluten-Free','Fitness & Instruction','Nurseries & Gardening','Wedding Planning',
                      'Embroidery & Crochet','Dance Schools','Performing Arts',
                      'Wholesale Stores','Tobacco Shops','Nutritionists','Hobby Shops','Pet Services',
                      'Electronics','Plumbing','Gyms','Yoga','Walking Tours','Toy Stores','Pet Stores',
                      'Pet Groomers','Vape Shops','Head Shops',
                      'Souvenir Shops','Pharmacy','Appliances & Repair','Wholesalers','Party Equipment Rentals',
                      'Tattoo','Funeral Services & Cemeteries','Sporting Goods','Dog Walkers',
                      'Pet Boarding/Pet Sitting','Scavenger Hunts','Contractors','Trainers', 
                      'Customized Merchandise', 'Dry Cleaning & Laundry', 'Art Galleries'
                      'Tax Law', 'Bankruptcy Law', 'Tax Services', 'Estate Planning Law', 
                      'Business Consulting', 'Lawyers', 'Pet Adoption', 'Escape Games', 
                      'Animal Shelters', 'Commercial Real Estate', 'Real Estate Agents', 
                      'Real Estate Services', 'Home Inspectors']

# %%
restaurants_df = restaurants_and_food[~restaurants_and_food['categories'].str.contains('|'.join(categoriesToRemove))]

# %%
restaurants_df.to_csv('data/restaurants.csv')
restaurants_df = pd.read_csv('data/restaurants.csv', encoding='ISO-8859-1', index_col=0)
all_nan, some_nan = find_ftres_with_nan(restaurants_df)
# Out:
# All NaN Features:  20 ['average_stars', 'compliment_cool', 'compliment_cute', 'compliment_funny', 'compliment_hot', 'compliment_list', 'compliment_more', 'compliment_note', 'compliment_photos', 'compliment_plain', 'compliment_profile', 'compliment_writer', 'cool', 'elite', 'fans', 'friends', 'funny', 'useful', 'user_id', 'yelping_since'] Some NaN Features:  24 ['address', 'attributes', 'average_stars', 'compliment_cool', 'compliment_cute', 'compliment_funny', 'compliment_hot', 'compliment_list', 'compliment_more', 'compliment_note', 'compliment_photos', 'compliment_plain', 'compliment_profile', 'compliment_writer', 'cool', 'elite', 'fans', 'friends', 'funny', 'hours', 'postal_code', 'useful', 'user_id', 'yelping_since']

# %%
restaurants_df.head()
# Out:
#                        address  \
# 1637167    1170 Queen Street W
# 1637311  241 W Charleston Blvd
# 1637502        12061 Perry Hwy
# 1637809    1150 College Street
# 1638108      541-543 Carnot Rd
#
#                                                 attributes  average_stars  \
# 1637167  {'WiFi': "u'no'", 'BikeParking': 'True', 'Rest...            NaN
# 1637311  {'BusinessParking': "{'garage': False, 'street...            NaN
# 1637502  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...            NaN
# 1637809  {'BusinessParking': "{'garage': False, 'street...            NaN
# 1638108  {'BusinessAcceptsCreditCards': 'True', 'GoodFo...            NaN
#
#                     business_id  \
# 1637167  NDuUMJfrWk52RA-H-OtrpA
# 1637311  v7ZFEEqJBg_r8NCwHRP_2A
# 1637502  El6Bum4I-0VWJRgzbtscJQ
# 1637809  4w-q_Wc77JzQZSIehKFTzA
# 1638108  5G9aIrRiCD4TZCC5j2D39A
#
#                                                 categories       city  \
# 1637167  Juice Bars & Smoothies, Food, Restaurants, Fas...    Toronto
# 1637311  Food, Pizza, Wine Bars, Bars, Restaurants, Nig...  Las Vegas
# 1637502  Fast Food, Sandwiches, Restaurants, Food, Food...    Wexford
# 1637809  Juice Bars & Smoothies, Restaurants, Sandwiche...    Toronto
# 1638108  Bagels, Donuts, Coffee & Tea, Breakfast & Brun...       Moon
#
#          compliment_cool  compliment_cute  compliment_funny  compliment_hot  \
# 1637167              NaN              NaN               NaN             NaN
# 1637311              NaN              NaN               NaN             NaN
# 1637502              NaN              NaN               NaN             NaN
# 1637809              NaN              NaN               NaN             NaN
# 1638108              NaN              NaN               NaN             NaN
#
#              ...         latitude   longitude            name  postal_code  \
# 1637167      ...        43.642889  -79.425429  Bolt Fresh Bar      M6J 1J5
# 1637311      ...        36.158264 -115.157967   Bistro Divino        89102
# 1637502      ...        40.632056  -80.058551    Jimmy John's        15090
# 1637809      ...        43.652361  -79.433924  Brockton Haunt      M6H 1B6
# 1638108      ...        40.515767  -80.221657  Dunkin' Donuts        15108
#
#          review_count  stars  state  useful  user_id  yelping_since
# 1637167            57    3.0     ON     NaN      NaN            NaN
# 1637311             3    4.5     NV     NaN      NaN            NaN
# 1637502            11    3.0     PA     NaN      NaN            NaN
# 1637809            25    4.0     ON     NaN      NaN            NaN
# 1638108             8    4.0     PA     NaN      NaN            NaN
#
# [5 rows x 34 columns]

# %%
def reduce_review(df, business_list):
    
    #drop columns where business_id or user_id is null
    df.dropna(subset=['business_id','user_id'], how='any',inplace=True)
    
    #restrict to businesses that are restaurants
    df = df[df['business_id'].isin(business_list)]
    
    #only keep user_id's with more than one review
    df = df[df.groupby('user_id').user_id.transform(len) > 1]
    
    #verify this worked by taking the minimum amount of user_id counts
    print('The minimum amount of reviews per user is {}'
          .format(np.min(df.groupby('user_id')['business_id'].count())))
    return df

# %%
df_reviewSample = pd.read_csv('data/review_sample.csv',encoding = "ISO-8859-1",index_col=0)
restaurant_reviews = reduce_review(df_reviewSample, restaurants['business_id']) #create dataframe
# _, _ = find_ftres_with_nan(restaurant_reviews) #report if there are null values

# restaurant_reviews['review_date'] = pd.to_datetime(restaurant_reviews['date'])
# restaurant_reviews['review_year'] = restaurant_reviews['review_date'].dt.year
# restaurant_reviews['review_month'] = restaurant_reviews['review_date'].dt.month
# restaurant_reviews['review_weekday'] = restaurant_reviews['review_date'].dt.weekday_name

# rename_cols = {'cool': 'review_cool','funny':'review_funny','stars':'review_stars','useful':'review_useful'}
# restaurant_reviews.rename(columns=rename_cols, inplace=True)
# review_cols_to_drop = ['text', 'review_date', 'date']
# restaurant_reviews.drop(review_cols_to_drop, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-05327951bde2> in <module>
#       1 df_reviewSample = pd.read_csv('data/review_sample.csv',encoding = "ISO-8859-1",index_col=0)
# ----> 2 restaurant_reviews = reduce_review(df_reviewSample, restaurants['business_id']) #create dataframe
#       3 # _, _ = find_ftres_with_nan(restaurant_reviews) #report if there are null values
#       4
#       5 # restaurant_reviews['review_date'] = pd.to_datetime(restaurant_reviews['date'])
#
# NameError: name 'restaurants' is not defined

# %%
df_reviewSample.count()
# Out:
# business_id    668330
# cool           668330
# date           668330
# funny          668330
# review_id      668330
# stars          668330
# text           668330
# useful         668330
# user_id        668330
# dtype: int64

# %%
restaurants.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-5802bf89ff67> in <module>
# ----> 1 restaurants.count()
#
# NameError: name 'restaurants' is not defined
